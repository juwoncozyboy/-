# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import re

# %%
da = pd.read_excel('다나와 상품.xlsx')
da = da.drop_duplicates(subset=['name.1'])

co = pd.read_excel('커뮤니티 상품 DB.xlsx')
co = co.drop_duplicates(subset=['title'])

def preprocess_text(text):
    if isinstance(text, str):
        return re.sub(r'[^\s\d\w]', '', text)
    return ''

da['name.1'] = da['name.1'].apply(preprocess_text)
co['title'] = co['title'].apply(preprocess_text)

da['name.1'] = da['name.1'].fillna('').astype(str)
co['title'] = co['title'].fillna('').astype(str)

# %%
texts = da['name.1'].tolist() + co['title'].tolist()

# %%
# TF-IDF 벡터화
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)

# %%
from sklearn.cluster import DBSCAN

# 최적의 eps와 min_samples 설정
optimal_eps = 0.5  # K-거리 그래프에서 결정된 값
# min_samples = 5  # 일반적으로 데이터의 차원 수 + 1 이상
min_samples = 3

# DBSCAN 클러스터링
dbscan = DBSCAN(eps=optimal_eps, min_samples=min_samples)
clusters = dbscan.fit_predict(X)

# 클러스터링 결과 평가
num_clusters = len(set(clusters)) - (1 if -1 in clusters else 0)
print(f'클러스터 수: {num_clusters}')
# Out:
# 클러스터 수: 1182

# %%
# 실루엣 스코어
if num_clusters > 1:
     score = silhouette_score(X, clusters)
     print(f'실루엣 스코어: {score}')
else:
     print('측정되지 않음')
# Out:
# 실루엣 스코어: -0.27842722198667225

# %%
clustered_texts = pd.DataFrame({'text': texts, 'cluster': clusters})
for cluster_num in range(num_clusters):
    print(f"\nCluster {cluster_num}:")
    cluster_texts = clustered_texts[clustered_texts['cluster'] == cluster_num]['text'].values
    for text in cluster_texts:  
        print(text)
# Out:
# Cluster 0:
# 2021 울트라기어 17UD70PPX76K 16GB램
# 2021 울트라기어 17UD70PPX76K 64GB램
# 2021 울트라기어 17UD70PPX76K WIN10
# 2021 울트라기어 17UD70PPX76K WIN10 16GB램
# 2021 울트라기어 17UD70PPX76K WIN10 64GB램
#
# Cluster 1:
# 2022 그램1412세대 14ZD90QGX50K
# 2022 그램1412세대 14ZD90QGX50K WIN10
# 2022 그램1412세대 14ZD90QGX50K WIN11
#
# Cluster 2:
# 2022 그램1412세대 14ZD90QGX56K
# 2022 그램1412세대 14ZD90QGX56K WIN10
# 2022 그램1412세대 14ZD90QGX56K WIN11
#
# Cluster 3:
# 2022 그램1512세대 15ZD90QGX56K
# 2022 그램1512세대 15ZD90QGX56K WIN10
# 2022 그램1512세대 15ZD90QGX56K WIN11
#
# Cluster 4:
# 2022 그램1512세대 15ZD90QGX76K
# 2022 그램1512세대 15ZD90QGX76K WIN10
# 2022 그램1512세대 15ZD90QGX76K WIN11
#
# Cluster 5:
# 2022 그램1512세대 15ZD95QGX56K
# 2022 그램1512세대 15ZD95QGX56K WIN10
# 2022 그램1512세대 15ZD95QGX56K WIN11
#
# Cluster 6:
# 2022 그램1612세대 16ZD90QGX56K
# 2022 그램1612세대 16ZD90QGX56K WIN10
# 2022 그램1612세대 16ZD90QGX56K WIN11
#
# Cluster 7:
# 2022 그램1612세대 16ZD95QGX56K
# 2022 그램1612세대 16ZD95QGX56K WIN10
# 2022 그램1612세대 16ZD95QGX56K WIN11
#
# Cluster 8:
# 2022 그램1712세대 17ZD90QEX56K
# 2022 그램1712세대 17ZD90QEX56K WIN10
# 2022 그램1712세대 17ZD90QEX56K WIN11
#
# Cluster 9:
# 2022 그램1712세대 17ZD90QEX76K
# 2022 그램1712세대 17ZD90QEX76K WIN10
# 2022 그램1712세대 17ZD90QEX76K WIN11
#
# Cluster 10:
# 2022 그램1712세대 17ZD90QGX56K
# 2022 그램1712세대 17ZD90QGX56K WIN10
# 2022 그램1712세대 17ZD90QGX56K WIN11
#
# Cluster 11:
# 2022 그램1712세대 17ZD90QGX76K
# 2022 그램1712세대 17ZD90QGX76K WIN10
# 2022 그램1712세대 17ZD90QGX76K WIN11
#
# Cluster 12:
# 2022 울트라기어 17GD90QXX79K
# 2022 울트라기어 17GD90QXX79K 32GB램
# 2022 울트라기어 17GD90QXX79K WIN11
# 2022 울트라기어 17GD90QXX79K WIN11 32GB램
# 2022 울트라기어 17GD90QXX79K WIN11 64GB램
#
# Cluster 13:
# 2023 울트라PC 15UD50RGX36K
# 2023 울트라PC 15UD50RGX36K WIN11
# 2023 울트라PC 15UD50RGX36K WIN11 램
# 2023 울트라PC 15UD50RGX36K 램
#
# Cluster 14:
# 불스원샷 골드 경유차
# 불스원샷 뉴 카 경유차
# 불스원샷 스탠다드 경유차
# 불스원샷 프리미엄 경유차
#
# Cluster 15:
# 불스원샷 골드 휘발유차
# 불스원샷 뉴 카 휘발유차
# 불스원샷 스탠다드 휘발유차
# 불스원샷 프리미엄 휘발유차
#
# Cluster 16:
# 올바르고 반듯한 미니 찹쌀 핫도그
# 올바르고 반듯한 찹쌀 핫도그
# 올바르고 반듯한 치즈 찹쌀 핫도그
#
# Cluster 17:
# 부르르 제로콜라 체리
# 일화 부르르 제로콜라 체리 250ml X 30캔
# 부르르 제로콜라 체리 250ml 30캔 13900원무료
# 부르르 제로콜라 체리
# 부르르 제로콜라 250ml x 30캔
# 부르르 제로콜라 체리 30캔
# 부르르 제로콜라 체리 250ml x 30캔
# 부르르 제로콜라 250ml 30캔
# 부르르 제로콜라 체리 250ml X 30캔 12500원무료
# 부르르 제로콜라 체리 250ml 30캔 12500원무료
#
# Cluster 18:
# A 등급 컬러 혼합
# A 등급 컬러 혼합
# B 등급 컬러 혼합
#
# Cluster 19:
# A 등급 화이트 혼합
# A 등급 화이트 혼합
# B 등급 화이트 혼합
#
# Cluster 20:
# L글루타민 120캡슐 해외
# L글루타민 1000mg 120캡슐 해외
# L글루타민 500mg 120캡슐 해외
#
# Cluster 21:
# 프로컷 L 커터날
# 프로컷 S 커터날
# 프로컷 커터날 L
#
# Cluster 22:
# 갤럭시S21 5G 256GB 공기계
# 갤럭시S21 울트라 5G 256GB 공기계
# 갤럭시S21 플러스 5G 256GB 공기계
#
# Cluster 23:
# 갤럭시S22 256GB 공기계
# 갤럭시S22 울트라 256GB 공기계
# 갤럭시S22 플러스 256GB 공기계
#
# Cluster 24:
# 갤럭시S23 256GB KT 완납
# 갤럭시S23 FE 256GB KT 완납
# 갤럭시S23 울트라 256GB KT 완납
# 갤럭시S23 플러스 256GB KT 완납
#
# Cluster 25:
# 갤럭시S23 256GB 공기계
# 갤럭시S23 울트라 256GB 공기계
# 갤럭시S23 플러스 256GB 공기계
#
# Cluster 26:
# 갤럭시S23 256GB 자급제
# 갤럭시S23 울트라 256GB 자급제
# 갤럭시S23 플러스 256GB 자급제
#
# Cluster 27:
# 갤럭시S23 512GB 공기계
# 갤럭시S23 울트라 512GB 공기계
# 갤럭시S23 플러스 512GB 공기계
#
# Cluster 28:
# 갤럭시S24 256GB KT 완납
# 갤럭시S24 울트라 256GB KT 완납
# 갤럭시S24 플러스 256GB KT 완납
#
# Cluster 29:
# 갤럭시S24 256GB SKT 완납
# 갤럭시S24 울트라 256GB SKT 완납
# 갤럭시S24 플러스 256GB SKT 완납
#
# Cluster 30:
# 갤럭시S24 256GB 자급제
# 갤럭시S24 울트라 256GB 자급제
# 갤럭시S24 플러스 256GB 자급제
# 갤럭시S24 자급제 256GB
#
# Cluster 31:
# 갤럭시S24 512GB KT 제휴카드
# 갤럭시S24 울트라 512GB KT 제휴카드
# 갤럭시S24 플러스 512GB KT 제휴카드
#
# Cluster 32:
# 갤럭시S24 512GB 자급제
# 갤럭시S24 울트라 512GB 자급제
# 갤럭시S24 플러스 512GB 자급제
#
# Cluster 33:
# 갤럭시북2 NT550XEZA38A
# 갤럭시북2 NT550XEZA38A WIN11
# 갤럭시북2 NT550XEZA38A WIN11 16GB램
#
# Cluster 34:
# 갤럭시탭S8 WiFi
# 갤럭시탭S8 울트라 WiFi
# 갤럭시탭S8 플러스 WiFi
#
# Cluster 35:
# 갤럭시탭S9 5G
# 갤럭시탭S9 울트라 5G
# 갤럭시탭S9 플러스 5G
#
# Cluster 36:
# 갤럭시탭S9 WiFi
# 갤럭시탭S9 플러스 WiFi
# 갤럭시탭s9 WiFi
# 갤럭시탭S9 플러스 WIFI 256gb
#
# Cluster 37:
# 갤럭시탭S9 울트라 WiFi  버즈2 프로 패키지
# 갤럭시탭S9 울트라 WiFi 256GB 버즈2 프로 패키지
# 갤럭시탭S9 울트라 WiFi 512GB 버즈2 프로 패키지
#
# Cluster 38:
# 황성주 국산콩 검은콩 고칼슘 두유
# 황성주 국산콩 두유 검은콩 무가당
# 황성주 국산콩 두유 무가당
# 황성주 박사의 국산콩 두유 검은콩
# 황성주 박사의 국산콩 두유 검은콩 고구마
# 황성주 박사의 국산콩 두유 검은콩 고칼슘
# 황성주 박사의 국산콩 두유 검은콩 단호박
# 황성주 박사의 국산콩 두유 검은콩 무가당
# 황성주 박사의 국산콩 두유 검은콩 밤
# 황성주 박사의 국산콩 두유 무가당
#
# Cluster 39:
# 황성주 국산콩 두유 우리땅 17곡
# 황성주 박사의 국산콩 두유 우리땅 17곡
# 황성주 우리땅 17곡 두유
#
# Cluster 40:
# 황성주 국산콩 두유 호두와 아몬드
# 황성주 박사의 국산콩 두유 호두와 아몬드
# 황성주 호두와 아몬드 두유
#
# Cluster 41:
# 글루코닥터 골드 혈당시험지
# 글루코닥터 탑 혈당시험지
# 글루코닥터 혈당시험지
#
# Cluster 42:
# 초임계 알티지 식물성 오메가3 30캡슐
# 초임계 알티지 오메가3 비타민D 30캡슐
# 초임계 식물성 알티지 오메가3 비타민D 앤 E 30캡슐
# 초임계 식물성 알티지 오메가3 30캡슐
# 초임계 알티지 오메가3 30캡슐
# 초임계 알티지 오메가3 알파 30캡슐
#
# Cluster 43:
# 스마트 밴드 7
# 스마트 밴드 8
# 스마트 밴드 8 Pro
#
# Cluster 44:
# 닥터유 단백질바
# 닥터유 단백질바 미니
# 닥터유 프로 단백질바
#
# Cluster 45:
# 닥터유 에너지바 호두
# 닥터유 에너지바 호두 4개입
# 닥터유 에너지바 호두 미니
#
# Cluster 46:
# 미니 핫브레이크
# 핫브레이크 미니
# 핫브레이크 미니 오리지널
#
# Cluster 47:
# 마켓오 오 그래놀라 단백질바 리얼초콜릿맛
# 오 그래놀라 단백질바 리얼초콜릿맛
# 오 그래놀라 단백질바 미니 리얼초콜릿맛
#
# Cluster 48:
# 시그니처 미스틱 레인
# 시그니처 미스틱 레인 120매
# 시그니처 미스틱 레인 40매
# 시그니처 섬유탈취제 미스틱 레인
#
# Cluster 49:
# 멀티 논슬립 옷걸이
# 프리미엄 멀티 논슬립 옷걸이
# 베이직 멀티 논슬립 옷걸이
#
# Cluster 50:
# The미식 비빔면
# The미식 비빔면 컵
# The미식 비빔면 24개
#
# Cluster 51:
# 오리지널 항균 비누
# 항균 비누
# 항균 비누 오리지널
# 화이트 항균 비누
#
# Cluster 52:
# 비 프로폴리스 스프레이
# 프로폴리스 스프레이
# 프리미엄 프로폴리스 스프레이
#
# Cluster 53:
# 센텔리안24 마데카 선 크림
# 센텔리안24 마데카 크림 스틱
# 센텔리안24 마데카 크림 오리지널
#
# Cluster 54:
# Arctis 1 Wireless
# Arctis 1 Wireless X
# Arctis 9 Wireless
# Arctis Pro Wireless
#
# Cluster 55:
# Arctis Nova 1
# Arctis Nova 3
# Arctis Nova Pro
#
# Cluster 56:
# Arctis Nova 7 Wireless
# Arctis Nova Pro Wireless
# Arctis Nova Pro Wireless X
#
# Cluster 57:
# 달콤한 베지밀 비
# 달콤한 베지밀 비 190ml 병
# 달콤한 베지밀 비 190ml 팩
#
# Cluster 58:
# GF시리즈 Sword GF76 B13VFK
# GF시리즈 Sword GF76 B13VFK 32GB램
# GF시리즈 Sword GF76 B13VFK WIN11
# GF시리즈 Sword GF76 B13VFK WIN11 32GB램
#
# Cluster 59:
# SPATIUM M480 PRO M2 NVMe
# SPATIUM M480 PRO M2 NVMe 해외구매
# MSI SPATIUM M480 PRO M2 NVMe 2TB
# MSI SPATIUM M480 PRO 2TB  1TBmsi spatium m480 pro
# MSI SPATIUM M480 PRO 2TB
# MSI SPATIUM M480 PRO M2 NVMe 1TB
#
# Cluster 60:
# 사이보그 15 AI A1VFK
# 사이보그 15 AI A1VFK 16GB램
# 사이보그 15 AI A1VFK 32GB램
# 사이보그 15 AI A1VFK WIN11 16GB램
# 사이보그 15 AI A1VFK WIN11 32GB램
#
# Cluster 61:
# 알파 17 C7VGR9 QHD
# 알파 17 C7VGR9 QHD 64GB램
# 알파 17 C7VGR9 QHD WIN11
# 알파 17 C7VGR9 QHD WIN11 64GB램
#
# Cluster 62:
# 짜글면 고깃집 된장찌개
# 풀무원 짜글면 고깃집 된장찌개 4개
# 풀무원 짜글면 고깃집 된장찌개
#
# Cluster 63:
# G502 X LIGHTSPEED
# G502 X LIGHTSPEED 정품
# 로지텍 G502 X LIGHTSPEED
#
# Cluster 64:
# MX Anywhere 3S
# MX Anywhere 3S 정품
# 로지텍 mx anywhere 3s
#
# Cluster 65:
# MX Master 3S
# MX Master 3S 정품
# 로지텍 MX MASTER 3S 무소음 무선 마우스 화이트
# 로지텍 MX MASTER 3S 블루투스 무선 마우스
# 로지텍 MX MASTER 3S
# 로지텍 MX MASTER 3S 무선 마우스
# 로지텍 MX MASTER 3S 무선 블루투스 마우스
# 로지텍 mx master 3s
#
# Cluster 66:
# 상하목장 유기농 멸균 우유
# 상하목장 유기농 우유 125ml 멸균
# 상하목장 유기농 우유 190ml 멸균
# 상하목장 유기농 우유 200ml 멸균
# 상하목장 유기농 우유 900ml 멸균
# 상하목장 유기농 우유 저지방 200ml 멸균
#
# Cluster 67:
# 소화가 잘되는 우유 바나나 락토프리 우유  멸균
# 소화가 잘되는 우유 오리지널 락토프리
# 소화가 잘되는 우유 오리지널 락토프리 우유  멸균
# 소화가 잘되는 우유 오리지널 락토프리 우유 190ml 멸균
# 소화가 잘되는 우유 저지방 락토프리
# 소화가 잘되는 우유 저지방 락토프리 우유  멸균
# 소화가 잘되는 우유 저지방 락토프리 우유 190ml 멸균
# 소화가 잘되는 우유 초콜릿 락토프리 우유  멸균
#
# Cluster 68:
# 에어랩 멀티 스타일러 컴플리트
# 에어랩 멀티 스타일러 컴플리트 롱
# 에어랩 스타일러 컴플리트
# 에어랩 스타일러 컴플리트 롱
#
# Cluster 69:
# X
# F
# 잣
#
# L
# 츄 2
# 첨
# 格 격
#  뭐
#
#
#
#
# 펑
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ฏ
#
# 1
#
#
#
#
#
# 뻥
#
#
# o
#
# Cluster 70:
# 엘리트북 630 G10 9F291PT
# 엘리트북 630 G10 9F291PT 32GB램
# 엘리트북 630 G10 9F291PT 64GB램
#
# Cluster 71:
# 엘리트북 640 G10 88D11PA
# 엘리트북 640 G10 88D11PA 32GB램
# 엘리트북 640 G10 88D11PA 64GB램
#
# Cluster 72:
# 엘리트북 640 G10 9F1K5PT
# 엘리트북 640 G10 9F1K5PT 32GB램
# 엘리트북 640 G10 9F1K5PT 64GB램
#
# Cluster 73:
# 엘리트북 640 G10 9F1K6PT
# 엘리트북 640 G10 9F1K6PT 32GB램
# 엘리트북 640 G10 9F1K6PT 64GB램
#
# Cluster 74:
# 엘리트북 640 G11 A40ZSPT
# 엘리트북 640 G11 A40ZSPT 32GB램
# 엘리트북 640 G11 A40ZSPT 64GB램
#
# Cluster 75:
# 엘리트북 645 G10 80D09PA
# 엘리트북 645 G10 80D09PA 16GB램
# 엘리트북 645 G10 80D09PA 32GB램
#
# Cluster 76:
# 엘리트북 645 G10 80D10PA
# 엘리트북 645 G10 80D10PA 16GB램
# 엘리트북 645 G10 80D10PA 32GB램
# 엘리트북 645 G10 80D10PA 64GB램
# 엘리트북 645 G10 80D10PA WIN11
# 엘리트북 645 G10 80D10PA WIN11 16GB램
# 엘리트북 645 G10 80D10PA WIN11 32GB램
#
# Cluster 77:
# 엘리트북 650 G10 88D08PA
# 엘리트북 650 G10 88D08PA 32GB램
# 엘리트북 650 G10 88D08PA 64GB램
#
# Cluster 78:
# 엘리트북 650 G10 88D09PA
# 엘리트북 650 G10 88D09PA 32GB램
# 엘리트북 650 G10 88D09PA 64GB램
#
# Cluster 79:
# 엘리트북 840 G11 8M4X5AV
# 엘리트북 840 G11 8M4X5AV 32GB램
# 엘리트북 840 G11 8M4X5AV 64GB램
#
# Cluster 80:
# 엘리트북 840 G11 A1VH3PT
# 엘리트북 840 G11 A1VH3PT 32GB램
# 엘리트북 840 G11 A1VH3PT 64GB램
#
# Cluster 81:
# 엘리트북 840 G11 A1VK4PT
# 엘리트북 840 G11 A1VK4PT 32GB램
# 엘리트북 840 G11 A1VK4PT 64GB램
#
# Cluster 82:
# 엘리트북 860 G11 A1VH4PT
# 엘리트북 860 G11 A1VH4PT 32GB램
# 엘리트북 860 G11 A1VH4PT 64GB램
#
# Cluster 83:
# 엘리트북 860 G11 A1VK5PT
# 엘리트북 860 G11 A1VK5PT 32GB램
# 엘리트북 860 G11 A1VK5PT 64GB램
#
# Cluster 84:
# DK200 RGB 강화유리
# DK200 RGB 강화유리 블랙 등
# DK200 RGB 강화유리 V2
#
# Cluster 85:
# 종가집 행복이온 전라도 포기김치
# 종가집 행복이온 포기김치
# 종가집 행복이온 포기김치 10kg
#
# Cluster 86:
# 청정원 굴소스
# 청정원 프리미엄 굴소스
# 청정원 굴소스 500ml 3개
# 청정원 굴소스 500ml
#
# Cluster 87:
# 청정원 두번달여 더 진한 진간장
# 청정원 두번달여 더 진한 진간장 골드
# 청정원 햇살담은 두번달여 더 진한 진간장 골드
#
# Cluster 88:
# The더건강한 닭가슴살 꼬치
# The더건강한 닭가슴살 소시지 꼬치
# The더건강한 닭가슴살 소시지 혼합 꼬치
#
# Cluster 89:
# 고메 소바바치킨 소이허니 봉
# 고메 소바바치킨 소이허니 순살
# 고메 소바바치킨 소이허니 윙
#
# Cluster 90:
# 고메 치즈 크리스피 핫도그
# 고메 치즈 크리스피 핫도그 4개입
# 고메 크리스피 핫도그
# 고메 핫도그 크리스피
#
# Cluster 91:
# 비비고 썰은 배추김치
# 비비고 썰은 배추김치  용기
# 비비고 썰은 배추김치 300g 용기
# 비비고 썰은 배추김치 500g 용기
#
# Cluster 92:
# 냉장 닭가슴살
# 닭가슴살 냉장
# 냉장 생 닭가슴살
#
# Cluster 93:
# 더리얼 그레인프리 크런치 닭고기 시니어
# 더리얼 캣 그레인프리 크런치 닭고기 시니어
# 더리얼 크런치 닭고기 시니어
#
# Cluster 94:
# 더리얼 그레인프리 크런치 닭고기 어덜트
# 더리얼 캣 그레인프리 크런치 닭고기 어덜트
# 더리얼 크런치 닭고기 어덜트
#
# Cluster 95:
# es고무장갑 대
# es고무장갑 소
# es고무장갑 중
#
# Cluster 96:
# 고무장갑 대
# 고무장갑 M
# 고무장갑 S
# 고무장갑 소
#
# Cluster 97:
# 하이퍼맥스 알카라인 AAA 벌크
# 하이퍼맥스 캐릭터 알카라인 AAA
# 하이퍼맥스 캐릭터 알카라인 AAA 벌크
#
# Cluster 98:
# 라텍스 고무장갑 중
# 프리미엄 라텍스 고무장갑 대
# 라텍스 고무장갑 10개
#
# Cluster 99:
# 냉장고 탈취제
# 냉장고 탈취제 숯
# 큰 냉장고 탈취제 숯
#
# Cluster 100:
# BlackShark V2
# BlackShark V2 Pro
# BlackShark V2 Pro 2023
# BlackShark V2 X
# BlackShark V2 X USB
# Blackshark V2
#
# Cluster 101:
# 크리넥스 NEW 데코소프트  30롤
# 크리넥스 NEW 데코소프트 27m 30롤
# 크리넥스 NEW 데코소프트 30m 30롤
# 크리넥스 NEW 데코소프트 화이트  30롤
#
# Cluster 102:
# 크리넥스 안심 키친타월 에코 패키지 120매 12롤
# 크리넥스 안심 키친타월 에코 패키지 120매 12롤 6880무료배송크리넥스 안심 키친타월 에코 패키지
# 크리넥스 안심 키친타월 에코 패키지 120매 12롤 6880원무료크리넥스 안심 키친타월 에코 패키지
#
# Cluster 103:
# 하기스 2023 네이처메이드 밤부 밴드형 2단계공용
# 하기스 2023 네이처메이드 밴드형 2단계공용
# 하기스 2023 네이처메이드 썸머 밴드형 2단계공용
# 하기스 2024 네이처메이드 밤부 밴드형 2단계공용
# 하기스 2024 네이처메이드 밴드형 2단계공용
# 하기스 2024 네이처메이드 썸머 밴드형 2단계공용
#
# Cluster 104:
# 하기스 2023 네이처메이드 밴드형 3단계공용
# 하기스 2023 네이처메이드 썸머 밴드형 3단계공용
# 하기스 2024 네이처메이드 밤부 밴드형 3단계공용
# 하기스 2024 네이처메이드 밴드형 3단계공용
# 하기스 2024 네이처메이드 썸머 밴드형 3단계공용
#
# Cluster 105:
# 락토핏 5X 생유산균 코어 2g 60포
# 락토핏 5X 생유산균 코어맥스 2g 60포
# 락토핏 5X 생유산균 팜 2g 60포
#
# Cluster 106:
# 락토핏 생유산균 맘스 2g 60포
# 락토핏 생유산균 맘스 60포
# 락토핏 생유산균 맘스 60포 리뉴얼
#
# Cluster 107:
# 락토핏 생유산균 베베 2g 60포
# 락토핏 생유산균 베베 60포
# 락토핏 생유산균 베베 60포 리뉴얼
#
# Cluster 108:
# 락토핏 생유산균 코어 60포 리뉴얼
# 락토핏 생유산균 코어 60포 3개입 세트
# 락토핏 생유산균 코어 60포 3개입 세트 리뉴얼
#
# Cluster 109:
# 칼슘 앤 마그네슘 비타민D 아연 180정
# 어린이 칼슘 마그네슘 아연 비타민D 180정
# 프라임 칼슘 마그네슘 비타민D 아연 180정
# 칼슘 마그네슘 아연 비타민D 180정
#
# Cluster 110:
# 쾌변엔 차전자피 식이섬유 30포
# 에버핏 쾌변엔 차전자피 식이섬유 30포
# 프리미엄 쾌변엔 차전자피 식이섬유 30포
#
# Cluster 111:
# 혈행건강 프로메가 알티지 오메가3 듀얼 30캡슐
# 혈행건강 프로메가 알티지 오메가3 듀얼 60캡슐
# 혈행건강 프로메가 알티지 오메가3 듀얼 비타민D 60캡슐
# 혈행건강 프로메가 알티지 오메가3 듀얼 플러스 60캡슐
#
# Cluster 112:
# 루테인 지아잔틴 아스타잔틴 30캡슐
# 루테인 지아잔틴 아스타잔틴 500mg 30캡슐
# 하이뮨 루테인 지아잔틴 아스타잔틴 500mg 30캡슐
#
# Cluster 113:
# 아르기닌 6000 15포
# 아르기닌 6000 맥스 15포
# 맥스 파워 아르기닌 6000 15포
#
# Cluster 114:
# 칼슘 마그네슘 아연 비타민D 90정
# 칼슘 마그네슘 아연 비타민D 맥스 90정
# 프리미엄 칼슘 마그네슘 아연 비타민D 90정
# 칼슘 마그네슘 아연 플러스 비타민D 90정
# 칼슘 마그네슘 아연 앤 비타민D 밸런스 90정
#
# Cluster 115:
# 루테인 지아잔틴 오메가3 30캡슐
# 루테인 지아잔틴 30캡슐
# 리얼 루테인 지아잔틴 30캡슐
#
# Cluster 116:
# 산소계표백제 유한젠
# 유한젠 산소계표백제
# 유한젠 산소계표백제 리필
#
# Cluster 117:
# 유한젠 산소계표백제 액체형
# 유한젠 산소계표백제 액체형 리필
# 유한젠 스포츠 산소계표백제 액체형
#
# Cluster 118:
# 듀오락 데일리 키즈 프로바이오틱스 60정
# 듀오락 데일리 키즈 프로바이오틱스 딸기맛 60정
# 듀오락 데일리 키즈 플러스 프로바이오틱스 60정
#
# Cluster 119:
# BYO바이오 CORE 건강한 생 유산균 30캡슐
# BYO바이오 CORE 건강한 생 유산균 30포
# BYO바이오 CORE 건강한 생 유산균 60캡슐
# BYO바이오 CORE 건강한 생 유산균 키즈 30포
#
# Cluster 120:
# 프리미엄 원목 옷걸이
# 프리미엄 원목 옷걸이 M
# 프리미엄 원목 옷걸이 M 블랙
# 프리미엄 원목 옷걸이 블랙
#
# Cluster 121:
# 롯데햄 의성마늘 프랑크
# 롯데햄 의성마늘 프랑크 빅 소시지
# 롯데햄 의성마늘 프랑크 소시지 2개입
#
# Cluster 122:
# 몽쉘 생크림케이크 6개입
# 몽쉘 오리지널 생크림케이크
# 몽쉘 오리지널 생크림케이크 12개입
# 몽쉘 오리지널 생크림케이크 6개입
# 몽쉘 카카오 생크림케이크 6개입
#
# Cluster 123:
# 정관장 홍삼정 에브리타임 10ml 30포
# 정관장 홍삼정 에브리타임 로얄 10ml 30포
# 정관장 홍삼정 에브리타임 리미티드 10ml 30포
# 정관장 홍삼정 에브리타임 밸런스 10ml 30포
#
# Cluster 124:
# 보스웰리아 60정
# 보스웰리아 플러스 60정
# 보스웰리아 프리미엄 60정
# 프리미엄 보스웰리아 60정
#
# Cluster 125:
# 정원삼 6년근 고려홍삼정 365 스틱 건 10g 30포
# 정원삼 6년근 고려홍삼정 365 스틱 궁 10g 30포
# 정원삼 6년근 고려홍삼정 365 스틱 황 10g 30포
#
# Cluster 126:
# 정원삼 6년근 고려홍삼정 365스틱  100포
# 정원삼 6년근 고려홍삼정 365스틱 10g 100포
# 정원삼 6년근 고려홍삼정 365스틱 10g 30포
# 정원삼 6년근 고려홍삼정 365스틱 원  100포
# 정원삼 6년근 고려홍삼정 365스틱 원 10g 100포
# 정원삼 6년근 고려홍삼정 365스틱 진 10g 30포
# 정원삼 6년근 고려홍삼정 365스틱 키즈  100포
# 정원삼 6년근 고려홍삼정 365스틱 키즈 10ml 100포
# 정원삼 6년근 고려홍삼정 365스틱 키즈 10ml 30포
#
# Cluster 127:
# 튼튼쑥쑥 키즈홍삼스틱 망고맛  100포
# 튼튼쑥쑥 키즈홍삼스틱 망고맛 10ml 100포
# 튼튼쑥쑥 키즈홍삼스틱 망고맛 10ml 30포
#
# Cluster 128:
# 키즈 멀티비타민 미네랄 60정
# 남성 멀티비타민 미네랄 60정
# 멀티비타민 앤 미네랄 60정
#
# Cluster 129:
# 6년근 고려홍삼정 골드녹용 스틱  100포
# 6년근 고려홍삼정 골드녹용 스틱 12g 100포
# 6년근 고려홍삼정 골드녹용 스틱 12g 30포
#
# Cluster 130:
# 6년근 고려홍삼정 골드영지 농축액 스틱  100포
# 6년근 고려홍삼정 골드영지 농축액 스틱 12g 100포
# 6년근 고려홍삼정 골드영지 농축액 스틱 12g 30포
#
# Cluster 131:
# 6년근 고려홍삼정 전체식 스틱  100포
# 6년근 고려홍삼정 전체식 스틱 12g 100포
# 6년근 고려홍삼정 전체식 스틱 12g 30포
#
# Cluster 132:
# 진삼명가 6년근 홍삼정 베이직 스틱  100포
# 진삼명가 6년근 홍삼정 베이직 스틱 10g 100포
# 진삼명가 6년근 홍삼정 베이직 스틱 10g 30포
# 진삼명가 6년근 홍삼정 오리진 스틱  100포
# 진삼명가 6년근 홍삼정 오리진 스틱 10g 100포
#
# Cluster 133:
# 비움 디럭스 KF94 대형 25개입
# 비움 디럭스 KF94 대형 그레이 25개입
# 비움 디럭스 KF94 대형 블랙 25개입
# 비움 디럭스 KF94 대형 아이보리 25개입
#
# Cluster 134:
# 비움 디럭스 KF94 대형 핑크베이지 25개입
# 비움 디럭스 KF94 소형 핑크베이지 25개입
# 비움 디럭스 KF94 중형 핑크베이지 25개입
#
# Cluster 135:
# 비움 디럭스 KF94 소형 25개입
# 비움 디럭스 KF94 소형 블랙 25개입
# 비움 디럭스 KF94 소형 아이보리 25개입
#
# Cluster 136:
# 비움 디럭스 KF94 중형 25개입
# 비움 디럭스 KF94 중형 그레이 25개입
# 비움 디럭스 KF94 중형 블랙 25개입
# 비움 디럭스 KF94 중형 아이보리 25개입
#
# Cluster 137:
# 비움 라이트핏 KF94 대형 25개입
# 비움 라이트핏 KF94 대형 베이지 25개입
# 비움 라이트핏 KF94 대형 블랙 25개입
# 비움 라이트핏 KF94 대형 코랄 25개입
#
# Cluster 138:
# 비움 에코 브리즈 KF94 대형 25개입
# 비움 에코 브리즈 KF94 대형 그레이 25개입
# 비움 에코 브리즈 KF94 대형 베이지 25개입
# 비움 에코 브리즈 KF94 대형 블랙 25개입
# 비움 에코 브리즈 KF94 대형 핑크 25개입
# 비움 에코 브리즈 KF94 중형 25개입
# 비움 에코 브리즈 KF94 중형 그레이 25개입
# 비움 에코 브리즈 KF94 중형 베이지 25개입
# 비움 에코 브리즈 KF94 중형 블랙 25개입
# 비움 에코 브리즈 KF94 중형 핑크 25개입
#
# Cluster 139:
# 비움 에코 프로 KF94 대형 25개입
# 비움 에코 프로 KF94 대형 블랙 25개입
# 비움 에코 플러스 KF94 대형 25개입
# 비움 에코 플러스 KF94 대형 블랙 25개입
#
# Cluster 140:
# 뉴케어 구수한맛
# 뉴케어 구수한맛 미니
# 뉴케어 구수한맛 순
# 뉴케어 구수한맛 클래식
# 뉴케어 구수한맛 플러스
#
# Cluster 141:
# 하이뮨 프로틴 밸런스 액티브
# 하이뮨 프로틴 밸런스 액티브 바 6개입
# 하이뮨 프로틴 밸런스 액티브 초코
# 하이뮨 프로틴 밸런스 액티브 커피
# 하이뮨 프로틴 밸런스 프로 액티브
#
# Cluster 142:
# 고기리 들기름 막국수
# 고기리 들기름 막국수 4인분
# 오뚜기 고기리 들기름 막국수 4인분육수2개오뚜기 고기리 들기름 막국수 육수
#
# Cluster 143:
# 맛있는 오뚜기 컵밥 진한 쇠고기 미역국밥
# 맛있는 컵밥 진한 쇠고기 미역국밥
# 컵밥 진한 쇠고기 미역국밥
#
# Cluster 144:
# 순후추 라면 사골곰탕맛
# 순후추 라면 사골곰탕맛 큰컵
# 순후추 사골곰탕맛 큰컵
#
# Cluster 145:
# 옛날 구수한 끓여먹는 누룽지
# 옛날 구수한 끓여먹는 보리 누룽지
# 옛날 구수한 끓여먹는 누룽지 국산 3kg
#
# Cluster 146:
# 오쉐프 렌지에 돌려먹는 순살 고등어구이
# 오뚜기 렌지에 돌려먹는 순살 고등어구이 60g x 15개
# 오쉐프 렌지에 돌려먹는 순살 고등어구이 60g x 20개
# 오쉐프 렌지에 돌려먹는 순살 고등어구이 60g x 15개
# 오뚜기 오쉐프 렌지에 돌려먹는 순살 고등어구이 60g x 20개
#
# Cluster 147:
# 진라면 매운맛
# 진라면 매운맛 컵
# 진라면 플러스 매운맛
#
# Cluster 148:
# 진라면 순한맛
# 진라면 순한맛 컵
# 진라면 플러스 순한맛
#
# Cluster 149:
# 폰타나 볼로냐 베이컨 볼로네제
# 폰타나 볼로냐 베이컨 볼로네제 파스타소스
# 볼로냐 베이컨 볼로네제 파스타소스
#
# Cluster 150:
# 본죽 미니 본 버터 쇠고기 장조림
# 본죽 본 쇠고기 장조림 미니
# 본죽 쇠고기 장조림
#
# Cluster 151:
# Think your dog teeth 오리우유껌 대 240g 3P
# Think your dog teeth 오리우유껌 소 240g 15P
# Think your dog teeth 오리우유껌 중 240g 6P
#
# Cluster 152:
# 슈퍼츄 일킬로그램 가득 담은 강아지 육포 닭가슴살 고구마
# 슈퍼츄 일킬로그램 가득 담은 강아지 육포 오리가슴살
# 슈퍼츄 일킬로그램 가득 담은 강아지 육포 오리가슴살 고구마
#
# Cluster 153:
# 아미오 건강한 덴탈껌
# 아미오 건강한 덴탈껌 그린
# 아미오 건강한 덴탈껌 레드
#
# Cluster 154:
# 3단 접이식 마약 토퍼 매트리스 MS
# 3단 접이식 마약 토퍼 매트리스 Q
# 3단 접이식 마약 토퍼 매트리스 SS
#
# Cluster 155:
# 베이직 마약 토퍼 매트리스 MS
# 베이직 마약 토퍼 매트리스 Q
# 베이직 마약 토퍼 매트리스 SS
#
# Cluster 156:
# HR고탄성폼 3단 접이식 토퍼 매트리스 MS
# HR고탄성폼 3단 접이식 토퍼 매트리스 Q
# HR고탄성폼 3단 접이식 토퍼 매트리스 SS
#
# Cluster 157:
# 착붙 천연라텍스 미디엄 토퍼 매트리스 K
# 착붙 천연라텍스 미디엄 토퍼 매트리스 LK
# 착붙 천연라텍스 미디엄 토퍼 매트리스 MS
# 착붙 천연라텍스 미디엄 토퍼 매트리스 Q
# 착붙 천연라텍스 미디엄 토퍼 매트리스 S
# 착붙 천연라텍스 미디엄 토퍼 매트리스 SS
# 천연라텍스 미디엄 토퍼 매트리스 K
# 천연라텍스 미디엄 토퍼 매트리스 LK
# 천연라텍스 미디엄 토퍼 매트리스 MS
# 천연라텍스 미디엄 토퍼 매트리스 Q
# 천연라텍스 미디엄 토퍼 매트리스 S
# 천연라텍스 미디엄 토퍼 매트리스 SS
#
# Cluster 158:
# 착붙 천연라텍스 소프트 토퍼 매트리스 K
# 착붙 천연라텍스 소프트 토퍼 매트리스 MS
# 착붙 천연라텍스 소프트 토퍼 매트리스 Q
# 착붙 천연라텍스 소프트 토퍼 매트리스 S
# 착붙 천연라텍스 소프트 토퍼 매트리스 SS
#
# Cluster 159:
# 착붙 천연라텍스 하드 토퍼 매트리스 K
# 착붙 천연라텍스 하드 토퍼 매트리스 LK
# 착붙 천연라텍스 하드 토퍼 매트리스 MS
# 착붙 천연라텍스 하드 토퍼 매트리스 Q
# 착붙 천연라텍스 하드 토퍼 매트리스 S
# 착붙 천연라텍스 하드 토퍼 매트리스 SS
# 천연라텍스 하드 토퍼 매트리스 LK
#
# Cluster 160:
# 천연라텍스 3단 접이식 미디엄 매트리스 MS
# 천연라텍스 3단 접이식 미디엄 매트리스 Q
# 천연라텍스 3단 접이식 미디엄 매트리스 SS
#
# Cluster 161:
# 천연라텍스 3단 접이식 소프트 매트리스 MS
# 천연라텍스 3단 접이식 소프트 매트리스 Q
# 천연라텍스 3단 접이식 소프트 매트리스 SS
#
# Cluster 162:
# 천연라텍스 3단 접이식 하드 매트리스 MS
# 천연라텍스 3단 접이식 하드 매트리스 Q
# 천연라텍스 3단 접이식 하드 매트리스 SS
#
# Cluster 163:
# 천연라텍스 소프트 토퍼 매트리스 K
# 천연라텍스 소프트 토퍼 매트리스 MS
# 천연라텍스 소프트 토퍼 매트리스 Q
# 천연라텍스 소프트 토퍼 매트리스 S
# 천연라텍스 소프트 토퍼 매트리스 SS
#
# Cluster 164:
# 천연라텍스 하드 토퍼 매트리스 K
# 천연라텍스 하드 토퍼 매트리스 MS
# 천연라텍스 하드 토퍼 매트리스 Q
# 천연라텍스 하드 토퍼 매트리스 S
# 천연라텍스 하드 토퍼 매트리스 SS
#
# Cluster 165:
# 내추럴슬립 접이식 천연라텍스 매트리스 Q
# 내추럴슬립 접이식 천연라텍스 매트리스 SS
# 내추럴슬립 천연라텍스 매트리스 K
# 내추럴슬립 천연라텍스 매트리스 Q
# 내추럴슬립 천연라텍스 매트리스 S
# 내추럴슬립 천연라텍스 매트리스 SS
#
# Cluster 166:
# 느웰 3모드 미디움 천연라텍스 토퍼 매트리스 K
# 느웰 3모드 미디움 천연라텍스 토퍼 매트리스 Q
# 느웰 3모드 미디움 천연라텍스 토퍼 매트리스 SS
#
# Cluster 167:
# 느웰 3모드 미디움하드 천연라텍스 토퍼 매트리스 K
# 느웰 3모드 미디움하드 천연라텍스 토퍼 매트리스 Q
# 느웰 3모드 미디움하드 천연라텍스 토퍼 매트리스 SS
#
# Cluster 168:
# 느웰 3모드 하드 천연라텍스 매트리스 K
# 느웰 3모드 하드 천연라텍스 매트리스 Q
# 느웰 3모드 하드 천연라텍스 매트리스 SS
#
# Cluster 169:
# 느웰 가든 천연라텍스 토퍼 매트리스 K
# 느웰 가든 천연라텍스 토퍼 매트리스 Q
# 느웰 가든 천연라텍스 토퍼 매트리스 SS
#
# Cluster 170:
# 느웰 루디아 천연라텍스 토퍼 매트리스 K
# 느웰 루디아 천연라텍스 토퍼 매트리스 Q
# 느웰 루디아 천연라텍스 토퍼 매트리스 SS
#
# Cluster 171:
# 느웰 미디움하드 천연라텍스 매트리스 K
# 느웰 미디움하드 천연라텍스 매트리스 Q
# 느웰 미디움하드 천연라텍스 매트리스 SS
#
# Cluster 172:
# 느웰 솔리드 천연라텍스 토퍼 매트리스 K
# 느웰 솔리드 천연라텍스 토퍼 매트리스 Q
# 느웰 솔리드 천연라텍스 토퍼 매트리스 S
# 느웰 솔리드 천연라텍스 토퍼 매트리스 SS
#
# Cluster 173:
# 느웰 오가닉 천연라텍스 토퍼 매트리스 K
# 느웰 오가닉 천연라텍스 토퍼 매트리스 Q
# 느웰 오가닉 천연라텍스 토퍼 매트리스 SS
#
# Cluster 174:
# 느웰 지제 천연라텍스 토퍼 매트리스 K
# 느웰 지제 천연라텍스 토퍼 매트리스 Q
# 느웰 지제 천연라텍스 토퍼 매트리스 SS
#
# Cluster 175:
# 느웰 클래식 천연라텍스 토퍼 매트리스 K
# 느웰 클래식 천연라텍스 토퍼 매트리스 Q
# 느웰 클래식 천연라텍스 토퍼 매트리스 SS
#
# Cluster 176:
# 느웰 템포 천연라텍스 토퍼 매트리스 K
# 느웰 템포 천연라텍스 토퍼 매트리스 Q
# 느웰 템포 천연라텍스 토퍼 매트리스 SS
#
# Cluster 177:
# 리엔아 110kg 고밀도 천연라텍스 매트리스 D
# 리엔아 110kg 고밀도 천연라텍스 매트리스 Q
# 리엔아 110kg 고밀도 천연라텍스 매트리스 S
# 리엔아 110kg 고밀도 천연라텍스 매트리스 SS
#
# Cluster 178:
# 클라우드 천연 라텍스 토퍼 매트리스 K
# 클라우드 천연 라텍스 토퍼 매트리스 Q
# 클라우드 천연 라텍스 토퍼 매트리스 SS
#
# Cluster 179:
# 킵에잇 천연라텍스 매트리스 K
# 킵에잇 천연라텍스 매트리스 Q
# 킵에잇 천연라텍스 매트리스 S
# 킵에잇 천연라텍스 매트리스 SS
#
# Cluster 180:
# 024홈 스트롱 3단 접이식 매트리스 MS
# 024홈 스트롱 3단 접이식 매트리스 Q
# 024홈 스트롱 3단 접이식 매트리스 SS
#
# Cluster 181:
# 리브맘 12존 폴딩 에어 토퍼 매트리스 MS
# 리브맘 12존 폴딩 에어 토퍼 매트리스 Q
# 리브맘 12존 폴딩 에어 토퍼 매트리스 SS
#
# Cluster 182:
# 리브맘 3단 접이식 무중력 메모리폼 롤팩 매트리스 Q
# 리브맘 3단 접이식 무중력 메모리폼 롤팩 매트리스 S
# 리브맘 무중력 롤팩 메모리폼 매트리스 Q
# 리브맘 무중력 롤팩 메모리폼 매트리스 S
# 리브맘 무중력 삼중직 롤팩 메모리폼 매트리스 Q
# 리브맘 무중력 삼중직 롤팩 메모리폼 매트리스 S
#
# Cluster 183:
# 리브맘 메모리폼 달콤매트리스 오가닉 토퍼 K
# 리브맘 메모리폼 달콤매트리스 오가닉 토퍼 Q
# 리브맘 메모리폼 달콤매트리스 오가닉 토퍼 S
#
# Cluster 184:
# 리브맘 베이직 에어 토퍼 매트리스 MS
# 리브맘 베이직 에어 토퍼 매트리스 Q
# 리브맘 베이직 에어 토퍼 매트리스 SS
#
# Cluster 185:
# 리브맘 세븐존 데일리 매트리스 MS
# 리브맘 세븐존 데일리 매트리스 Q
# 리브맘 세븐존 데일리 매트리스 SS
# 리브맘 세븐존 프리미엄 매트리스 Q
# 리브맘 세븐존 프리미엄 매트리스 SS
#
# Cluster 186:
# 리브맘 세븐존 스퀘어 누빔 매트리스 MS
# 리브맘 세븐존 스퀘어 누빔 매트리스 Q
# 리브맘 세븐존 스퀘어 누빔 매트리스 SS
#
# Cluster 187:
# 리브맘 세븐존 퀼팅누빔 매트리스 MS
# 리브맘 세븐존 퀼팅누빔 매트리스 Q
# 리브맘 세븐존 퀼팅누빔 매트리스 SS
#
# Cluster 188:
# 포근한 연화 3단 접이식 토퍼 매트리스 MS
# 포근한 연화 3단 접이식 토퍼 매트리스 Q
# 포근한 연화 3단 접이식 토퍼 매트리스 SS
#
# Cluster 189:
# 포근한 연화 베이직 토퍼 매트리스 MS
# 포근한 연화 베이직 토퍼 매트리스 Q
# 포근한 연화 베이직 토퍼 매트리스 SS
#
# Cluster 190:
# 라움 말레이시아 3단 접이식 천연라텍스 매트리스 Q
# 라움 말레이시아 3단 접이식 천연라텍스 매트리스 SS
# 라움 말레이시아 천연라텍스 매트리스 K
# 라움 말레이시아 천연라텍스 매트리스 Q
# 라움 말레이시아 천연라텍스 매트리스 S
# 라움 말레이시아 천연라텍스 매트리스 SS
#
# Cluster 191:
# 리엔아 프리미엄 고밀도 천연 라텍스 매트리스 K
# 리엔아 프리미엄 고밀도 천연 라텍스 매트리스 Q
# 리엔아 프리미엄 고밀도 천연 라텍스 매트리스 SS
#
# Cluster 192:
# 미디움 천연 라텍스 3단 접이식 토퍼 Q
# 미디움 천연 라텍스 3단 접이식 토퍼 S
# 미디움 천연 라텍스 3단 접이식 토퍼 SS
#
# Cluster 193:
# 소프트 천연 라텍스 토퍼 매트리스 K
# 소프트 천연 라텍스 토퍼 매트리스 Q
# 소프트 천연 라텍스 토퍼 매트리스 S
# 소프트 천연 라텍스 토퍼 매트리스 SS
#
# Cluster 194:
# 스마트슬립 천연라텍스 매트리스 Q
# 스마트슬립 천연라텍스 매트리스 S
# 스마트슬립 천연라텍스 매트리스 SS
#
# Cluster 195:
# 아이소페 라텍스 접이식 매트리스 MS
# 아이소페 라텍스 접이식 매트리스 Q
# 아이소페 라텍스 접이식 매트리스 SS
#
# Cluster 196:
# 이즈 카이 수납 C형 LED침대 Q
# 이즈 카이 수납 C형 LED침대 SS
# 이즈 카이 수납 LED침대 SS
#
# Cluster 197:
# 힐링 히노끼 편백나무 수납헤드 평상형 침대 Q
# 힐링 히노끼 편백나무 수납헤드 평상형 침대 SS
# 힐링 히노끼 편백나무 평상형 침대 SS
#
# Cluster 198:
# 로미홈 9존 마약매트리스 MS
# 로미홈 9존 마약매트리스 Q
# 로미홈 9존 마약매트리스 SS
#
# Cluster 199:
# 2레이어 3단 접이식 침대형 토퍼 매트리스 MS
# 2레이어 3단 접이식 침대형 토퍼 매트리스 Q
# 2레이어 3단 접이식 침대형 토퍼 매트리스 SS
#
# Cluster 200:
# 9존 마약 매트리스 MS
# 9존 마약 매트리스 Q
# 9존 마약 매트리스 SS
#
# Cluster 201:
# 오가닉 2레이어 3단 접이식 메모리폼 토퍼 매트리스 MS
# 오가닉 2레이어 3단 접이식 메모리폼 토퍼 매트리스 Q
# 오가닉 2레이어 3단 접이식 메모리폼 토퍼 매트리스 SS
#
# Cluster 202:
# 투슬리핑 7존 기절 마약 매트리스 MS
# 투슬리핑 7존 기절 마약 매트리스 Q
# 투슬리핑 7존 기절 마약 매트리스 SS
#
# Cluster 203:
# 라네즈 립 슬리핑 마스크
# 라네즈 립 슬리핑 마스크 EX
# 라네즈 시카 슬리핑 마스크
# 라네즈 워터 슬리핑 마스크
# 라네즈 워터 슬리핑 마스크 EX
#
# Cluster 204:
# 메디안 덴탈IQ 치석케어 86 맥스 치약
# 메디안 덴탈IQ 치석케어 86 오리지널 치약
# 메디안 덴탈IQ 치석케어 86 화이트 치약
#
# Cluster 205:
# 미쟝센 살롱 플러스 클리닉 10 손상모발용 샴푸
# 미쟝센 살롱 플러스 클리닉 10 에센스 팩 손상모발용
# 미쟝센 손상모발용 살롱 플러스 클리닉 10 트리트먼트
#
# Cluster 206:
# 설화수 NEW 퍼펙팅 쿠션
# 설화수 퍼펙팅 쿠션
# 설화수 퍼펙팅 쿠션 EX
#
# Cluster 207:
# 에스트라 2세대 아토베리어 365 로션
# 에스트라 2세대 아토베리어 365 크림
# 에스트라 아토베리어 365 크림
#
# Cluster 208:
# 이니스프리 NEW 그린티 아미노 수분 클렌징 폼
# 이니스프리 그린티 수분 아미노 클렌징 워터
# 이니스프리 그린티 수분 아미노 클렌징 폼
# 이니스프리 그린티 아미노 수분 클렌징 워터
#
# Cluster 209:
# 이니스프리 NEW 화산송이 모공 바하 클렌징 폼
# 이니스프리 화산송이 모공 바하 클렌징 폼
# 이니스프리 화산송이 모공 바하 클렌징 폼 150g 3개
# 이니스프리 화산송이 모공 바하 클렌징 폼 150g 3개 16580원  무료
# 화산송이 모공 바하 클렌징 폼 150G 111
# 이니스프리 화산송이 모공 바하 클렌징 폼 150g 2개
# 이니스프리 화산송이 모공 바하 클렌징 폼 150g 2개 10790무배
# 화산송이 모공 바하 클렌징 폼 150g 2개
# 이니스프리 화산송이 모공 바하 클렌징 폼 150g 2개 10400원무배
#
# Cluster 210:
# 해피바스 PH45 로즈 버블 여성청결제
# 해피바스 PH45 로즈 젤 여성청결제
# 해피바스 PH45 쑥 버블 여성청결제
# 해피바스 PH45 쑥 젤 여성청결제
# 해피바스 PH45 약산성 쑥 버블 여성청결제
#
# Cluster 211:
# 리츠 치즈 샌드위치 크래커
# 카누 리츠 치즈 샌드위치 크래커
# 리츠 샌드위치 크래커 레몬 2개입
# 리츠 샌드위치 크래커 초코 2개입
# 리츠 샌드위치 크래커 치즈 2개입
# 리츠 샌드위치 크래커 화이트 2개입
#
# Cluster 212:
# 맥심 모카골드 마일드 커피믹스 400T
# 맥심 모카골드 400T
# 맥심 모카골드 커피믹스 400T
# 맥심 모카골드 마일드 커피믹스 스틱 400T
# 맥심 모카골드 마일드 커피믹스 400T
#
# Cluster 213:
# 맥심 화이트골드 커피믹스 400T
# 맥심 화이트골드 400T 역대가
# 맥심 화이트골드 커피믹스 400T
# 맥심 화이트골드 400T
#
# Cluster 214:
# 오레오 웨하스 스틱 초코
# 오레오 웨하스 초코
# 오레오 웨하스 스틱 초코 10개입
# 오레오 웨하스 스틱 초코 5개입
#
# Cluster 215:
# 포스트 오곡 코코볼바
# 포스트 오곡 코코볼바 10개입
# 포스트 오곡 코코볼바 4개입
#
# Cluster 216:
# 오가닉 레드비트배토마토
# 오가닉 유기농 레드비트배토마토
# 오가닉 유기농 주스 레드비트배토마토
#
# Cluster 217:
# 국내산 율무
# 율무 국내산
# 율무
#
# Cluster 218:
# 보약같은 신동진쌀 10kg 23년 햅쌀
# 보약같은 신동진쌀 3kg 23년 햅쌀
# 보약같은 신동진쌀 5kg 23년 햅쌀
#
# Cluster 219:
# 사조 살코기 안심따개
# 사조 살코기 참치 안심따개
# 사조 살코기 플러스 안심따개
#
# Cluster 220:
# 해표 순창궁 태양초 100 우리햅쌀 고추장
# 해표 순창궁 태양초 우리햅쌀 고추장
# 해표 순창궁 태양초 우리햅쌀 매운 고추장
#
# Cluster 221:
# 잇메이트 닭가슴살 볼 마늘맛
# 잇메이트 닭가슴살 소시지 마늘맛
# 잇메이트 닭가슴살 소시지 미니 마늘맛
# 잇메이트 닭가슴살 스테이크 마늘맛
# 잇메이트 스팀 닭가슴살 마늘맛
#
# Cluster 222:
# 잇메이트 닭가슴살 소시지 프로 훈제맛
# 잇메이트 닭가슴살 소시지 훈제맛
# 잇메이트 닭가슴살 소시지 훈제맛 미니
#
# Cluster 223:
# 닭가슴살 훈제 칠리맛
# 훈제 닭가슴살 칠리맛
# 훈제 닭가슴살 칠리맛 냉장
#
# Cluster 224:
# 훈제 닭가슴살 마늘맛
# 훈제 닭가슴살 마늘맛 냉장
# 닭가슴살 훈제 마늘맛
#
# Cluster 225:
# 냉동 훈제 닭가슴살 훈제맛
# 훈제 닭가슴살 훈제맛
# 훈제 닭가슴살 훈제맛 냉장
#
# Cluster 226:
# 팬시피스트 메들리 파테 프리마베라 닭고기
# 팬시피스트 메들리 파테 프리마베라 연어
# 팬시피스트 메들리 파테 프리마베라 치킨
#
# Cluster 227:
# 기동전사 건담 익스트림 버서스 맥시 부스트 온 PS4
# 기동전사 건담 익스트림 버서스 맥시 부스트 온 한글판
# 기동전사 건담 익스트림 버서스 맥시 부스트 온13262
# 기동전사 건담 익스트림 버서스 맥시 부스트 온
#
# Cluster 228:
# 슈퍼로봇대전 T PS4
# 슈퍼로봇대전 V PS4
# 슈퍼로봇대전 X PS4
#
# Cluster 229:
# 라이스데이 비누 유
# 라이스데이 비누 윤
# 라이스데이 비누 청
#
# Cluster 230:
# 아이깨끗해 레몬 항균 폼 핸드 솝 리필
# 아이깨끗해 순 항균 폼 핸드 솝 리필
# 아이깨끗해 청포도 항균 폼 핸드 솝 리필
#
# Cluster 231:
# 참그린 녹차 뽀드득
# 참그린 녹차 뽀드득 리필
# 참그린 녹차 뽀드득 주방세제
#
# Cluster 232:
# 건조기용 섬유유연제 시트 라벤더향 80매
# 건조기용 시트 섬유유연제 80매
# 건조기용 섬유유연제 시트 80매  80매 11930원무배건조기용 섬유유연제 시트
#
# Cluster 233:
# 비데 물티슈 베이직 캡형 60매
# 비데 물티슈 캡형 60매
# 잘풀리는집 비데 물티슈 캡형 60매
#
# Cluster 234:
# 핸드워시 파우더향
# 핸드워시 파우더향 리필
# 파우더향 핸드워시 리필
#
# Cluster 235:
# 테크 호르몬으로 인한 특유취 제거
# 테크 호르몬으로 인한 특유취 제거 라벤더 30매
# 테크 호르몬으로 인한 특유취 제거 프레쉬 30매
#
# Cluster 236:
# 테크 호르몬으로 인한 특유취 제거 스파클링 프레쉬 드럼용
# 테크 호르몬으로 인한 특유취 제거 스파클링 프레쉬 일반용
# 테크 호르몬으로 인한 특유취 제거 스파클링 프레시 드럼용
# 테크 호르몬으로 인한 특유취 제거 스파클링 프레시 일반용
#
# Cluster 237:
# 홈스타 뿌리는 곰팡이싹
# 홈스타 뿌리는 곰팡이싹 리필
# 홈스타 뿌리는 곰팡이싹 500ml x 4개
#
# Cluster 238:
# 닌텐도 스위치 OLED
# 닌텐도 스위치 OLED
# 닌텐도 스위치 oled 화이트
# 닌텐도 스위치 oled
#
# Cluster 239:
# 바로사용OK 게이밍 i5 14 RTX4060
# 바로사용OK 게이밍 i5 14 RTX4060 Ti
# 바로사용OK 게이밍 i5 RTX4060
#
# Cluster 240:
# 존쿡 델리미트 킬바사
# 존쿡 델리미트 킬바사 부대찌개
# 존쿡 델리미트 킬바사 치즈
#
# Cluster 241:
# 에버콜라겐 타임 30포
# 에버콜라겐 타임 비오틴 30포
# 에버콜라겐 타임 비오틴 셀 30포
#
# Cluster 242:
# EL 삼파장 형광등 전구색
# EL 절전형 삼파장 형광등 전구색
# 장수램프 EL 삼파장 형광등 전구색
# 장수램프 EL 형광등 전구색
#
# Cluster 243:
# EL 삼파장 형광등 주광색
# 번개표 EL 삼파장 형광등 주광색
# 장수램프 EL 삼파장 형광등 주광색
# 장수램프 EL 형광등 주광색
#
# Cluster 244:
# LED PAR30 집중형 할로겐전구 전구색
# 장수램프 LED PAR30 집중형 할로겐전구 전구색
# LED PAR30 집중형 에코 할로겐전구 전구색
#
# Cluster 245:
# LED PAR30 집중형 할로겐전구 주광색
# 장수램프 LED PAR30 집중형 할로겐전구 주광색
# LED PAR30 집중형 에코 할로겐전구 주광색
#
# Cluster 246:
# LED PAR30 확산형 할로겐전구 전구색
# 장수램프 LED PAR30 확산형 할로겐전구 전구색
# LED PAR30 확산형 에코 할로겐전구 전구색
#
# Cluster 247:
# LED PAR30 확산형 할로겐전구 주광색
# 장수램프 LED PAR30 확산형 할로겐전구 주광색
# LED PAR30 확산형 에코 할로겐전구 주광색
#
# Cluster 248:
# 세븐펫 도톰카페트 50x50cm 레드
# 세븐펫 도톰카페트 50x50cm 옐로우
# 세븐펫 도톰카페트 50x50cm 크림
#
# Cluster 249:
# 랩 샴푸
# 쿨 샴푸
# 폼 샴푸 포 뉴 본
# 샴푸
# 발 샴푸
#
# Cluster 250:
# 랩 트리트먼트
# 트리트먼트
# 트리트먼트
#
# Cluster 251:
# 투펫 닭고기 올라이프
# 투펫 램 올라이프
# 투펫 캣 올라이프
#
# Cluster 252:
# 구 녹두 약산성 클렌징 워터 티슈 20매
# 녹두 약산성 클렌징 워터 티슈 20매
# 녹두 약산성 클렌징 티슈 20매
#
# Cluster 253:
# 마이산 정기담은 메추리알 장조림
# 마이산 정기담은 메추리알 장조림 1kg1kg마이산 정기담은 메추리알 장조림
# 마이산 정기담은 메추리알 장조림 2kg
# 마이산 정기담은 메추리알 장조림 1kg1kg 10010무료마이산 정기담은 메추리알 장조림
#
# Cluster 254:
# 퍼실 딥클린 4in1 디스크 라벤더 캡슐세제 파우치 38개입
# 퍼실 딥클린 4in1 디스크 컬러 캡슐세제 파우치 38개입
# 퍼실 디스크 4in1 딥클린 캡슐세제 라벤더 38개입 2개  31900원  무료 배송 퍼실 디스크 4in1 딥클린 캡슐세제 라벤더
#
# Cluster 255:
# 퍼실 딥클린 파워젤 라벤더 일반용
# 퍼실 딥클린 파워젤 일반용
# 퍼실 딥클린 파워젤 일반용 리필
# 퍼실 딥클린 파워젤 일반용 리필 15L
#
# Cluster 256:
# 딜라잇가든 냉동 블루베리
# 딜라잇가든 유기농 냉동 블루베리
# 딜라잇가든 유기농 냉동 아이스 블루베리
#
# Cluster 257:
# 복숭아 아이스티
# 복숭아 아이스티 제로
# 제로 복숭아 아이스티
#
# Cluster 258:
# 딸기 미니 웨하스
# 딸기 웨하스
# 미니 웨하스 딸기
#
# Cluster 259:
# 까르보 불닭볶음면
# 까르보 불닭볶음면 컵
# 크림 까르보 불닭볶음면
#
# Cluster 260:
# AOP 무염 버터
# AOP 무염 버터 스틱
# AOP 미니 무염 버터
#
# Cluster 261:
# 2080 파워쉴드 골드 스피아민트 치약
# 2080 파워쉴드 치약 골드 스피아민트
# 2080 파워쉴드 플러스 치약 골드 스피아민트
#
# Cluster 262:
# 리큐 진한겔 드럼용
# 리큐 진한겔 하이브리드 드럼용
# 리큐 진한겔 하이브리드 실내건조 드럼용
#
# Cluster 263:
# 샤워메이트 말랑이 버블 핸드워시 딸기우유향
# 샤워메이트 말랑이 버블 핸드워시 딸기우유향 리필
# 샤워메이트 말랑카우 말랑이 버블 핸드워시 딸기우유향
#
# Cluster 264:
# 케라시스 엑스트라 데미지 린스
# 케라시스 엑스트라 데미지 케어 린스
# 케라시스 엑스트라 데미지 케어 린스 리필
#
# Cluster 265:
# 립톤 아이스티 믹스 복숭아맛
# 립톤 아이스티 믹스 복숭아맛 20T
# 립톤 아이스티 복숭아맛
# 립톤 아이스티 분말 복숭아맛
#
# Cluster 266:
# 바세린 인텐시브 케어 헬씨 핸드 앤 스트롱거 네일
# 바세린 인텐시브 케어 헬씨 핸드 앤 스트롱거 네일 로션
# 바세린 헬씨 핸드 앤 스트롱거 네일 로션
# 바세린 인텐시브 케어 헬씨 핸드 앤 스트롱거 네일 로션 120ml 2개 2900원무료
# 바세린 인텐시브 케어 헬씨 핸드 앤 스트롱거 네일 로션 120ml 2개
#
# Cluster 267:
# 티즐 스파클링 제로 피치 우롱티
# 티즐 제로 피치 우롱티
# 티즐 피치 우롱티
#
# Cluster 268:
# 갸스비 슈퍼 하드 스타일링 젤
# 갸스비 슈퍼 하드 스타일링 젤 핸디형
# 갸스비 슈퍼 하드 스타일링 폼
#
# Cluster 269:
# 2024 iPad Air 11 M2 Cellular
# 2024 iPad Air 13 M2
# 2024 iPad Air 13 M2 Cellular
#
# Cluster 270:
# 2024 iPad Pro 11 M4 Cellular
# 2024 iPad Pro 13 M4
# 2024 iPad Pro 13 M4 Cellular
#
# Cluster 271:
# 2024 맥북에어13 M3 8Core 10GPU 골드
# 2024 맥북에어13 M3 8Core 10GPU 그레이
# 2024 맥북에어13 M3 8Core 10GPU 블루
#
# Cluster 272:
# 2024 맥북에어15 M3 8Core 10GPU 골드
# 2024 맥북에어15 M3 8Core 10GPU 그레이
# 2024 맥북에어15 M3 8Core 10GPU 블루
# 2024 맥북에어15 M3 8Core 10GPU 실버
#
# Cluster 273:
# 아이폰14 128GB 자급제
# 아이폰14 프로 128GB 자급제
# 아이폰14 프로 맥스 128GB 자급제
# 아이폰14 플러스 128GB 자급제
#
# Cluster 274:
# 아이폰15 128GB 자급제
# 아이폰15 프로 128GB 자급제
# 아이폰15 플러스 128GB 자급제
#
# Cluster 275:
# 아이폰15 256GB 자급제
# 아이폰15 프로 256GB 자급제
# 아이폰15 프로 맥스 256GB 자급제
# 아이폰15 플러스 256GB 자급제
#
# Cluster 276:
# 센카 올 클리어 더블 워시
# 센카 올 클리어 더블 워시 구
# 센카 올 클리어 더블 워시 폼
#
# Cluster 277:
# 깐은행 대
# 깐은행 중
# 깐은행 특
#
# Cluster 278:
# 세척 꿀고구마 대
# 세척 꿀고구마 중
# 세척 꿀고구마 특
#
# Cluster 279:
# LEGION 5 Pro 16ACH R7 STORM
# LEGION 5 Pro 16ACH R7 STORM 3070
# LEGION 5 Pro 16ACH R7 STORM 3070 W11P
#
# Cluster 280:
# 아이디어패드 Slim115ALC R3
# 아이디어패드 Slim115ALC R3 16GB램
# 아이디어패드 Slim115ALC R3 WIN11 16GB램
#
# Cluster 281:
# 아이디어패드 Slim115ALC R5
# 아이디어패드 Slim115ALC R5 16GB램
# 아이디어패드 Slim115ALC R5 WIN10
# 아이디어패드 Slim115ALC R5 WIN10 16GB램
# 아이디어패드 Slim115ALC R5 WIN11
# 아이디어패드 Slim115ALC R5 WIN11 16GB램
#
# Cluster 282:
# 아이디어패드 Slim3 15IAH8 83ER005YKR
# 아이디어패드 Slim3 15IAH8 83ER005YKR WIN10
# 아이디어패드 Slim3 15IAH8 83ER005YKR WIN11
#
# Cluster 283:
# 아이디어패드 Slim3 15IAH8 83ER0060KR
# 아이디어패드 Slim3 15IAH8 83ER0060KR WIN10
# 아이디어패드 Slim3 15IAH8 83ER0060KR WIN11
#
# Cluster 284:
# 아이디어패드 Slim3 15IAU7 82RK0164KR
# 아이디어패드 Slim3 15IAU7 82RK0164KR 16GB램
# 아이디어패드 Slim3 15IAU7 82RK0164KR WIN11
# 아이디어패드 Slim3 15IAU7 82RK0164KR WIN11 16GB램
#
# Cluster 285:
# 아이디어패드 Slim315IAU7 5D
# 아이디어패드 Slim315IAU7 5D 16GB램
# 아이디어패드 Slim315IAU7 5D WIN11
# 아이디어패드 Slim315IAU7 5D WIN11 16GB램
#
# Cluster 286:
# 아이디어패드 Slim5 14IMH Ultra5
# 아이디어패드 Slim5 14IMH Ultra5 W11
# 아이디어패드 Slim5 14IMH Ultra5 WIN11
#
# Cluster 287:
# 아이디어패드 Slim5 16IMH Ultra5
# 아이디어패드 Slim5 16IMH Ultra5 OLED
# 아이디어패드 Slim5 16IMH Ultra5 OLED W11
# 아이디어패드 Slim5 16IMH Ultra5 OLED WIN11
# 아이디어패드 Slim5 16IMH Ultra5 WIN11
#
# Cluster 288:
# 아이디어패드 Slim5 16IMH Ultra7 OLED
# 아이디어패드 Slim5 16IMH Ultra7 OLED W11
# 아이디어패드 Slim5 16IMH Ultra7 OLED WIN11
#
# Cluster 289:
# 아이디어패드 Slim515ITL Premiere i5
# 아이디어패드 Slim515ITL Premiere i5 WIN10
# 아이디어패드 Slim515ITL Premiere Plus i5
# 아이디어패드 Slim515ITL Premiere Plus i5 WIN10
#
# Cluster 290:
# 다향 다향 국내산 닭다리살 오븐구이 스파이시
# 다향 다향 국내산 닭다리살 오븐구이 오리지널
# 다향 다향 국내산 뼈없는 닭다리살 오븐구이 스파이시
# 다향 다향 국내산 뼈없는 닭다리살 오븐구이 오리지널
#
# Cluster 291:
# 빅 핫도그
# 퀸 핫도그
# 킹 핫도그
#
# Cluster 292:
# 부산어포 포포
# 부산어포 포포 매운맛
# 부산어포 포포 오리지널
#
# Cluster 293:
# 다우니 초고농축 화이트티와 릴리
# 다우니 초고농축 화이트티와 릴리 향
# 다우니 초고농축 화이트티와 릴리 향 리필
#
# Cluster 294:
# 팬틴 PROV 극손상 케어 샴푸
# 팬틴 PROV 극손상 케어 컨디셔닝 린스
# 팬틴 PROV 극손상 케어 컨디셔닝 샴푸
#
# Cluster 295:
# 아토팜 MLE 크림
# 아토팜 MLE 크림 스틱 밤
# 아토팜 MLE 페이스 크림
#
# Cluster 296:
# 호호바 100 오일
# 100 퓨어 호호바 오일
# 호호바 오일
#
# Cluster 297:
# 뉴트로지나 NEW 딥클린 브라이트닝 포밍 클렌저
# 뉴트로지나 NEW 딥클린 아크네 포밍 클렌저
# 뉴트로지나 NEW 딥클린 젠틀 포밍 클렌저
# 뉴트로지나 NEW 딥클린 포밍 클렌저
#
# Cluster 298:
# 뉴트로지나 딥 클린 브라이트닝 포밍 클렌저
# 뉴트로지나 딥 클린 브라이트닝 포밍 클렌저 구
# 뉴트로지나 딥 클린 수딩 포밍 클렌저
# 뉴트로지나 딥 클린 아크네 포밍 클렌저
# 뉴트로지나 딥 클린 포밍 클렌저
#
# Cluster 299:
# 김나운더키친 프렙프렙 아이스 탕후루 귤
# 김나운더키친 프렙프렙 아이스 탕후루 딸기
# 김나운더키친 프렙프렙 아이스 탕후루 망고
# 김나운더키친 프렙프렙 아이스 탕후루 샤인머스켓
#
# Cluster 300:
# 닥터지 그린 마일드 업 선
# 닥터지 그린 마일드 업 선 에센스
# 닥터지 그린 마일드 업 선 플러스
#
# Cluster 301:
# 닥터지 레드 블레미쉬 수딩 업 선
# 닥터지 레드 블레미쉬 수딩 업 선스틱
# 닥터지 레드 블레미쉬 클리어 수딩 바디미스트
# 닥터지 레드 블레미쉬 클리어 수딩 크림
# 닥터지 레드 블레미쉬 클리어 수딩 크림 튜브형
# 닥터지 레드 블레미쉬 클리어 수딩 토너
# 닥터지 레드 블레미쉬 클리어 수딩 폼
# 닥터지 레드 블레미쉬 클리어 크림
#
# Cluster 302:
# 엑스트라버진 아보카도오일 선물세트
# 엑스트라버진 아보카도오일
# 아보카도오일 엑스트라버진
# 엑스트라버진 아보카도오일 30캡슐
# 엑스트라버진 아보카도오일 캡슐 30캡슐
#
# Cluster 303:
# 맛있는우유 GT 180ml 멸균
# 맛있는우유 GT 딸기 180ml 멸균
# 맛있는우유 GT 초코 180ml 멸균
#
# Cluster 304:
# 아이꼬야 동결건조 과일 귤
# 아이꼬야 동결건조 과일 딸기
# 아이꼬야 동결건조 과일 사과
#
# Cluster 305:
# 맨 데오드란트 스프레이 딥
# 맨 데오드란트 스프레이 쿨 킥
# 풋 데오드란트 스프레이
#
# Cluster 306:
# TS TS 키즈 샴푸
# TS 내추럴 올뉴 TS 샴푸
# TS 뉴 TS 쿨 샴푸
# TS 뉴 TS 트리트먼트
# TS 뉴 프리미엄 TS 샴푸
# TS 뉴 프리미엄 TS 샴푸 리필
# TS 올뉴 TS 샴푸
# TS 올리브 TS 트리트먼트
# TS 저스트 TS 샴푸
# TS 저스트 TS 트리트먼트
# TS 쿨 샴푸
# TS 프리미엄 TS 샴푸
# TS 프리미엄 TS 샴푸 세트
# TS 프리미엄 TS 트리트먼트
# TS
#
# Cluster 307:
# 구워만든 곡물 그대로 21
# 구워만든 곡물 그대로 21 18개입
# 구워만든 곡물 그대로 21 딸기
# 구워만든 곡물 그대로 21 초코
#
# Cluster 308:
# 그린너트 뉴 에브리데이 넛츠 매일매일 건강채움 20g 25개입 선물세트
# 그린너트 에브리데이 넛츠 매일매일 건강채움 25g 30개입 선물세트
# 그린너트 에브리데이 넛츠 화이트 매일매일 건강채움 20g 30개입 선물세트
# 그린너트 엘 에브리데이 넛츠 매일매일 건강채움 20g 30개입 선물세트
#
# Cluster 309:
# 왕다리 오징어
# 오징어 미니 왕다리
# 오징어 왕다리
#
# Cluster 310:
# 칼로바이 퍼펙트 파워쉐이크 아이솔레이트 초코맛
# 칼로바이 퍼펙트 파워쉐이크 초코맛
# 칼로바이 퍼펙트 파워쉐이크 믹스 초코맛 2kg
#
# Cluster 311:
# ROG KERIS WIRELESS AIMPOINT
# ASUS ROG KERIS WIRELESS AIMPOINT 특가
# ASUS ROG KERIS WIRELESS AIMPOINT 무선 게이밍 마우스
# Asus ROG Keris Wireless AimPoint
#
# Cluster 312:
# 제이멜라 디즈니 100주년 한정판 라임 앤 바질 데일리 클렌징폼 EX
# 제이멜라 디즈니 100주년 한정판 스파클링 로제 데일리 클렌징폼 EX
# 제이멜라 디즈니 100주년 한정판 퀸 5 데일리 클렌징폼 EX
# 제이멜라 디즈니 100주년 한정판 팜므파탈 데일리 클렌징폼 EX
#
# Cluster 313:
# 제이멜라 인 프랑스 블루밍 피오니 바디로션 디즈니 100주년
# 제이멜라 인 프랑스 블루밍 피오니 바디워시 디즈니 100주년
# 제이멜라 인 프랑스 블루밍 피오니 헤어 샴푸 디즈니 100주년
#
# Cluster 314:
# 네이처 리커버리 비타민 마스크팩
# 네이처 리커버리 쌀 마스크팩
# 네이처 리커버리 커피 마스크팩
#
# Cluster 315:
# 메구리즘 멕리듬 스팀 아이마스크 라벤더향 12매입
# 메구리즘 멕리듬 스팀 아이마스크 삼나무 앤 라벤더향 12매입
# 메구리즘 멕리듬 아이마스크 라벤더향 12매입
#
# Cluster 316:
# 노르웨이 고등어 대 140
# 노르웨이 고등어 140
# 노르웨이 순살 고등어 140
#
# Cluster 317:
# 22년 햇빛고을 햇 고춧가루 고추장용 매운맛
# 22년 햇빛고을 햇 고춧가루 고추장용 보통 매운맛
# 햇빛고을 고춧가루 보통 매운맛 고추장용
#
# Cluster 318:
# 빛깔찬 23년 고춧가루 김치용 매운맛
# 빛깔찬 고춧가루 김치용 매운맛
# 빛깔찬 고춧가루 김치용 보통맛
# 빛깔찬 빛깔찬 고춧가루 매운맛 김치용
# 빛깔찬 빛깔찬 고춧가루 보통맛 김치용
#
# Cluster 319:
# 호주 마카다미아
# 호주 마카다미아
# 호주 마카다미아 4팩
#
# Cluster 320:
# 아워티 레몬 얼그레이티
# 아워티 레몬 얼그레이티 10T
# 아워티 레몬 얼그레이티 제로
#
# Cluster 321:
# 아워티 오렌지 자몽 블랙티
# 아워티 오렌지 자몽 블랙티 10T
# 아워티 오렌지 자몽 블랙티 제로
#
# Cluster 322:
# 시칼파트 리페어 SOS 크림
# 시칼파트 플러스 SOS 크림
# 시칼파트 플러스 SOS 리페어 크림
#
# Cluster 323:
# 챠오츄르 유산균 참치 4P
# 챠오츄르 참치 4P
# 챠오츄르 참치 연어 4P
#
# Cluster 324:
# 시카플라스트 밤 B5
# 시카플라스트 밤 B5 플러스
# 시카플라스트 젤 B5
# 시카플라스트 밤 B5 100ml
#
# Cluster 325:
# 추억의 국민학교 떡볶이 국떡 매운맛
# 추억의 국민학교 떡볶이 국떡 오리지널
# 추억의 국민학교 떡볶이 국떡 4팩 골라담기 20000원무료
# 추억의 국민학교 떡볶이 국떡 4팩
# 추억의 국민학교 떡볶이 국떡 4팩 골라담기
# 추억의 국민학교 떡볶이 국떡 600g 4팩
#
# Cluster 326:
# 청정원 소불고기 양념
# 양념 소불고기
# 소불고기 양념 2개
#
# Cluster 327:
# 단백질 본드 앰플
# 단백질 본드 앰플 트리트먼트
# 단백질 본드 트리트먼트
#
# Cluster 328:
# 가스트로 인테스티널 독 캔
# 독 가스트로 인테스티널
# 독 가스트로 인테스티널 캔
# 캣 가스트로 인테스티널
# 캣 가스트로 인테스티널 파우치
#
# Cluster 329:
# 독 다이아베틱
# 독 다이아베틱 캔
# 캣 다이아베틱
#
# Cluster 330:
# 독 하이포알러제닉
# 독 하이포알러제닉 캔
# 캣 하이포알러제닉
#
# Cluster 331:
# 경북 안동 순살 간고등어
# 순살 안동 간고등어
# 순살 안동 간고등어 대
#
# Cluster 332:
# 푸드어홀릭 바세린 데일리 모이스처 핸드크림
# 푸드어홀릭 바세린 딥 모이스처 핸드크림
# 푸드어홀릭 바세린 콜라겐 모이스처 핸드크림
#
# Cluster 333:
# 에바스 샤샤 밀크 앤 허니 소프트 머스크 바디로션
# 에바스 샤샤 밀크 앤 허니 소프트 머스크 바디워시
# 에바스 샤샤 밀크 앤 허니 소프트 머스크 핸드크림
#
# Cluster 334:
# 에바스 샤샤 아르간 오일 바디로션
# 에바스 샤샤 아르간 오일 바디워시
# 에바스 샤샤 아르간 오일 샴푸
#
# Cluster 335:
# 천하장사 더블링 콘스윗치즈
# 천하장사 더블링 콘스윗치즈 10개입
# 천하장사 더블링 콘스윗치즈 16개입
#
# Cluster 336:
# 천하장사 더블링 콰트로치즈
# 천하장사 더블링 콰트로치즈 10개입
# 천하장사 더블링 콰트로치즈 16개입
#
# Cluster 337:
# 자연루 투데이넛 너트한줌 럭셔리 선물세트 20g 30개입
# 자연루 투데이넛 너트한줌 요거트 선물세트 20g 30개입
# 자연루 투데이넛 너트한줌 프리미엄 선물세트 20g 30개입
# 자연루 투데이넛 너트한줌 후르츠 선물세트 20g 30개입
#
# Cluster 338:
# 무꼬뭐꼬 궁물 떡볶이 무꼬뭐꼬 추억맛
# 무꼬뭐꼬 추억의 궁물 떡볶이 무꼬뭐꼬 매운맛
# 무꼬뭐꼬 추억의 궁물 떡볶이 무꼬뭐꼬 짜장맛
# 무꼬뭐꼬 추억의 궁물 떡볶이 무꼬뭐꼬 추억맛
#
# Cluster 339:
# 네스카페 수프리모 크레마 스위트 아메리카노 미니 130T
# 네스카페 수프리모 크레마 아메리카노 미니 130T
# 네스카페 수프리모 크레마 인텐소 아메리카노 미니 130T
#
# Cluster 340:
# 리벤스 에버뉴크린 황사 방역 마스크 KF94 소형 베이지 5개입
# 리벤스 에버뉴크린 황사 방역 마스크 KF94 특대형 그레이 5개입
# 리벤스 에버뉴크린 황사 방역 마스크 KF94 특대형 베이지 5개입
# 리벤스 에버뉴크린 황사 방역 마스크 KF94 특대형 블랙 5개입
#
# Cluster 341:
# 마일드 스테비아 커피믹스 100T
# 프리미엄 스테비아 커피믹스 100T
# 스테비아 마일드 커피믹스 100T
# 스테비아 커피믹스 100T
#
# Cluster 342:
# 마일드 스테비아 커피믹스 30T
# 스테비아 마일드 커피믹스 30T
# 스테비아 커피믹스 30T
#
# Cluster 343:
# 바다모아 광천 녹차 돌자반
# 바다모아 광천 돌자반
# 바다모아 광천 들기름 돌자반
# 바다모아 광천 멸치 돌자반
#
# Cluster 344:
# 페퍼민트 물티슈 리필형 70매
# 페퍼민트 블루 물티슈 리필형 70매
# 깨끗한나라 물티슈 페퍼민트 블루 리필형 70매 10팩 외 첫구매깨끗한나라 물티슈 페퍼민트 블루 리필형
#
# Cluster 345:
# 더내추럴 호박 군고구마 스틱
# 더내추럴 호박 군고구마 칩
# 더내추럴 호박 군고구마 큐브
#
# Cluster 346:
# 건강가득 노즈워크 닭가슴살 야채 큐브
# 건강가득 노즈워크 소고기 야채 큐브
# 건강가득 노즈워크 연어 야채 큐브
#
# Cluster 347:
# 브리더랩 엔젤링 THIN TYPE 링 S
# 브리더랩 엔젤링 링 THIN TYPE M
# 브리더랩 엔젤링 링 THIN TYPE S
# 브리더랩 엔젤링 본 THIN TYPE S
#
# Cluster 348:
# 건강백서 건강한 체중
# 건강백서 순 건강한 체중
# 건강백서 캣 건강한 체중
#
# Cluster 349:
# 달링키친 강아지 자연화식 닭
# 달링키친 강아지 자연화식 연어
# 달링키친 강아지 자연화식 오리
#
# Cluster 350:
# 카르마 퀸오브샌드 누디 두부모래 녹차
# 카르마 퀸오브샌드 누디 두부모래 커피
# 카르마 퀸오브샌드 누디 두부모래 퓨어
#
# Cluster 351:
# 카르마 퀸오브샌드 두부모래 녹차
# 카르마 퀸오브샌드 두부모래 숯
# 카르마 퀸오브샌드 두부모래 오리지널
#
# Cluster 352:
# 미라클 오리진 손소독제
# 미라클 오리진 손소독제 리필
# 미라클 오리진 스프레이 손소독제
#
# Cluster 353:
# 그린 소독용 에탄올
# 소독용 에탄올
# 소독용 에탄올 스프레이
#
# Cluster 354:
# 경포장 OPP 박스테이프 48mm x
# 경포장 OPP 아크릴 박스테이프 48mm x
# OPP 경포장 박스테이프
#
# Cluster 355:
# 마산명산 마산명산 몽고간장 송표
# 마산명산 마산명산 몽고간장 송표 골드
# 마산명산 마산명산 몽고간장 송표 프라임
# 마산명산 몽고간장 송표 골드
# 마산명산 몽고간장 송표 프라임
#
# Cluster 356:
# 동결건조 아로니아 파우더
# 유기농 동결건조 아로니아 파우더
# 동결건조 유기농 아로니아 파우더
#
# Cluster 357:
# SYN 프리바이오틱스 유산균 30포
# SYN 프리바이오틱스 30포
# SYN 프리바이오틱스 5g 30포
#
# Cluster 358:
# 순 에탄올 워셔액
# 에탄올 워셔액
# 더 뷰 에탄올 워셔액
#
# Cluster 359:
# 엑스트라버진 올리브유
# 엑스트라버진 유기농 올리브유
# 유기농 엑스트라버진 올리브유
#
# Cluster 360:
# 벨버드 뉴벨버드 알파독 기저귀 M 10매
# 벨버드 뉴벨버드 알파독 기저귀 S 10매
# 벨버드 뉴벨버드 알파독 기저귀 SS 10매
#
# Cluster 361:
# 벨버드 자연밥상 닭고기 원형캔
# 벨버드 자연밥상 새우 닭고기 원형캔
# 벨버드 자연밥상 소고기 닭고기 원형캔
# 벨버드 자연밥상 쌀 닭고기 원형캔
# 벨버드 자연밥상 야채 닭고기 원형캔
#
# Cluster 362:
# 스카이 갤럭시S23 팔레트 맥세이프 호환 그립 스마트링 스탠드 케이스
# 스카이 아이폰13 팔레트 맥세이프 호환 그립 스마트링 스탠드 케이스
# 스카이 아이폰14 팔레트 맥세이프 호환 그립 스마트링 스탠드 케이스
# 스카이 아이폰15 팔레트 맥세이프 호환 그립 스마트링 스탠드 케이스
#
# Cluster 363:
# 아임닭 프랑크 오리지날 닭가슴살 꼬치형 소시지
# 아임닭 프랑크 허브 닭가슴살 꼬치형 소시지
# 아임닭 꼬치형 닭가슴살 소시지 프랑크 오리지널
#
# Cluster 364:
# 육포 선물세트
# 프리미엄 육포 선물세트
# 궁 육포 선물세트
#
# Cluster 365:
# 마일드라이너 한정판 형광펜 세트
# 마일드라이너 형광펜
# 마일드라이너 형광펜 세트
#
# Cluster 366:
# 유니 제트스트림 SXR 10 단색 리필심
# 유니 제트스트림 SXR 38 단색 리필심
# 유니 제트스트림 SXR 5 단색 리필심
# 유니 제트스트림 단색 SXR 7 리필심
#
# Cluster 367:
# 유성 매직
# 유성 매직 세트
# 파워 유성 매직
#
# Cluster 368:
# 파워라인 마일드 형광펜
# 파워라인 마일드 형광펜 세트
# 파워라인 형광펜
# 파워라인 형광펜 세트
#
# Cluster 369:
# 1000 제도 샤프
# 1000 투명 제도 샤프
# 제도 1000 샤프
#
# Cluster 370:
# 파워엣지 R250 E2324G RAID1
# 파워엣지 R250 E2324G RAID1 W2022
# 파워엣지 R250 E2324G W2022
#
# Cluster 371:
# 파워엣지 R350 E2378G RAID1
# 파워엣지 R350 E2378G RAID1 W2019
# 파워엣지 R350 E2378G RAID1 W2022
# 파워엣지 R350 E2378G W2019
#
# Cluster 372:
# 파워엣지 T150 E2324G RAID1
# 파워엣지 T150 E2324G RAID1 W2019
# 파워엣지 T150 E2324G RAID1 W2022
# 파워엣지 T150 E2324G W2019
#
# Cluster 373:
# 파워엣지 T150 E2334 RAID1
# 파워엣지 T150 E2334 RAID1 W2022
# 파워엣지 T150 E2334 W2022
#
# Cluster 374:
# 라이피스트 디어 팬트리 수납 정리함 대
# 라이피스트 디어 팬트리 수납 정리함 소
# 라이피스트 디어 팬트리 수납 정리함 중
#
# Cluster 375:
# 라이피스트 주방 팬트리 수납 정리함 대형
# 라이피스트 주방 팬트리 수납 정리함 소형
# 라이피스트 주방 팬트리 수납 정리함 중형
#
# Cluster 376:
# 더착한 절단 쭈꾸미
# 더착한 절단 쭈꾸미 대
# 더착한 절단 쭈꾸미 중
# 더착한 절단 쭈꾸미 특대
#
# Cluster 377:
# 보스톤 고블렛 대
# 보스톤 고블렛 중
# 보스톤 고블렛 중 해외구매
#
# Cluster 378:
# 티볼리 컬러 수납박스 대
# 티볼리 컬러 수납박스 소
# 티볼리 컬러 수납박스 중
#
# Cluster 379:
# 시그니처 프리미엄 복사용지 A4 80g 팩
# 프리미엄 복사용지 A4 80g 박스
# 프리미엄 복사용지 A4 80g 팩
#
# Cluster 380:
# 오토 아이브로우 펜슬
# 컬러 오토 아이브로우 펜슬
# 오토 듀얼 아이브로우 펜슬
#
# Cluster 381:
# 레드 락토 콜라겐 클리어 20
# 레드 락토 콜라겐 클리어 20 클렌징폼
# 레드 락토 콜라겐 클리어 클렌징폼
#
# Cluster 382:
# 골프공
# C 골프공
# Q 골프공
#
# Cluster 383:
# 1025 독도 버블 클렌징 폼
# 1025 독도 클렌징 밀크
# 1025 독도 클렌징 밤
# 1025 독도 클렌징 오일
# 1025 독도 클렌징 워터
#
# Cluster 384:
# 데이지가든 내츄럴 깊은 라탄 바구니 L
# 데이지가든 내츄럴 라탄 바구니 S
# 데이지가든 내츄럴 라탄 바구니 XS
#
# Cluster 385:
# 포레스트 블랙체인지 골드라벨 샴푸 벚꽃에디션 자연갈색
# 포레스트 블랙체인지 샴푸 골드라벨 자연갈색
# 포레스트 블랙체인지 샴푸 자연갈색
#
# Cluster 386:
# 포레스트 블랙체인지 골드라벨 샴푸 벚꽃에디션 흑갈색
# 포레스트 블랙체인지 샴푸 골드라벨 흑갈색
# 포레스트 블랙체인지 샴푸 흑갈색
#
# Cluster 387:
# 카누들 잇몸플러스 L
# 카누들 잇몸플러스 M
# 카누들 잇몸플러스 S
#
# Cluster 388:
# 블루택 재사용 점착제 점토 블루
# 블루택 재사용 점토 점착제 블루
# 블루택 재사용 점토 점착제 컬러
#
# Cluster 389:
# 더블리 제크 소프트마이크로 차렵이불
# 더블리 제크 소프트마이크로 차렵이불 베개세트
# 더블리 제크 소프트마이크로 차렵이불 풀세트
#
# Cluster 390:
# 더블리 파리스 고밀도 60수 간절기 이불
# 더블리 파리스 고밀도 60수 간절기 이불 베개세트
# 더블리 파리스 고밀도 60수 간절기 이불 풀세트
#
# Cluster 391:
# 더블리 헨드리 소프트마이크로 차렵이불
# 더블리 헨드리 소프트마이크로 차렵이불 베개세트
# 더블리 헨드리 소프트마이크로 차렵이불 풀세트
#
# Cluster 392:
# 샤르르 루화 여름 모달이불
# 샤르르 루화 여름 모달이불 베개세트
# 샤르르 루화 여름 모달이불 풀세트
#
# Cluster 393:
# 샤르르 서리 냉감 여름 홑이불
# 샤르르 서리 냉감 여름 홑이불 베개세트
# 샤르르 서리 냉감 여름 홑이불 풀세트
#
# Cluster 394:
# 샤르르 세인 10mm 착번 극세사 차렵이불
# 샤르르 세인 10mm 착번 극세사 차렵이불 베개세트
# 샤르르 세인 10mm 착번 극세사 차렵이불 풀세트
#
# Cluster 395:
# 샤르르 쿨리쉬 냉감 여름 홑이불
# 샤르르 쿨리쉬 냉감 여름 홑이불 베개세트
# 샤르르 쿨리쉬 냉감 여름 홑이불 풀세트
#
# Cluster 396:
# 아밍 로빈 세미 마이크로 차렵이불
# 아밍 로빈 세미 마이크로 차렵이불 베개세트
# 아밍 로빈 세미 마이크로 차렵이불 풀세트
#
# Cluster 397:
# 아밍 아린 피그먼트 워싱 순면 양모 차렵이불
# 아밍 아린 피그먼트 워싱 순면 양모 차렵이불 베개세트
# 아밍 아린 피그먼트 워싱 순면 양모 차렵이불 풀세트
#
# Cluster 398:
# 훈제 닭가슴살 저염분 냉동
# 훈제 닭가슴살 저염분 냉장
# 닭가슴살 훈제 저염분
#
# Cluster 399:
# 겐조 옥토퍼스
# 겐조 옥토퍼스 V
# 겐조 옥토퍼스 스페셜
#
# Cluster 400:
# 제라늄 리프 바디 밤
# 제라늄 리프 바디 스크럽
# 제라늄 리프 바디 클렌저
#
# Cluster 401:
# 7mm 21cm 검정 일자 스트로우 음료용
# 개별포장 7mm 21cm 검정 일자 스트로우 음료용
# 블랙 일자 스트로우 음료용 7mm 21cm
#
# Cluster 402:
# 리빙숲 바오 팬트리 박스 대
# 리빙숲 바오 팬트리 박스 소
# 리빙숲 바오 팬트리 박스 중
#
# Cluster 403:
# 보노하우스 로코스 정리함 수납바스켓 L
# 보노하우스 로코스 정리함 수납바스켓 M
# 보노하우스 로코스 정리함 수납바스켓 S
# 보노하우스 로코스 정리함 수납바스켓 XS
#
# Cluster 404:
# 보노하우스 리빙 그립 바스켓 L
# 보노하우스 리빙 그립 바스켓 M
# 보노하우스 리빙 그립 바스켓 S
#
# Cluster 405:
# 보노하우스 아이엠 리빙박스 L
# 보노하우스 아이엠 리빙박스 M
# 보노하우스 아이엠 리빙박스 S
#
# Cluster 406:
# 구워먹는 치즈
# 프리미엄 구워먹는 치즈
# 프리미엄 유기농 구워먹는 치즈
#
# Cluster 407:
# 그린토마토 포어 리프팅 앰플
# 그린토마토 포어 리프팅 앰플 토너
# 그린토마토 포어 리프팅 앰플 플러스
#
# Cluster 408:
# 노니 에너지 앰플
# 더 리얼 노니 에너지 앰플
# 더 리얼 노니 에너지 앰플 마스크
#
# Cluster 409:
# 랩몬스터 반양피 골프장갑
# 랩몬스터 반양피 여성용 골프장갑
# 랩몬스터 스카이 반양피 여성용 골프장갑
#
# Cluster 410:
# 엑스핏 워시앤케어 세차타월 소
# 엑스핏 워시앤케어 세차타월 중
# 엑스핏 워시앤케어 세차타월 특대
#
# Cluster 411:
# 라이젠55세대 8600G 피닉스
# AMD 라이젠55세대 8600G 피닉스 정품
# AMD 라이젠55세대 8600G 피닉스 정품
#
# Cluster 412:
# CHARGE 3
# CHARGE 4
# CHARGE 5
#
# Cluster 413:
# PULSE 3
# PULSE 4
# PULSE 5
#
# Cluster 414:
# 벨라홈 팬트리 수납함 대
# 벨라홈 팬트리 수납함 소
# 벨라홈 팬트리 수납함 중
#
# Cluster 415:
# 더 잇츄 그린 S 948g 12g x 79P
# 더 잇츄 브라운 S 948g 12g x 79P
# 더 잇츄 옐로우 S 948g 12g x 79P
#
# Cluster 416:
# 갤럭시S23 렌즈 풀커버 하드 케이스
# 갤럭시S23 울트라 렌즈 풀커버 하드 케이스
# 갤럭시S23 플러스 렌즈 풀커버 하드 케이스
#
# Cluster 417:
# 아이폰11 렌즈 풀커버 하드 케이스
# 아이폰11 프로 렌즈 풀커버 하드 케이스
# 아이폰11 프로 맥스 렌즈 풀커버 하드 케이스
#
# Cluster 418:
# 아이폰13 렌즈 풀커버 하드 케이스
# 아이폰13 프로 렌즈 풀커버 하드 케이스
# 아이폰13 프로 맥스 렌즈 풀커버 하드 케이스
#
# Cluster 419:
# 베드리움 노블 모션센서 LED침대 K
# 베드리움 노블 모션센서 LED침대 Q
# 베드리움 노블 모션센서 LED침대 SS
#
# Cluster 420:
# 베드리움 레오스 4단 수납 LED침대 Q
# 베드리움 레오스 4단 수납 LED침대 SS
# 베드리움 레오스 가죽 4단 수납 LED침대 Q
# 베드리움 레오스 가죽 4단 수납 LED침대 SS
#
# Cluster 421:
# 베드리움 리디아 원목 LED침대 K
# 베드리움 리디아 원목 LED침대 Q
# 베드리움 리디아 원목 LED침대 SS
#
# Cluster 422:
# 베드리움 셀린 패브릭 호텔형 침대 K
# 베드리움 셀린 패브릭 호텔형 침대 Q
# 베드리움 셀린 패브릭 호텔형 침대 SS
#
# Cluster 423:
# 베드리움 파운데이션 침대 K
# 베드리움 파운데이션 침대 Q
# 베드리움 파운데이션 침대 SS
#
# Cluster 424:
# 베드리움 피보 패브릭 호텔형 침대 K
# 베드리움 피보 패브릭 호텔형 침대 Q
# 베드리움 피보 패브릭 호텔형 침대 SS
#
# Cluster 425:
# 로톰 기본형 썬루프 썬팅필름 르노 SM5 2세대 전용 RTF1S
# 로톰 기본형 썬루프 썬팅필름 르노 SM5 2세대 전용 RTF4S
# 로톰 기본형 썬루프 썬팅필름 르노 SM5 2세대 전용 RTF7S
#
# Cluster 426:
# 로톰 기본형 썬루프 썬팅필름 쉐보레 라세티 프리미어 전용 RTF1S
# 로톰 기본형 썬루프 썬팅필름 쉐보레 라세티 프리미어 전용 RTF4S
# 로톰 기본형 썬루프 썬팅필름 쉐보레 라세티 프리미어 전용 RTF7S
#
# Cluster 427:
# 로톰 전면 열성형 썬팅필름 쉐보레 더 넥스트 스파크 전용 RTF1S
# 로톰 전면 열성형 썬팅필름 쉐보레 더 넥스트 스파크 전용 RTF4S
# 로톰 전면 열성형 썬팅필름 쉐보레 더 넥스트 스파크 전용 RTF7S
#
# Cluster 428:
# 로톰 파노라마 썬루프 썬팅필름 기아 K5 JF 전용 RTF1S
# 로톰 파노라마 썬루프 썬팅필름 기아 K5 JF 전용 RTF4S
# 로톰 파노라마 썬루프 썬팅필름 기아 K5 JF 전용 RTF7S
#
# Cluster 429:
# 로톰 파노라마 썬루프 썬팅필름 기아 K5 TF 전용 RTF1S
# 로톰 파노라마 썬루프 썬팅필름 기아 K5 TF 전용 RTF4S
# 로톰 파노라마 썬루프 썬팅필름 기아 K5 TF 전용 RTF7S
#
# Cluster 430:
# 로톰 파노라마 썬루프 썬팅필름 기아 K7 VG 전용 RTF1S
# 로톰 파노라마 썬루프 썬팅필름 기아 K7 VG 전용 RTF4S
# 로톰 파노라마 썬루프 썬팅필름 기아 K7 VG 전용 RTF7S
# 로톰 파노라마 썬루프 썬팅필름 기아 올 뉴 K7 전용 RTF1S
# 로톰 파노라마 썬루프 썬팅필름 기아 올 뉴 K7 전용 RTF4S
# 로톰 파노라마 썬루프 썬팅필름 기아 올 뉴 K7 전용 RTF7S
#
# Cluster 431:
# 로톰 파노라마 썬루프 썬팅필름 기아 스포티지 QL 전용 RTF1S
# 로톰 파노라마 썬루프 썬팅필름 기아 스포티지 QL 전용 RTF4S
# 로톰 파노라마 썬루프 썬팅필름 기아 스포티지 QL 전용 RTF7S
#
# Cluster 432:
# 로톰 파노라마 썬루프 썬팅필름 현대 i40 살룬 전용 RTF1S
# 로톰 파노라마 썬루프 썬팅필름 현대 i40 살룬 전용 RTF4S
# 로톰 파노라마 썬루프 썬팅필름 현대 i40 살룬 전용 RTF7S
#
# Cluster 433:
# 로톰 파노라마 썬루프 썬팅필름 현대 벨로스터 FS 전용 RTF1S
# 로톰 파노라마 썬루프 썬팅필름 현대 벨로스터 FS 전용 RTF4S
# 로톰 파노라마 썬루프 썬팅필름 현대 벨로스터 FS 전용 RTF7S
#
# Cluster 434:
# 로톰 파노라마 썬루프 썬팅필름 현대 쏘나타 DN8 전용 RTF1S
# 로톰 파노라마 썬루프 썬팅필름 현대 쏘나타 DN8 전용 RTF4S
# 로톰 파노라마 썬루프 썬팅필름 현대 쏘나타 DN8 전용 RTF7S
#
# Cluster 435:
# 저스트 클릭 M2 형광펜
# 저스트 클릭 M2 형광펜 세트
# 저스트 클릭 S 형광펜
# 저스트 클릭 S 형광펜 세트
#
# Cluster 436:
# 라클라우드 헬스모션 모션베드 K
# 라클라우드 헬스모션 모션베드 Q
# 라클라우드 헬스모션 모션베드 SS
#
# Cluster 437:
# 더캐럿 허니 마 베이스
# 더캐럿 허니 밀크 베이스
# 더캐럿 허니 바닐라 베이스
#
# Cluster 438:
# 오디세이 2021 텐 시리즈 텐 S 트리플 트랙 퍼터
# 오디세이 2021 텐 시리즈 텐 트리플 트랙 퍼터
# 오디세이 2021 텐 시리즈 투볼 텐 S 트리플 트랙 퍼터
# 오디세이 텐 시리즈 투볼 텐 트리플 트랙 퍼터
#
# Cluster 439:
# 오디세이 일레븐 트리플 트랙 DB 퍼터
# 오디세이 일레븐 트리플 트랙 S 퍼터
# 오디세이 투볼 일레븐 트리플 트랙 퍼터
#
# Cluster 440:
# 뉴트리원라이프 루테인 지아잔틴 164 30캡슐
# 뉴트리원라이프 루테인 지아잔틴 164 알티지 오메가3 100캡슐
# 뉴트리원라이프 루테인 지아잔틴 164 알티지 오메가3 30캡슐
#
# Cluster 441:
# 김용석생활연구소 모던 M 빨래집게
# 김용석생활연구소 모던 이불 빨래집게
# 김용석생활연구소 모던 일반 빨래집게
#
# Cluster 442:
# 인베스코 숨쉬는 깔판 D
# 인베스코 숨쉬는 깔판 Q
# 인베스코 숨쉬는 깔판 SS
#
# Cluster 443:
# 그린페트 개나리 고무장갑 대
# 그린페트 개나리 고무장갑 소
# 그린페트 개나리 고무장갑 중
#
# Cluster 444:
# 모던하우스 슈퍼쿨 3도씨 프로즌 냉감 아이스 패드 라벤더
# 모던하우스 슈퍼쿨 3도씨 프로즌 냉감 아이스 패드 레몬
# 모던하우스 슈퍼쿨 3도씨 프로즌 냉감 아이스 패드 민트
#
# Cluster 445:
# 롯데이라이프 비닐봉투 미니 흑색 90매
# 롯데이라이프 비닐봉투 소형 흑색 90매
# 롯데이라이프 비닐봉투 중형 흑색 90매
#
# Cluster 446:
# SK매직 WPU2100C 1년 호환필터 세트
# SK매직 WPU2100C 1회 호환필터 세트
# SK매직 WPU2100C 호환필터 세트
#
# Cluster 447:
# 킹 물티슈 캡형 100매
# 숨 물티슈 캡형 100매
# 물티슈 캡형 100매
# 오리지널 물티슈 캡형 100매
#
# Cluster 448:
# 포메리트 롤링 토퍼 매트리스 MS
# 포메리트 롤링 토퍼 매트리스 Q
# 포메리트 롤링 토퍼 매트리스 S
# 포메리트 롤링 토퍼 매트리스 SS
#
# Cluster 449:
# 마니수 강화사자발쑥 진액 오리지널 80ml 30포
# 마니수 강화사자발쑥 진액 오리지널 80ml 60포
# 마니수 강화사자발쑥 진액 프리미엄 80ml 60포
#
# Cluster 450:
# 스텔스2 HD 여성용 페어웨이우드
# 스텔스2 HD 페어웨이우드
# 스텔스2 페어웨이우드
# 스텔스2 플러스 페어웨이우드
#
# Cluster 451:
# 파인뷰 X550 4K 빌트인 와이파이 2채널
# 파인뷰 X550 빌트인 와이파이 2채널
# 파인뷰 X550 클라우드 빌트인 와이파이 2채널
#
# Cluster 452:
# 천연목화 풍기인견 여름이불 그레이 기본세트
# 천연목화 풍기인견 여름이불 블루 기본세트
# 천연목화 풍기인견 여름이불 핑크 기본세트
#
# Cluster 453:
# CAT5e UTP 다이렉트 랜케이블
# CAT5e UTP 랜케이블
# CAT5e UTP 랜케이블 박스
#
# Cluster 454:
# CAT6 UTP 기가바이트 랜케이블
# CAT6 UTP 랜케이블
# CAT6 UTP 랜케이블 박스
#
# Cluster 455:
# 바론 모션베드 Q
# 바론 모션베드 S
# 바론 모션베드 SS
#
# Cluster 456:
# 로이스 호텔 멀티수납 LED침대 K
# 로이스 호텔 멀티수납 LED침대 Q
# 로이스 호텔 멀티수납 LED침대 SS
#
# Cluster 457:
# QC 울트라 이어버드
# QC 이어버드
# QC 이어버드 2
#
# Cluster 458:
# 릴렉스 롱 체어
# 롱 릴렉스 체어
# 릴렉스 체어 S
#
# Cluster 459:
# Crucial DDR55600 CL46 PRO 패키지 대원씨티에스
# 다나와DPG 마이크론 Crucial DDR55600 CL46 PRO 패키지 대원씨티에스 64GB32Gx2마이크론 crucial ddr55600 cl46 pro 패키지 대원씨티에스
# 마이크론 Crucial DDR55600 CL46 PRO 패키지 대원씨티에스 64GB32Gx2 무배마이크론 crucial ddr55600 cl46 pro 패키지 대원씨티에스
#
# Cluster 460:
# 맨 EDT
# 르 말 EDT
# 로 EDT
#
# Cluster 461:
# 복사용지 A4 75g 박스
# 프리미엄 그린 복사용지 A4 75g 박스
# 프리미엄 복사용지 A4 75g 박스
#
# Cluster 462:
# 더 블랙 옴므 올인원 플루이드
# 파워 옴므 올인원 플루이드
# 옴므 올인원 플루이드
#
# Cluster 463:
# 산양유 초유 단백질 프로틴
# 산양유 초유 단백질 콜라겐
# 산양유 초유 단백질 플러스
# 산양유 초유 단백질
#
# Cluster 464:
# 100 엑스트라 버진 아보카도 오일
# 팔레오 엑스트라 버진 아보카도 오일
# 엑스트라 버진 아보카도 오일
#
# Cluster 465:
# 알로에베라 100 수딩젤
# 알로에베라 100 수딩젤
# 알로에베라 수딩젤
#
# Cluster 466:
# 네이버페이 일일적립 클릭 16원
# 일일적립 클릭 16원
# 일일적립 클릭 16원
#
# Cluster 467:
# 스포티파이 프리미엄 3개월 무료
# 스포티파이 프리미엄 베이직 3개월 무료무료
# 스포티파이 3개월
# 스포티파이 3개월 무료  무료
# 스포티파이 w 카카오페이 3개월 무료
# 스포티파이 프리미엄 베이직 3개월 무료
# 스포티파이 베이직 3개월 무료 무료무료
# 스포티파이 베이직 3개월 무료
# 스포티파이 3개월 무료
#
# Cluster 468:
# 펩시콜라 제로 210ml 60캔
# 펩시콜라 제로 210ml x 60캔
# 펩시콜라 제로 210ml x 60캔 유클
# 펩시콜라 제로 210ml x 60캔 무배
#
# Cluster 469:
# 네이버페이 금요일은 편의점 가는 날
# 금요일은 편의점 가는 날
# 금요일은 편의점 가는 날
#
# Cluster 470:
# 쉬크 면도크림 쉐이브가드 센서티브 라임폼 210g 4개
# 면도크림 쉐이브가드 센서티브 라임폼 210g 4개
# 쉬크 쉐이브가드 센서티브 라임폼 면도크림 210g 4개
#
# Cluster 471:
# ARCTIC P12 PWM PST VALUE PACK 서린 옥션 지마켓
# ARCTIC P12 PWM PST VALUE PACK 서린
# ARCTIC P12 PWM PST VALUE PACK 서린 외 1
# ARCTIC P12 PWM PST VALUE PACK
# ARCTIC P12 PWM PST VALUE PACK 아틱
# ARCTIC P12 PWM PST VALUE PACK 서린 5팩 정품
# ARCTIC P12 PWM PST VALUE PACK 아틱 5개 세트
# ARCTIC P12 PWM PST VALUE PACK 아틱 유니버스클럽
# ARCTIC P12 PWM PST ARGB VALUE PACK 화이트
#
# Cluster 472:
# 워치 페이스 3종 무료
# 워치 페이스 무료
# 워치 페이스 2종 무료
# 워치 페이스 5종 무료
# 워치 페이스 몇 종 무료
# 워치 페이스 3 종 무료
#
# Cluster 473:
# 네이버 15원 a
# 네이버 15원
# 네이버 15원  a
#
# Cluster 474:
# 오뚜기 컵밥 333 총 9개 골라담기
# 오뚜기 컵밥 333 총 9개 골라담기 15900원  무료
# 오뚜기 컵밥 333 9개 골라담기 15900원무료
#
# Cluster 475:
# 삼성 오디세이 G5 C27G54T 게이밍 모니터
# 빅세일 삼성 오디세이 G5 C27G54T 게이밍 모니터
# 삼성 오디세이 G5 C27G54T
# 오디세이 위크 삼성 오디세이 G5 C27G54T 게이밍 모니터
#
# Cluster 476:
# ASUS ROG HERCULX 그래픽카드 지지대
# ASUS ROG Herculx 그래픽카드 지지대
# ASUS ROG HERCULX 그래픽카드 지지대
#
# Cluster 477:
# 갈배사이다 제로 355ml 24캔 외
# 갈배사이다 제로 355ml 24캔
# 갈배사이다 제로 24캔 355ml
#
# Cluster 478:
# SK하이닉스 Gold P31 NVMe SSD 2TB
# SK하이닉스 GOLD P31 NVMe 2TB SSD 169000원무료
# SK하이닉스 GOLD P31 NVMe SSD 2TB
#
# Cluster 479:
# 레쓰비 마일드 캔커피 175ml x 60캔
# 레쓰비 마일드 캔커피 175ml 60캔 19950원무료
# 레쓰비 마일드 캔커피 175ml 60캔
#
# Cluster 480:
# 이번주 만원 이하 한국어 지원 할인 타이틀
# 이번주 만원 이하 할인 한국어 타이틀
# 이번주 만원 이하 할인 한국어 지원 타이틀
#
# Cluster 481:
# 파이널 판타지 픽셀 리마스터 91600원
# 닌텐도 스위치 파이널 판타지 픽셀 리마스터 91600원
# 파이널 판타지 픽셀 리마스터 91600원  3000원
# 파이널 판타지 픽셀 리마스터 91600원  3500원
# 파이널 판타지 픽셀 리마스터 91600원  3천원
# 파이널 판타지 픽셀 리마스터 91600원
#
# Cluster 482:
# 파이널 판타지 픽셀 리마스터 91600
# 파이널 판타지 픽셀 리마스터 91600
# 파이널 판타지 픽셀 리마스터 91600  2500
# SWITCH 파이널 판타지 픽셀 리마스터  91600
#
# Cluster 483:
# CJ 비비고 사골곰탕 500G 18개
# 비비고 사골곰탕 500g x 18개
# 비비고 사골곰탕 500G X 18개 무배
# 비비고 사골곰탕 500g 18개
# 비비고 사골곰탕 500g x 18개 무배
# 비비고 사골곰탕 500g  18개 카카오페이
#
# Cluster 484:
# 리퍼 BRAVOTEC GUARDIAN 3100M V2 타이탄 글래스 A등급 블랙
# BRAVOTEC GUARDIAN 3100M V2 타이탄 글래스 블랙
# BRAVOTEC GUARDIAN 3100M V2 타이탄 글래스 블랙 등
# BRAVOTEC GUARDIAN 3100M V2 타이탄 글래스 블랙 리퍼
# 중고 B등급 BRAVOTEC GUARDIAN 3100M V2 타이탄 글래스 블랙
# B등급 BRAVOTEC GUARDIAN 3100M V2 타이탄 글래스 블랙
#
# Cluster 485:
# AMD 라이젠 라파엘 정품 R5 7500F 멀티팩
# AMD 라이젠 라파엘 R5 7500F 멀티팩
# AMD 라이젠 R5 7500F 멀티팩
#
# Cluster 486:
# 질레트 대용량 면도날 16입 모음전
# 질레트 대용량 면도날 16입
# 질레트 대용량 팩 면도날 16입
#
# Cluster 487:
# 메가커피 아이스 아메리카노
# 메가커피 아이스 아메리카노 20
# 메가커피 아이스 아메리카노 20 할인
# 메가커피 아메리카노 아이스
#
# Cluster 488:
# 소니 WH1000XM5 블루투스 헤드폰
# WH1000XM5 노이즈캔슬링 블루투스 헤드폰
# 소니 WH1000XM5 노이즈캔슬링 블루투스 헤드폰
# 소니 WH1000XM5 노이즈캔슬링 블루투스 헤드폰 외 KB페이
# 소니 노이즈캔슬링 블루투스 헤드폰 WH1000XM5
# 소니 WH1000XM5 노이즈캔슬링 블루투스 헤드폰 3종
#
# Cluster 489:
# 쏜리서치 베이직 뉴트리언트 투퍼데이 종합비타민 60캡슐 4병
# 쏜리서치 베이직 뉴트리언트 투퍼데이 종합비타민 60캡슐 4병 79800원무료
# 쏜리서치 투퍼데이 종합비타민 60캡슐 4병 79800원무료
#
# Cluster 490:
# 에픽게임즈 Orwell Keeping an Eye on You  무료무료
# Orwell Keeping an Eye on You 무료
# Orwell Keeping an Eye on You
#
# Cluster 491:
# 카툰 크래프트 무료
# 카툰 크래프트
# 안드로이드 카툰 크래프트 무료
#
# Cluster 492:
# CTOC 60w 초고속 충전 기본케이블 5개 1mctoc 초고속 충전 기본케이블
# 14 CTOC 60w 초고속 충전 기본케이블 1mctoc 초고속 충전 기본케이블
# CTOC 60w 초고속 충전 기본케이블 5개
#
# Cluster 493:
# 양조간장 701
# 샘표 양조간장 701 17L  701 500ml 11810원무료샘표 양조간장 701  701
# 샘표 양조간장 701 17L  701 860ml 10980원  유클무료샘표 양조간장 701  701
#
# Cluster 494:
# G마켓 메가커피 아이스 아메리카노 외 20할인 1600무료
# 메가커피 아이스 아메리카노 외 20할인 1600무료
# 메가커피 아이스 아메리카노 20할인 외 기타 1600무료
#
# Cluster 495:
# 8월 프로모션 이벤트
# 8월 프로모션 할인 이벤트
# 8월 프로모션 할인 특가 이벤트
#
# Cluster 496:
# 원쁠 한우 부위별 모듬구이 600g800g1kg소불고기국거리 등 골라담기 다양무료원쁠 한우 부위별 모듬구이 소불고기국거리 등600g
# 1 한우 부위별 모듬구이 600g800g1kg소불고기국거리 등 골라담기 39600원무료1 한우 부위별 모듬구이 소불고기국거리 등600g
# 1 한우 부위별 모듬구이 600g800g1kg소불고기국거리 등 골라담기 39600원  무료배송1 한우 부위별 모듬구이 소불고기국거리 등600g
#
# Cluster 497:
# DJMAX RESPECT V 할인
# DJMax Respect V 80 할인
# 스팀 DJMAX RESPECT V 할인
#
# Cluster 498:
# 파이널판타지 픽셀 리마스터 91600원 배송비 3천원
# 품절 파이널판타지 픽셀 리마스터 91600원  배송비 3천원
# 파이널판타지 픽셀 리마스터 91600원 예약  배송비 3천원
# 파이널판타지 픽셀 리마스터 91600원  배송비 3천원
#
# Cluster 499:
# 비달사순 2000W 파워 블랙 앤 로즈 헤어 드라이기 VSD120K
# 비달사순 2000W 파워 블랙 앤 로즈 헤어 드라이기 VSD120K 17910로켓배송
# 비달사순 2000W 파워 블랙 앤 로즈 헤어 드라이기 VSD120K 18810원 무료
#
# Cluster 500:
# 크리넥스 3겹 울트라클린 25M 24롤 2팩크리넥스 3겹 울트라클린
# 크리넥스 3겹 울트라클린 25m 24롤 2팩크리넥스 3겹 울트라클린
# 크리넥스 3겹 울트라클린 25m x 24롤 2팩크리넥스 3겹 울트라클린
# 크리넥스 3겹 울트라클린 25m 24롤 x 2팩크리넥스 3겹 울트라클린
# 크리넥스 3겹 울트라클린 25m x 24롤 x 2팩크리넥스 3겹 울트라클린 x
#
# Cluster 501:
# 삼성 오디세이 G5 G52A S32AG520 32인치 게이밍 모니터 IPS QHD 165Hz HDR 400오디세이 g52a s32ag520 게이밍 모니터 ips qhd hdr 4005 g
# 삼성 오디세이 G5 G52A S32AG520 32인치 게이밍 모니터 IPS QHD 165Hz HDR 400 카드 379000원무료오디세이 g52a s32ag520 게이밍 모니터 ips qhd hdr 4005 g
# 삼성 오디세이 G5 G52A S32AG520 32인치 게이밍 모니터 QHD 165Hz IPS HDR 400무배오디세이 g52a s32ag520 게이밍 모니터 qhd ips hdr 4005 g
#
# Cluster 502:
# ASRock B650 PG Lightning 대원씨티에스
# AsRock B650 PG Lightning 대원씨티에스 판매
# ASRock B650 PG Lightning
#
# Cluster 503:
# 갤럭시 RTX 4070 EX GAMER BLACK OC D6X 12GB
# 갤럭시 GALAX 지포스 RTX 4070 EX GAMER BLACK OC D6X 12GB
# 갤럭시 GALAX 지포스 RTX 4070 Ti EX GAMER WHITE OC D6X 12GB
# GALAX 지포스 RTX 4070 EX GAMER WHITE OC D6X 12GB
# 갤럭시 지포스 RTX 4070 Super EX Gamer Black OC D6X 12GB
# 갤럭시 GALAX 지포스 RTX 4070 SUPER EX GAMER BLACK OC D6X 12GB
# 갤럭시 GALAX 지포스 RTX 4070 Super EX Gamer Black OC D6X 12GB 768240원무료
# 갤럭시 GALAX 지포스 RTX 4070 Super EX Gamer White OC D6X 12GB
#
# Cluster 504:
# 네이버 1원
# 네이버 1원  a
# 네이버 1원 _
#
# Cluster 505:
# 오뚜기 3분 짜장 200g 12개  카레 약간매운맛 200g 12개 15800  무료오뚜기 3분 짜장  카레 약간매운맛200g
# 오뚜기 3분 짜장 200g 12개  카레 약간매운맛 200g 12개 15800원  무료오뚜기 3분 짜장  카레 약간매운맛200g
# 오뚜기 3분 짜장 200g 12개  카레 약간매운맛 200g 12개 17750원무료오뚜기 3분 짜장  카레 약간매운맛200g
# 오뚜기 3분 짜장 200g 12개  카레 약간매운맛 200g 12개오뚜기 3분 짜장  카레 약간매운맛200g
#
# Cluster 506:
# 핫식스 더킹포스 355ml 24캔
# 핫식스 더킹포스 355ml 24캔 유니버스클럽
# 핫식스 더킹포스 355ml x 24캔
#
# Cluster 507:
# 닥터페퍼 제로 355ml 24개
# 닥터페퍼 제로 355ml 24개
# 닥터페퍼 제로 355ml 24개 무배
# 닥터페퍼 제로 355ml X 24개 무배
# 닥터페퍼 제로 355ML 24개
#
# Cluster 508:
# 블루다이아몬드 아몬드 브리즈 오리지널 190ml 24개
# 블루다이아몬드 아몬드 브리즈 오리지널 190ml x 24개
# 블루다이아몬드 아몬드 브리즈 오리지널 190ml 24개
#
# Cluster 509:
# LG전자 트롬 워시타워 W20WD 세탁24kg 건조20kg 2459000원무료lg전자 트롬 워시타워 wd 세탁 건조20w
# LG전자 트롬 워시타워 W20WD 세탁24kg 건조20kg 트루스팀o카드2299000원무료lg전자 트롬 워시타워 wd 세탁 건조20w
# LG전자 트롬 워시타워 W20WD 세탁24kg 건조20kg 카드 2258000원무료lg전자 트롬 워시타워 wd 세탁 건조20w
# LG전자 트롬 워시타워 W20WD 세탁24kg 건조20kg 카드 2189000원무료lg전자 트롬 워시타워 wd 세탁 건조20w
# LG전자 트롬 워시타워 W20WD 세탁24kg 건조20kg 카드 2199000원무료lg전자 트롬 워시타워 wd 세탁 건조20w
# LG전자 트롬 워시타워 W20WD 세탁24kg 건조20kg 2189000원무료lg전자 트롬 워시타워 wd 세탁 건조20w
# LG전자 트롬 워시타워 W20WD 세탁24kg 건조20kg 2189000무배lg전자 트롬 워시타워 wd 세탁 건조20w
# LG전자 트롬 워시타워 W20WD 세탁24kg 건조20kg 2169000원무료lg전자 트롬 워시타워 wd 세탁 건조20w
# LG전자 트롬 워시타워 W20WD 세탁24kg 건조20kg 카드 2159000원무료lg전자 트롬 워시타워 wd 세탁 건조20w
# LG전자 트롬 워시타워 W20WD 세탁24kg 건조20kg 트루스팀o 2159000원무료lg전자 트롬 워시타워 wd 세탁 건조20w
# ...
#
# Cluster 1080:
# 빅스마일 최종가 159만원 ASUS 비보북 프로 15 OLED N6506MUMA001 인텔 U7 RTX 4050 노트북 2024년 신제품
# 빅스마일 최종가 162만원 ASUS 비보북 프로 15 OLED N6506MUMA001 인텔 U7 RTX 4050 노트북 2024년 신제품
# 빅스마일 최종가 162만원 ASUS 비보북 프로 15 OLED N6506MUMA001 인텔 U7 RTX 4050 2024년 신제품 노트북
# 로캣배송 최종가 162만원 ASUS 비보북 프로 15 OLED N6506MUMA001 인텔 U7 RTX 4050 노트북 2024년 노트북 신제품
#
# Cluster 1081:
# 빅스마일데이 알파스캔 27인치 QHD Fast IPS  게이밍 모니터 Q27G2SD 최대 34 할인299070  무료알파스캔 qhd fast ips 게이밍 모니터 q2sd 최대
# 빅스마일데이 알파스캔 27인치 QHD Fast IPS  게이밍 모니터 Q27G2SD 최대 34 할인296990  무료알파스캔 qhd fast ips 게이밍 모니터 q2sd 최대
# 빅스마일데이 알파스캔 27인치 QHD Fast IPS  게이밍 모니터 Q27G2SD 최대 34 할인296990원  무료알파스캔 qhd fast ips 게이밍 모니터 q2sd 최대
#
# Cluster 1082:
# 엡손 EHLS800W 빔프로젝터 초단초점 4000루멘 4K UHD 2990000원무료
# 엡손 EHLS800W 빔프로젝터 초단초점 4000루멘 4K UHD 삼성
# 엡손 EHLS800W 빔프로젝터 초단초점 4000루멘 4K UHD
#
# Cluster 1083:
# 남자양말 중목 단목 1190원3000원
# 남자양말 중목 단목 양말 여러종 1190원3000원
# 남자양말 중목 단목 양말 등 다양 1190원3000원
#
# Cluster 1084:
# 클럽전용 컴포즈 아메리카노
# 컴포즈 아메리카노 클럽전용 990원
# 컴포즈 아메리카노 클럽전용
#
# Cluster 1085:
# 빅스마일데이 알파스캔 32인치 QHD IPS  게이밍 모니터 Q32G3S 포함 3종 추가 할인 안내309210  무료알파스캔 qhd ips 게이밍 모니터 q3s 포함 3종 추가 할인 안내
# 빅스마일데이 알파스캔 32인치 QHD IPS  게이밍 모니터 Q32G3S 포함 3종 할인 안내309210  무료알파스캔 qhd ips 게이밍 모니터 q3s 포함 3종 할인 안내
# 빅스마일데이 알파스캔 32인치 QHD IPS 게이밍 모니터 Q32G3S 포함 3종 할인 안내309210 무료배송알파스캔 qhd ips 게이밍 모니터 q3s 포함 3종 할인 안내
#
# Cluster 1086:
# 스틸시리즈 Arctis Nova 1 유선 게이밍 헤드셋 화이트
# 스틸시리즈 Arctis Nova 1 유선 헤드셋 리퍼
# 스틸시리즈 Arctis Nova 1 유선 게이밍 헤드셋 리퍼
#
# Cluster 1087:
# 홈스타 파워액션 뿌리는 곰팡이싹 500ml 4개
# 홈스타 파워액션 뿌리는 곰팡이싹 500ml x 4개 9810원무료
# 홈스타 파워액션 뿌리는 곰팡이싹 500ml x 4개 9810무료
# 홈스타 파워액션 뿌리는 곰팡이싹 500ml 4개 9810원무료 배송
# 홈스타 파워액션 뿌리는 곰팡이싹 500ml x 4개 9810원  무배
# 홈스타 파워액션 뿌리는 곰팡이싹 500ml x 4개 9810원 무료
#
# Cluster 1088:
# 다우니 햇볕 실내건조 플러스 섬유유연제 클린 1L 5개  200ml다우니 햇볕 실내건조 플러스 섬유유연제 클린
# 다우니 햇볕 실내건조 플러스 섬유유연제 클린 1L 5개  200ml 22970원  무료다우니 햇볕 실내건조 플러스 섬유유연제 클린
# 다우니 햇볕 실내건조 플러스 섬유유연제 클린 1L 5개
# 다우니 햇볕 실내건조 플러스 섬유유연제 클린 1L 5개 22950원 무료배송
#
# Cluster 1089:
# BBQ 비비큐 자메이카뱀파이어 통다리 바베큐 170g x 10팩 25900원무료
# BBQ 자메이카뱀파이어 통다리 바베큐 170g x 10팩 23900원무료
# BBQ 비비큐 자메이카뱀파이어 통다리 바베큐 170g x 10팩 23900원무료
#
# Cluster 1090:
# 틴도우 클리닝봇 자동 충전 물걸레 로봇청소기 BR151 119000원  무배
# 틴도우 클리닝봇 자동 충전 물걸레 로봇청소기 BR151
# 틴도우 클리닝봇 자동 충전 물걸레 로봇청소기 BR151 112800원 무료
#
# Cluster 1091:
# 안드로이드 Tetragon Puzzle Game 무료
# Tetragon Puzzle Game
# Tetragon Puzzle Game 무료
#
# Cluster 1092:
# 경기미 특등급 10kg 23541원무료
# 경기미 10kg 특등급 23541원무료
# 햅쌀 경기미 특등급 10kg 23541원무료
#
# Cluster 1093:
# 부채살 스테이크 200G 1팩  척아이롤 스테이크 200G 1팩  시즈닝 1팩부채살 스테이크  척아이롤 스테이크  시즈닝200g200g
# 부채살 스테이크 200G 1팩  척아이롤 스테이크 200G 1팩  시즈닝 1팩 9900원무료부채살 스테이크  척아이롤 스테이크  시즈닝200g200g
# 초이스등급 부채살 스테이크 200G 1팩  척아이롤 스테이크 200G 1팩  시즈닝 1팩 8970원무배초이스등급 부채살 스테이크  척아이롤 스테이크  시즈닝200g200g
#
# Cluster 1094:
# Edifier 에디파이어 스피커MR4 화이트 스튜디오 앰프 스피커 64470원무료
# Edifier 에디파이어 스피커MR4 화이트 스튜디오 앰프 스피커 당일출고59795원무료
# Edifier 에디파이어 스피커MR4 화이트 스튜디오 앰프 스피커 당일출고64610원무료
# Edifier 에디파이어 스피커MR4 화이트 스튜디오 앰프 스피커 당일출고59530원무료
# Edifier 에디파이어 스피커MR4 화이트 스튜디오 앰프 스피커
#
# Cluster 1095:
# Machinika Museum 무료 배포
# Machinika Museum 외 무료무료
# Machinika Museum
# 스팀 Machinika Museum 무료
# Machinika Museum 무료
#
# Cluster 1096:
# 가뿐한끼 현미밥 150g 30개
# 오뚜기 가뿐한끼 현미밥 150g 30개
# 오뚜기 가뿐한끼 현미밥 150g x 30개 토스페이
#
# Cluster 1097:
# 아카페라 카페라떼 바닐라라떼 5종 240ml 20개
# 아카페라 카페라떼 바닐라라떼 5종 240ml 20개 14900원무배
# 아카페라 카페라떼 바닐라라떼 5종 240ml 20개 15900원무배
#
# Cluster 1098:
# ATTACK SHARK X11마우스 RGB 3가지 모드 마우스 충전독 무소음29900원무료
# ATTACK SHARK X11마우스 RGB 3가지 모드 마우스 충전독 무소음
# ATTACK SHARK X11마우스 RGB 3가지 모드 마우스 충전독  포함
#
# Cluster 1099:
# Halnziye HY883 써멀 구리스 2g 11 외 2종
# Halnziye HY883 써멀 구리스 2g 11 증정행사 외 2종
# Halnziye HY883 써멀 구리스 2g 11 증정행사 외 3종
#
# Cluster 1100:
# 맥널티 제로칼로리 복숭아 아이스티 15L 12개입
# 맥널티 복숭아 아이스티 제로칼로리 음료 15L 12개입
# 맥널티 복숭아 아이스티 제로칼로리 음료 15L 12개입 16070원 무료
#
# Cluster 1101:
# 스팸 클래식 340g x6스팸 25라이트 340g x2 25750원무료스팸 클래식 x6스팸 25라이트 x2
# 스팸 클래식 340g x6스팸 25라이트 340g x2스팸 클래식 x6스팸 25라이트 x2
# 스팸 클래식 340g x6스팸 25라이트 340g x2 25750원  무료스팸 클래식 x6스팸 25라이트 x2
# 스팸 클래식 340g x6스팸 25라이트 340g x2 23620무료스팸 클래식 x6스팸 25라이트 x2
#
# Cluster 1102:
# 드래곤 에이지 인퀴지션  올해의 게임 에디션 무료무료
# 무료게임 드래곤 에이지 인퀴지션  올해의 게임 에디션
# 드래곤 에이지 인퀴지션  올해의 게임 에디션 무료 배포 시작
# 드래곤 에이지 인퀴지션  올해의 게임 에디션 무료배포
# 드래곤 에이지 인퀴지션  올해의 게임 에디션 무료
#
# Cluster 1103:
# 버드와이저 00 제로 330ml x 12캔변온 알루컵1개증정 14900원무료버드와이저 00 제로 변온 알루컵증정
# 버드와이저 00 제로 330ml x 12캔변온 알루컵1개증정 유클14040원무배버드와이저 00 제로 변온 알루컵증정
# 버드와이저 00 제로 330ml x 12캔변온 알루컵1개증정 14040원무료버드와이저 00 제로 변온 알루컵증정
#
# Cluster 1104:
# 100 Orange Juice 무료
# 100 Orange Juice 무료
# 스팀 100 Orange Juice 무료
#
# Cluster 1105:
# ENDLESS Legend 무료
# ENDLESS Legend 무료
# 스팀 ENDLESS Legend 무료
#
# Cluster 1106:
# HBAF 바프 아몬드 120g 5봉 골라담기 11930원무료
# HBAF 바프 아몬드 120g 5봉 골라담기
# HBAF 바프 아몬드 120g 5봉 골라담기 11930원무료 배송
#
# Cluster 1107:
# 맥스엘리트 MAXWELL COUNT 850W 80PLUS GOLD 풀모듈러 ATX 30 PCIE5 본체플랫멀티팩 외 다수  맥스엘리트 지마켓 빅스마일데이 한정 수량 행사
# 맥스엘리트 MAXWELL COUNT 850W 80PLUS GOLD 풀모듈러 ATX 30 PCIE5 본체플랫멀티팩 외 다수   지마켓 맥스엘리트 빅스마일데이 한정 수량 행사
# 맥스엘리트 MAXWELL COUNT 850W 80PLUS GOLD 풀모듈러 ATX 30 PCIE5 본체플랫멀티팩 외 다수  한정 수량 행사
# 맥스엘리트 MAXWELL COUNT 850W 80PLUS GOLD 풀모듈러 ATX 30 PCIE5 본체플랫멀티팩  온세일 한정 수량 행사
#
# Cluster 1108:
# 스너글 초고농축 섬유유연제 허거블 코튼 4L  26L  26L 카드 24570원무료스너글 초고농축 섬유유연제 허거블 코튼4l
# 스너글 초고농축 섬유유연제 허거블 코튼 4L  26L  26L 외 다양스너글 초고농축 섬유유연제 허거블 코튼4l
# 스너글 초고농축 섬유유연제 허거블 코튼 4L  26L  26L스너글 초고농축 섬유유연제 허거블 코튼4l
# 스너글 초고농축 섬유유연제 허거블 코튼 4L  26L  26L 토스 23913원무료스너글 초고농축 섬유유연제 허거블 코튼4l
#
# Cluster 1109:
# 마루찬 미도리의 타누키 튀김소바 101g 10개
# 마루찬 미도리의 타누키 튀김소바 101g 10개 19150원 무료
# 마루찬 미도리의 타누키 튀김소바 101g 10개
#
# Cluster 1110:
# 도브 바디워시 1L 3개  9950원무료
# 도브 바디워시 1L 3개 토스 9950원무료
# 도브 바디워시 1L 3개 9950원무료
# 도브 바디워시 1L  3 9950원무료
#
# Cluster 1111:
# 질레트 프로쉴드 파워 면도기 핸들1  면도날 4입 19810무료
# 질레트 프로쉴드 파워 면도기 핸들1  면도날 4입 19550원무료
# 질레트 프로쉴드 파워 면도기 핸들1  면도날 4입 미니젤 증정 토스 17900무료
# 질레트 프로쉴드 파워 면도기 핸들1  면도날 4입  미니젤 증정
# 질레트 프로쉴드 파워 면도기 핸들1  면도날 4입
#
# Cluster 1112:
# 닛신 야끼소바 스파이스 특제 소스 5개입 2개닛신 야끼소바 스파이스 특제 소스
# 닛신 야끼소바 스파이스 특제 소스 5개입 2개 13590원2500원닛신 야끼소바 스파이스 특제 소스
# 닛신 야끼소바 스파이스 특제 소스 5개입 2개 13590원 와우무료닛신 야끼소바 스파이스 특제 소스
#
# Cluster 1113:
# 차이파이 얼리버드 할인 TRN MEDUSA  1DD
# TRN MEDUSA  1DD 2999  차이파이 얼리버드 할인
# 차이파이 얼리버드 할인 TRN MEDUSA  1DD 2999 무료
#
# Cluster 1114:
# 타임딜  컴퍼니 오브 히어로즈3 19800원
# 컴퍼니 오브 히어로즈3 타임딜
# 컴퍼니 오브 히어로즈3  타임딜 19800원
#
# Cluster 1115:
# 원앙닭발 뼈없는 s라인 불닭발 230g x 5팩
# 원앙닭발 뼈없는 s라인 불닭발 230g x 5팩 24700원무료 배송
# 원앙닭발 S라인 뼈없는 불닭발 230g x 5팩 24700원무료배송
#
# Cluster 1116:
# 봉봉 포도 제로 340ml 24캔
# 봉봉 포도 제로 340ml x 24캔
# 봉봉 제로 340ml x 24캔
#
# Cluster 1117:
# MSI MAG274UPF 4K IPS HDR400 피벗 게이밍 모니터 무결점522120원무배
# MSI MAG274UPF 4K IPS HDR400 27인치 게이밍 모니터 무결점
# MSI MAG274UPF 4K IPS HDR400 피벗 게이밍 모니터
# MSI MAG274UPF 4K IPS HDR400 게이밍 모니터
#
# Cluster 1118:
# 종료 Android 신분증 사진 및 여권 사진 무료
# 안드로이드 신분증 사진 및 여권 사진 무료
# 신분증 사진 및 여권 사진
#
# Cluster 1119:
# 스파클 2L 24병
# 스파클 생수 2L 24병
# 스파클 생수 2L 24병 7900원무료
#
# Cluster 1120:
# 에픽게임즈 Farming Simulator 22 무료
# Farming Simulator 22 무료무료
# Farming Simulator 22 무료
#
# Cluster 1121:
# Warhammer 40000 Gladius  Relics of War 재배포 외 무료무료
# 에픽게임즈 Warhammer 40000 Gladius  Relics of War
# Warhammer 40000 Gladius  Relics of War 무료
# 스팀 Warhammer 40000 Gladius  Relics of War 무료
# Warhammer 40000 Gladius  Relics of War
#
# Cluster 1122:
# SK하이닉스 Platinum P41
# SK하이닉스 Platinum P41 2TB 해외구매
# SK하이닉스 Platinum P41 2TB
#
# Cluster 1123:
# Xiaomi Robotic Vacuum Cleaner E5 샤오미 스마트 로봇청소기
# Xiaomi Robotic Vacuum Cleaner E5 샤오미 스마트 로봇청소기 97800원  무료
# Xiaomi Robotic Vacuum Cleaner E5 샤오미 스마트 로봇청소기 112560원무료
#
# Cluster 1124:
# 안드로이드 고독한 해커 무료
# 고독한 해커 무료
# 고독한 해커
#
# Cluster 1125:
# 스탬프1장씩주는 생활잡화  알파 같은판매자 묶음배송가능 33
# 스탬프1장씩주는 생활잡화  알파 같은판매자 묶음배송가능 23
# 스탬프1장씩주는 생활잡화  알파 같은판매자 묶음배송가능 13
#
# Cluster 1126:
# LG생활건강 체험팩 모음 2500무료
# LG생활건강 체험팩 2500무료
# LG생활건강 체험팩 2500무료
#
# Cluster 1127:
# 아기물티슈 엘리트 올인원 A 엠보 캡형 72매 x 20팩 25900무료아기물티슈 엘리트 올인원 a 엠보 캡형
# 아기물티슈 엘리트 올인원 A 엠보 캡형 72매 x 20팩 26880무배아기물티슈 엘리트 올인원 a 엠보 캡형
# 아기물티슈 엘리트 올인원 A 엠보 캡형 72매 x 20팩  22500원  무료배송 아기물티슈 엘리트 올인원 a 엠보 캡형
# 지마켓 아기물티슈 엘리트 올인원 A 엠보 캡형 72매 x 20팩  22500원  무료배송 지마켓 아기물티슈 엘리트 올인원 a 엠보 캡형
#
# Cluster 1128:
# 육즙폭발 쟌슨빌 소시지 1670g 벌크형 1팩
# 육즙폭발 쟌슨빌 소시지 1670g 벌크형 1팩 20920원무료
# 육즙폭발 쟌슨빌 소시지 1670g 벌크형 1팩 20920원  무료
#
# Cluster 1129:
# 해피머니 5만원권 46200원
# 끌올 해피머니 5만원권 46200원 무료
# 해피머니 5만원권 46200원 무료
#
# Cluster 1130:
# 베이스어스 탁상 다용도 스탠드형 선풍기 7800원무료
# 베이스어스 탁상 다용도 스탠드형 선풍기
# 베이스어스 탁상 다용도 스탠드형 선풍기 8900원무료
# 베이스어스 탁상 다용도 스탠드형 선풍기 8900원무배
#
# Cluster 1131:
# 위메프 해피머니 5만원 46200무료
# 해피머니 5만원 46200무료
# 해피머니 5만원 46200무료
# 해피머니 5만원  46200무료
# 해피머니 5만원 46200무료
# 위메프 해피머니 5만원 46200무료
# 끌올 해피머니 5만원 46200무료
#
# Cluster 1132:
# 2021 우수소상공인 특별할인전 가격다양무배 20최대 3000원 할인
# G9  2021 우수소상공인 특별할인전 가격다양무배 20최대 5000원 할인
# 2021 우수소상공인 특별할인전 가격다양무배 20최대 5000원 할인
#
# Cluster 1133:
# 선진농협 새청무 보배진미쌀 10kg 21년 햅쌀 32900무료배송
# 선진농협 새청무 보배진미쌀 10kg 21년 햅쌀 32900무료배송 다시 풀렷네요 쿠폰적용시 17900무료배송
# 선진농협 새청무 보배진미쌀 10kg 21년 햅쌀 32900무료배송  쿠폰적용시 17900무료배송
#
# Cluster 1134:
# 웨스턴 디지털 WD BLUE 하드디스크 8TB HDD WD80EAZZ무배
# 웨스턴 디지털 WD BLUE 하드디스크 8TB HDD 153000원무배
# 웨스턴 디지털 WD BLUE 하드디스크 8TB HDD WD80EAAZ무배
# 웨스턴 디지털 WD BLUE 하드디스크 8TB HDD
# 웨스턴 디지털 WD BLUE 하드디스크 8TB
#
# Cluster 1135:
# 해피바스 필쏘굿 선샤인프리지아 굿나잇라벤더 760g 3개 9900원무배
# 해피바스 바디워시 필쏘굿 선샤인프리지아  굿나잇라벤더 760g 3개
# 해피바스 바디워시 선샤인프리지아  굿나잇라벤더 760g 3개
#
# Cluster 1136:
# 클라 파워클린 3in1 캡슐세제 실내건조 80개입코어캡슐세제 20개입 15740원무료클라 파워클린 3in1 캡슐세제 실내건조 코어캡슐세제
# 클라 파워클린 3in1 캡슐세제 실내건조 80개입코어캡슐세제 20개입클라 파워클린 3in1 캡슐세제 실내건조 코어캡슐세제
# 클라 파워클린 3in1 캡슐세제 80개입코어캡슐세제 20개입 15740원무료클라 파워클린 3in1 캡슐세제 코어캡슐세제
#
# Cluster 1137:
# 필립스 라떼클래식 2200 시리즈 전자동 에스프레소 커피 머신 399390원
# 필립스 라떼클래식 2200 시리즈 전자동 에스프레소 커피 머신
# 필립스 라떼클래식 2200 시리즈 전자동 에스프레소 커피 머신 314000카드할인시289240
#
# Cluster 1138:
# 비트 캡슐세제 42개입 2개  증정캡슐세제 15입 5입 3개  포린스 바이올렛 섬유유연제 21L 1개  일드겸용 290ml 1개  34900원  무료 배송 비트 캡슐세제  증정  포린스 바이올렛 섬유유연제  일드겸용21l290ml42개입2개15입5입
# 비트 실내건조 캡슐세제 42입 2개  증정캡슐세제 15입 5입 3개  포린스 바이올렛 섬유유연제 21L 1개  일드겸용 290ml 1개  34900원  무료 배송 비트 실내건조 캡슐세제  증정  포린스 바이올렛 섬유유연제  일드겸용21l290ml42입2개15입5입
# 비트 실내건조 캡슐세제 42입 1개  캡슐세제 42개입 1개  증정캡슐세제 15입 5입 3개  포린스 바이올렛 섬유유연제 21L 1개  일드겸용 290ml 1개  31900원  무료 배송 비트 실내건조 캡슐세제  캡슐세제  증정  포린스 바이올렛 섬유유연제  일드겸용21l290ml42입1개42개입1개15입5입
#
# Cluster 1139:
# 안드로이드 Rotaeno  로테이노 무료
# Rotaeno 로테이노 무료
# Rotaeno  로테이노 무료
# Rotaeno  로테이노 무료 게임
#
# Cluster 1140:
# 오르테 4in1 젖병세척기 319000원  무료배송
# 오르테 4in1 젖병세척기 319000원  무료
# 오르테 젖병세척기 319000원  무료배송
#
# Cluster 1141:
# 페넬로페 초고평량 85g 세느 캡형 70매 20팩26980원무료페넬로페 초고평량 세느 캡형
# 페넬로페 초고평량 85g 세느 캡형 70매 x 20팩페넬로페 초고평량 세느 캡형
# 페넬로페 초고평량 85g 세느 캡형 70매 20팩 26980원무배페넬로페 초고평량 세느 캡형
#
# Cluster 1142:
# 틴트 선글라스 5종 네이버 멤버쉽 반품무료
# 틴트 선글라스 5종 네이버 멤버쉽 반품무료 3400원 무료배송
# 틴트 선글라스 5종 네이버 멤버쉽 반품무료 3400원무료배송
#
# Cluster 1143:
# 해썹인증 전라도식 파김치 1kg 6900원무료
# 해썹인증 전라도식 파김치 1kg
# 해썹인증 전라도식 파김치 1kg 6900원 무료
#
# Cluster 1144:
# 스팀 Tell Me Why 무료
# Tell Me Why
# Tell Me Why 무료
#
# Cluster 1145:
# 오랄비 치실 글라이드 딥클린 40m 4개 7000원무료
# 오랄비 글라이드 딥클린 치실 40m x 4개
# 오랄비 글라이드 딥클린 치실 40m 6개
# 오랄비 글라이드 딥클린 40m 6개
#
# Cluster 1146:
# 갸스비 무빙러버 스파이키엣지 80g 11 12900원  무료
# 갸스비 헤어왁스 무빙러버 스파이키엣지 80g 11
# 갸스비 무빙러버 스파이키엣지 80g 11
#
# Cluster 1147:
# 와치아테 폴란드 수입멸균우유 35 1L 12입
# 와치아테 폴란드 수입멸균우유 35 1L 12입 15810원카드13920원무배
# 와치아테 폴란드 수입멸균우유 35 1L 12입 외 13950원무료
#
# Cluster 1148:
# 알파스캔 27인치 QHD FAST IPS 게이밍 모니터 Q27G2SD 포함 12모델 할인 안내296350  무료알파스캔 qhd fast ips 게이밍 모니터 q2sd 포함 12모델 할인 안내
# 가격호려쇼 알파스캔 27인치 QHD FAST IPS 게이밍 모니터 Q27G2SD 포함 12모델 할인 안내296350  무료가격호려쇼 알파스캔 qhd fast ips 게이밍 모니터 q2sd 포함 12모델 할인 안내
# 지마켓 알파스캔 27인치 QHD FAST 게이밍 모니터 Q27G2SD 포함 12모델 할인 안내296350  무료알파스캔 qhd fast 게이밍 모니터 q2sd 포함 12모델 할인 안내
#
# Cluster 1149:
# 신일 BLDC 에어서큘레이터 AIR S9 블루 SIFTS30RB 92310원카카오머니79130원무배
# 신일 BLDC 에어서큘레이터 AIR S9 블루
# 신일 BLDC 에어서큘레이터 AIR S9 블루 SIFTS30RB 78780원무료
# 신일 BLDC 에어서큘레이터 AIR S9 블루 SIFTS30RB
# 신일 BLDC 에어서큘레이터 AIR S9 블루 SIFTS30RB 88330원카드75410원무배
#
# Cluster 1150:
# 프레시누리 호주청정우 차돌박이 250g 4팩 KB카드
# 프레시누리 호주청정우 차돌박이 250g 4팩  13950원  무료
# 프레시누리 호주청정우 차돌박이 250g 4팩 KB카드 13950원 무료
#
# Cluster 1151:
# 명륜진사갈비 성인 1인 이용권 17000원
# 명륜진사갈비 성인 1인 이용권
# 명륜진사갈비 성인 1인 이용권 17900원무료
#
# Cluster 1152:
# 도브 포밍 핸드워시 딥너리싱 본품 240ml 2개  리필 430ml 2개 9730원무료도브 포밍 핸드워시 딥너리싱 본품  리필240ml
# 도브 포밍 핸드워시 딥너리싱 본품 240ml 2개  리필 430ml 2개도브 포밍 핸드워시 딥너리싱 본품  리필240ml
# 포밍 핸드워시 딥너리싱 본품 240ml 2개  리필 430ml 2개 9730원무료포밍 핸드워시 딥너리싱 본품  리필240ml
# 도브 포밍 핸드워시 딥너리싱 본품 240ml 2개  리필 430ml 2개 10710원무료도브 포밍 핸드워시 딥너리싱 본품  리필240ml
#
# Cluster 1153:
# 안드로이드 Equalizer  Bass Booster Pro 무료
# 안드로이드 Equalizer  Bass Booster pro 무료
# 안드로이드 Equalizer Bass Booster Pro 무료
# 안드로이드 Equalizer  Bass Booster Pro 무료
#
# Cluster 1154:
# 린나이 3구 빌트인 인덕션 299000원무료
# 린나이 3구 인덕션 299000원무료
# 린나이 인덕션 3구 299000원무료
#
# Cluster 1155:
# 오사카식 타코야끼 1kg50알  소스 풀 세트 11900원무배
# 오사카식 타코야끼 1kg50알  소스 풀 세트  11900원  무료 배송
# 오사카식 타코야끼 1kg50알  소스 풀 세트
#
# Cluster 1156:
# 구이요 소곱창 160g  소스
# 구이요 소곱창 160g  2팩 카카오페이
# 구이요 소곱창 160g
# 구이요 소곱창 160g x 2팩 무료배송
#
# Cluster 1157:
# 바리스타룰스 5종 250ml 10개 카카오 11900원무료
# 바리스타룰스 250ml 10개 11900원무료
# 바리스타룰스 5종 250ml 10개 11900원무료
#
# Cluster 1158:
# 드리미 X40 Ultra 올인원 로봇청소기 1649000원무료
# 드리미 X40 Ultra 로봇청소기 신제품 1649000원무료
# 드리미 x40 Ultra 로봇청소기 1649000원무료
# 드리미 X40 Ultra 로봇청소기 1649000원무료
#
# Cluster 1159:
# 소니 인존 게이밍 헤드셋 이어폰 할인 이벤트  헤드셋 인존 거치대 증정인존 H9 279000원 인존 H5 149000원 등  무료
# 소니 인존 게이밍 헤드셋 이어폰 할인 이벤트  헤드셋 인존 거치대 증정인존 H9 279000원 인존 H5 149000원 등  무료 내일까지
# 소니 인존 게이밍 헤드셋 이어폰 할인 이벤트  헤드셋 인존 거치대 증정인존 H9 279000원 인존 H5 149000원 등  무료  오늘 마지막일
#
# Cluster 1160:
# 신라면 5입  너구리 5입  짜파게티 10입 13150원무료배송신라면  너구리  짜파게티
# 신라면 5입  너구리 5입  짜파게티 10입 13150원무료신라면  너구리  짜파게티
# 신라면 10입  너구리 5입  짜파게티 5입 12550원무료배송신라면  너구리  짜파게티
#
# Cluster 1161:
# 폰타나 베이컨앤머쉬룸 크림파스타소스 430g 3개  증정스파게티면 500g 1개  15400원  무료 배송 폰타나 베이컨앤머쉬룸 크림파스타소스  증정430g
# 폰타나 베이컨앤머쉬룸 크림파스타소스 430g 3개  증정스파게티면 500g 1개  13100원  무료 배송 폰타나 베이컨앤머쉬룸 크림파스타소스  증정430g
# 폰타나 베이컨앤머쉬룸 크림파스타소스 430g 3개  증정스파게티면 500g 1개  15900원  무료 배송 폰타나 베이컨앤머쉬룸 크림파스타소스  증정430g
#
# Cluster 1162:
# Android SUI File Explorer PRO 무료
# SUI File Explorer Pro 무료
# 안드로이드  SUI File Explorer Pro 무료
#
# Cluster 1163:
# Knightfall A Daring Journey 무료
# 스팀 Knightfall A Daring Journey 무료
# 스팀 무료 Knightfall A Daring Journey
#
# Cluster 1164:
# 문경 오미자 닭갈비 500g 4개
# 문경 오미자 닭갈비 2kg
# 문경 오미자 닭갈비
#
# Cluster 1165:
# HAWKED  Singularity Pack 무료무료
# HAWKED  Singularity Pack 무료
# 스팀 무료 HAWKED  Singularity Pack
#
# Cluster 1166:
# 하남쭈꾸미 500g 5팩 외 토스 35136원무료
# 하남쭈꾸미 500g x 5팩 35136원무료
# 하남쭈꾸미 500g 5팩 외 카카오 35136원무료
#
# Cluster 1167:
# 광천김 간장에 찍어먹는 구운 곱창김 60g 180매 2봉 7290원무료광천김 간장에 찍어먹는 구운 곱창김
# 광천김 간장에 찍어먹는 구운 곱창김 180매 x 2봉 7600원무료광천김 간장에 찍어먹는 구운 곱창김
# 광천김 간장에 찍어먹는 구운 곱창김 60g 180매 x 2봉 6490원무료광천김 간장에 찍어먹는 구운 곱창김
#
# Cluster 1168:
# 영재컴퓨터 TKD Cycle7 베어본  수제 윤활 스위치 패키지 특가 사전 안내
# 영재컴퓨터 D3 TKD Cycle7 베어본  수제 윤활 스위치 패키지 특가 사전 안내
# 영재컴퓨터 D2 TKD Cycle7 베어본  수제 윤활 스위치 패키지 특가 사전 안내
#
# Cluster 1169:
# Naturehike 45L 100L 캠핑가방 748 104310일 배송  LED 버섯 소형 테이블 램프 72910일 배송naturehike 캠핑가방 led 버섯 소형 테이블 램프
# Naturehike 45L 100L 캠핑가방 748 104410일 배송  LED 버섯 소형 테이블 램프 72910일 배송naturehike 캠핑가방 led 버섯 소형 테이블 램프
# Naturehike 45L 100L 캠핑가방 749 104510일 배송  LED 버섯 소형 테이블 램프 72910일 배송naturehike 캠핑가방 led 버섯 소형 테이블 램프
# Naturehike 45L 100L 캠핑가방 750 104710일 배송  LED 버섯 소형 테이블 램프 72910일 배송naturehike 캠핑가방 led 버섯 소형 테이블 램프
# Naturehike 45L 100L 캠핑가방 749 104610일 배송  LED 버섯 소형 테이블 램프 72910일 배송naturehike 캠핑가방 led 버섯 소형 테이블 램프
#
# Cluster 1170:
# Cakeys Twisted Bakery 무료
# Cakeys Twisted Bakery 무료
# Cakeys Twisted Bakery 무료무료
# Cakeys Twisted Bakery 무료배포 무료무료
#
# Cluster 1171:
# ASOMETECH 65W GaN 고속 충전기 71610일 배송  Baseus 65W 차량용 충전기 96210일 배송asometech gan 고속 충전기 baseus 차량용 충전기
# ASOMETECH 65W GaN 고속 충전기 81710일 배송  Baseus 65W 차량용 충전기 97210일 배송asometech gan 고속 충전기 baseus 차량용 충전기
# ASOMETECH 65W GaN 고속 충전기 81810일 배송  Baseus 65W 차량용 충전기 97310일 배송asometech gan 고속 충전기 baseus 차량용 충전기
#
# Cluster 1172:
# Jaded 무료
# JADED 무료
# JADED 무료  무료
#
# Cluster 1173:
# Baseus 7in1 4K 60Hz USB C 허브 144210일 배송  ASOMETECH 65W GaN 고속 충전기 81810일 배송baseus 7in1 4k usb c 허브 asometech gan 고속 충전기
# Baseus 7in1 4K 60Hz USB C 허브 144310일 배송  ASOMETECH 65W GaN 고속 충전기 81810일 배송baseus 7in1 4k usb c 허브 asometech gan 고속 충전기
# Baseus 7in1 4K 60Hz USB C 허브 144710일 배송  ASOMETECH 65W GaN 고속 충전기 82010일 배송baseus 7in1 4k usb c 허브 asometech gan 고속 충전기
#
# Cluster 1174:
# 매직캔 반값 호환 리필봉투 280 20개입 20300원무료
# 매직캔 호환 리필봉투 280 20개입
# 매직캔 호환 반값 리필봉투 280 20개입
#
# Cluster 1175:
# 농심 짜파게티 범벅 미니 컵라면 70g 30개 15240원무료
# 농심 짜파게티 범벅 미니 컵라면 70g X 30개 15240원무료
# 농심 짜파게티 범벅 미니 컵라면 70g X 30개 16190원무료
# 농심 짜파게티 범벅 미니 컵라면 70g 30개
#
# Cluster 1176:
# 한성기업 크래미 몬스터크랩 72g x 20개 카드할인 15550원무료
# 한성기업 크래미 몬스터크랩 72g x 20개 15550원무료
# 크래미 몬스터크랩 72g 20개 15550원무료
#
# Cluster 1177:
# 홈런볼 41g 4개 와우 3490원무료
# 홈런볼 41g x 4개 3490원무료
# 홈런볼 초코 41g 4개 와우 3490원무료
# 홈런볼 초코 41g 4개 3490원무료 배송
#
# Cluster 1178:
# 메가커피 최대 23
# 메가커피 최대 23 할인 다양 무료
# 메가커피 최대 23 할인
#
# Cluster 1179:
# 신라면 5입  안성탕면 5입  짜파게티 더블랙 8입 12900원무료신라면  안성탕면  짜파게티 더
# 신라면 5입  안성탕면 5입  짜파게티 더블랙 8입 12910원무료신라면  안성탕면  짜파게티 더
# 신라면 5입  안성탕면 5입  짜파게티 더블랙 8입 12910원무배신라면  안성탕면  짜파게티 더
#
# Cluster 1180:
# 환타 제로 오렌지음료 355ml 24개 10380원무료
# 환타 제로 오렌지음료 355ml 24개 10380원무료
# 코카콜라 환타 제로 오렌지음료 355ml 24개 10380원무료
#
# Cluster 1181:
# 피죤 퓨어 뽀드득 주방세제 자몽향 3L
# 피죤 퓨어 뽀드득 자몽향 주방세제 3L 31 16900원무료
# 피죤 퓨어 뽀드득 자몽향 주방세제 3L 4개 16900원무료

# %%
with open('클러스터 결과 min_samples = 3.txt', 'w', encoding='utf-8') as file:
    for cluster_num in range(num_clusters):
        file.write(f"\nCluster {cluster_num}:\n")
        cluster_texts = clustered_texts[clustered_texts['cluster'] == cluster_num]['text'].values
        for text in cluster_texts:
            file.write(text + '\n')
