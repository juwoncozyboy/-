# %%
import pandas as pd
import numpy as np
from rapidfuzz import fuzz
from sklearn.base import BaseEstimator, ClusterMixin
from collections import defaultdict
from tqdm import tqdm

class MemoryEfficientDBSCAN(BaseEstimator, ClusterMixin):
    def __init__(self, eps=0.5, min_samples=5):
        self.eps = eps
        self.min_samples = min_samples

    def fit(self, X):
        self.labels_ = np.full(len(X), -1)
        cluster_label = 0
        for i in tqdm(range(len(X)), desc="Clustering"):
            if self.labels_[i] != -1:
                continue
            neighbors = self._region_query(X, i)
            if len(neighbors) < self.min_samples:
                self.labels_[i] = -1  # Noise
            else:
                self._expand_cluster(X, i, neighbors, cluster_label)
                cluster_label += 1
        return self

    def _region_query(self, X, point_idx):
        return [i for i in range(len(X)) if i != point_idx and fuzz.ratio(X[point_idx], X[i]) / 100.0 >= 1 - self.eps]

    def _expand_cluster(self, X, point_idx, neighbors, cluster_label):
        self.labels_[point_idx] = cluster_label
        i = 0
        while i < len(neighbors):
            neighbor = neighbors[i]
            if self.labels_[neighbor] == -1:
                self.labels_[neighbor] = cluster_label
                new_neighbors = self._region_query(X, neighbor)
                if len(new_neighbors) >= self.min_samples:
                    neighbors.extend(new_neighbors)
            i += 1

# 1. 데이터 로드
data = pd.read_csv('community-posts.csv')

# 2. 중복 및 빈 문자열 제거
data['product_name'] = data['title'].str.strip().str.lower()
data = data[data['product_name'] != '']
data = data.drop_duplicates(subset=['product_name'])

# 3. 메모리 효율적인 DBSCAN 클러스터링
dbscan = MemoryEfficientDBSCAN(eps=0.2, min_samples=2)
labels = dbscan.fit(data['product_name'].tolist()).labels_

# 4. 클러스터링 결과를 데이터프레임에 추가
data['cluster'] = labels

# 5. 클러스터별 대표 항목 추출 함수
def get_cluster_representatives(data):
    cluster_representatives = defaultdict(list)
    
    for _, row in tqdm(data.iterrows(), total=len(data), desc="Extracting representatives"):
        cluster_id = row['cluster']
        if cluster_id != -1:
            cluster_representatives[cluster_id].append(row['product_name'])
    
    results = []
    for cluster_id, items in cluster_representatives.items():
        representative = max(items, key=lambda x: sum(fuzz.ratio(x, y) for y in items))
        results.append((cluster_id, representative, items))
    
    return results

# 6. 클러스터별 대표 항목 추출
cluster_representatives = get_cluster_representatives(data)

# 결과 출력
for cluster_id, representative, cluster_items in cluster_representatives:
    print(f"\n클러스터 {cluster_id}:")
    print(f"대표 항목: {representative}")
    print("클러스터 내 항목 수:", len(cluster_items))
    print("클러스터 내 항목 (최대 10개):")
    print(cluster_items[:10])
# Out:
# Clustering: 100%|██████████| 96207/96207 [53:40<00:00, 29.87it/s]
# Extracting representatives: 100%|██████████| 96207/96207 [00:02<00:00, 45812.08it/s]
# 클러스터 0:
# 대표 항목: 하림 밥싸먹는닭가슴살 슬라이스햄
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['하림 밥싸먹는 닭가슴살 슬라이스 햄', '하림 밥싸먹는닭가슴살 슬라이스햄', '공식 하림 밥싸먹는 닭가슴살 슬라이스 햄', '하림 밥싸먹는닭가슴살슬라이스햄']
#
# 클러스터 1:
# 대표 항목: 베베숲 시그니처 위드블루 캡
# 클러스터 내 항목 수: 39
# 클러스터 내 항목 (최대 10개):
# ['베베숲 물티슈 시그니처', '베베숲 시그니처 캡', '베베숲 sm 고평량 시그니처 위드블루 캡 +휴대용', '베베숲 시그니처 위드그린 그린 휴대용', '리벤스 시그니처 물티슈', '베베숲 물티슈 시그니처캡', '베베숲 시그니처 블루 슬림 캡', '베베숲 시그니처 블루 에코 캡형 아기물티슈', '베베숲 시그니처 위드블루', '베베숲 시그니처위드블루 +그린 휴대용']
#
# 클러스터 22:
# 대표 항목: 청정원 파스타소스 +면
# 클러스터 내 항목 수: 73
# 클러스터 내 항목 (최대 10개):
# ['청정원 로제 스파게티소스 x 페이', '청정원 로제 스파게티소스', '폰타나 파스타소스 +면증정', '청정원 파스타소스', '청정원 파스타소스 x+소스 면', '청정원 비스크 로제 스파게티소스', '청정원 스파게티소스 + 면', '청정원 스파게티소스 + 스파게티면', '청정원 파스타 소스 + 스파게티면', '청정원 프리미엄파스타소스 +면 or 파우치']
#
# 클러스터 2:
# 대표 항목: 광동 비타500 스파클링
# 클러스터 내 항목 수: 37
# 클러스터 내 항목 (최대 10개):
# ['비타500제로 스파클링 유자', '광동 비타500 칼슘', '비타500 스파클링제로 미니', '비타500 제로스파클링', '비타500 제로 스파클링 유자맛', '품절 비타500 제로스파클링유자', '비타500 제로 스파클링', '광동제약 비타500', '광동 비타500', '비타500 제로 스파클링 유자']
#
# 클러스터 3:
# 대표 항목: 로지텍 g pro x superlight 무선게이밍마우스
# 클러스터 내 항목 수: 21
# 클러스터 내 항목 (최대 10개):
# ['g pro x superlight 2 지슈라2', '로지텍g pro x superlight 2', '마우스 g pro x superlight2 최대', '티몬 g pro x superlight 2', 'g304 및 g pro x superlight', '로지텍 gpro x superlight 게이밍마우스', '로지텍 g pro x superlight 무선게이밍마우스', '로지텍코리아 pro x superlight 무선 게이밍 마우스', '로지텍 g304 g pro x superlight', '로지텍 pro x superlight 무선 게이밍마우스']
#
# 클러스터 4:
# 대표 항목: 티젠 콤부차 200스틱+보틀증정
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['티젠 콤부차 140스틱+보틀증정', '티젠 콤부차 200스틱 + 보틀증정', '티젠 콤부차 200스틱+보틀증정']
#
# 클러스터 5:
# 대표 항목: 이마트트레이더스 5만원권
# 클러스터 내 항목 수: 62
# 클러스터 내 항목 (최대 10개):
# ['이마트 트레이더스권', '이마트 상품권 5만원권 잔액관리형', '이마트트레이더스 여름나기 5만원권', '이마트트레이더스 5만 잔액관리형', '이마트트레이더스 5만원권 잔액관리형', '이마트트레이더스 5만원 잔액관리형', '이마트트레이더스 5만원권', '이마트 5만원권 잔액관리형', '이마트 잔액관리형 5만원', '이마트 트레이더스 5만원권']
#
# 클러스터 6:
# 대표 항목: 사조 참치액
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['사조 참치', '사조 참치액', '사조참치', '사조 고추참치', '사조참치액', '사조대림 참치액']
#
# 클러스터 7:
# 대표 항목: 아이스 넥쿨러
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['아이스 넥쿨러', '아이스넥쿨러', '울프 아이스 넥쿨러']
#
# 클러스터 8:
# 대표 항목: 갤럭시탭 s9 fe
# 클러스터 내 항목 수: 296
# 클러스터 내 항목 (최대 10개):
# ['갤럭시탭s9울트라 wifi', '갤럭시탭 s9 fe wifi', '갤럭시탭aifi', '갤럭시 탭sifi', '갤럭시탭 s9울트라 wifi', '갤럭시 a35 자급제', '갤럭시탭 s9fe 플러스 wifi', '전자 갤럭시탭 s9 fe wifi', '전자 갤럭시탭 s9 wifi', '갤럭시 z플립5 z폴드5 자급제']
#
# 클러스터 9:
# 대표 항목: 쏜리서치 투퍼데이 종합비타민 60캡슐
# 클러스터 내 항목 수: 27
# 클러스터 내 항목 (최대 10개):
# ['쏜리서치 투퍼데이 외 기타', '쏜리서치 종합비타민 투퍼데이 60캡슐', '쏜리서치 투퍼데이 60캡슐', '쏜리서치 베이직 뉴트리언트 투퍼데이 60캡슐', '쏜리서치 베이직 뉴트리언트 투퍼데이 60캡슐 페이', '쏜리서치 투퍼데이 종합비타민 60캡슐', '쏜리서치 투퍼데이 x 당', '쏜리서치 베이직 투퍼데이 60캡슐', '쏜리서치 종합비타민 60캡슐', '쏜리서치 투퍼데이']
#
# 클러스터 10:
# 대표 항목: 깨끗한나라 순수 프리미엄 화장지
# 클러스터 내 항목 수: 107
# 클러스터 내 항목 (최대 10개):
# ['헬로 순수 라벤더 3겹 천연펄프 화장지', '오늘 천연펄프 3겹', '천연펄프 무형광 숨 프리미엄 3겹', '한예지 천연펄프 화장지', '100 천연펄프 숨 프리미엄 3겹', '순수네이처 천연펄프 화장지', '한예지 천연펄프 페르니 클린앤소프트', '천연펄프 숨 프리미엄 3겹', '깨끗한나라 순수 시그니처 브라운 화장지 + 사은품', '깨끗한나라 프리미엄 3겹 화장지']
#
# 클러스터 11:
# 대표 항목: 일리 네스프레소 호환 100캡슐
# 클러스터 내 항목 수: 95
# 클러스터 내 항목 (최대 10개):
# ['일리 네스프레소 호환 캡슐', '일리 네스프레소 호환 캡슐 커피 개당 398원', '일리 네스프레소 호환 캡슐 커피 100캡슐', '할리스 네스프레소 호환 캡슐커피', '스타벅스 네스프레소 캡슐커피 14종 10캡슐+ 머그컵 증정', '일리 네스프레소 캡슐 개당 380원', '일리 네스프레소 100캡슐', '일리 네스프레소 캡슐', '카누 네스프레소 호환 캡슐커피 9종', '던킨 네스프레소 호환 캡슐커피 100캡슐 5종']
#
# 클러스터 12:
# 대표 항목: 연세우유 뼈칼슘두유
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['연세우유 고칼슘두유', '연세유업 고칼슘두유', '연세우유 뼈칼슘두유', '연세 뼈칼슘두유']
#
# 클러스터 13:
# 대표 항목: 담양 대숲맑은 담양쌀 특등급
# 클러스터 내 항목 수: 17
# 클러스터 내 항목 (최대 10개):
# ['특등급 대숲맑은 담양쌀', '담양 대숲맑은 담양쌀 특등급', '대숲 맑은 담양쌀 특등급', '푸드페어 담양 대숲맑은 담양쌀 특등급', '산 대숲맑은 담양쌀', '대숲맑은 담양쌀', '대숲맑은 담양쌀 새청무특등급', '햅쌀 대숲맑은 담양쌀', '대숲맑은 담양쌀 특등급', '대숲맑은 담양쌀 새청무 특등급']
#
# 클러스터 14:
# 대표 항목: 건조기용 섬유유연제 시트
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['건조기용 피죤 섬유유연제 시트', '피죤 건조기용 섬유유연제 시트', '건조기용 섬유유연제 시그니처', '건조기용 섬유유연제 시트', '건조기용 섬유유연제시트', '닥터퓨리 건조기용 섬유유연제 시트']
#
# 클러스터 15:
# 대표 항목: 비플레인 녹두 약산성 클렌징폼
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['비플레인 녹두 약산성 클렌징폼', '약산성 클렌징폼', '비플레인 녹두 약산성 클렌징폼 기획세트', '녹두 약산성 클렌징폼']
#
# 클러스터 16:
# 대표 항목: 올반 찰핫도그 +크런치 핫도그
# 클러스터 내 항목 수: 27
# 클러스터 내 항목 (최대 10개):
# ['올반 찰핫도그', '올반 핫도그 찰핫도그+크런치핫도그', '올반 찰핫도그+크런치핫도그', '올반 크런치 찰 핫도그', '올반 찰 핫도그', '올반 찰핫도그 +크런치핫도그 삼롯농비하스', '올반 핫도그', '크런치 찰핫도그5종', '슈퍼크런치 찰 핫도그', '올반 찰핫도그 +크런치핫도그']
#
# 클러스터 17:
# 대표 항목: 골드 카무트 효소
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['골드 카무트 효소', '골드 카무트 곡물 효소', '카무트 효소']
#
# 클러스터 18:
# 대표 항목: 노르웨이 슈페리어등급 생연어
# 클러스터 내 항목 수: 31
# 클러스터 내 항목 (최대 10개):
# ['노르웨이 생연어 통살', '두팜 노르웨이 생연어 필렛', '티프레쉬 노르웨이 생연어 슬라이스', '노르웨이 슈페리어등급 생연어 슬라이스', '노르웨이 생연어 몸뱃살', '노르웨이 생연어 필렛', '프레쉬몰 노르웨이 슈페리어 등급 생연어', '노르웨이 생연어 슬라이스', '노르웨이 슈페리어급 딥스킨 생연어', '노르웨이 생연어']
#
# 클러스터 19:
# 대표 항목: 본죽 메추리알 장조림
# 클러스터 내 항목 수: 14
# 클러스터 내 항목 (최대 10개):
# ['본죽 메추리알 장조림 x4', '마이산 정기담은 메추리알 장조림', '메추리알 장조림', '메추리알장조림', '본죽 메추리알 장조림', '늘푸른 메추리알 장조림', '진안 늘푸른 메추리알 장조림', '본죽 메추리알 장조림 등등', '대용량 메추리알 장조림', '본죽 메추리알장조림']
#
# 클러스터 39:
# 대표 항목: 반납작 대극천 복숭아 소과
# 클러스터 내 항목 수: 8
# 클러스터 내 항목 (최대 10개):
# ['황도복숭아 중소과', '반납작 대극천 복숭아', '반납작 대극천복숭아', '천도복숭아 중소과', '대극천 복숭아 특등급 중소과', '반납작 대극천 복숭아 로얄과', '대극천 복숭아 중소과', '반납작 대극천 복숭아 소과']
#
# 클러스터 20:
# 대표 항목: 브라더 dcpt720dw 무한잉크복합기
# 클러스터 내 항목 수: 20
# 클러스터 내 항목 (최대 10개):
# ['dcpt720dw 정품 무한잉크복합기', '브라더 dcpt720dw 복합기', '브라더 dcpt720dw 무한잉크복합기', '브라더 dcpt720dw 정품 무한잉크복합기', '브라더 복합기 dcpt720dw', '브라더 dcp720dw 정품무한잉크복합기', '브라더 dcpt720dw 정품무한잉크복합기', 'dcpt720dw 무한잉크복합기', '브라더 dcpt720dw 프린터', '브라더 dcpt 정품 무한잉크복합기']
#
# 클러스터 21:
# 대표 항목: 햇 수미감자 특
# 클러스터 내 항목 수: 27
# 클러스터 내 항목 (최대 10개):
# ['햇 감자 중', '수미감자 대', '수미감자', '햇 수미감자', '햇 수미 감자 특대혼합', '햇감자', '햇 수미감자 왕특', '서산 햇감자 중', '햇감자 중', '감자 서산 햇 감자 중']
#
# 클러스터 23:
# 대표 항목: 스테비아 대추방울토마토
# 클러스터 내 항목 수: 89
# 클러스터 내 항목 (최대 10개):
# ['스테비아 대추방울토마토', '대추방울토마토', '건달마토 달콤한 스테비아방울토마토', '대추 방울토마토', '스테비아 방울토마토', '정품 스테비아방울토마토', '망고향 스윗 스테비아 방울토마토', '대추방울토마토 로얄과 중과', '부산 흑대출방울 토마토', '대추방울토마토 12번 로얄과']
#
# 클러스터 24:
# 대표 항목: 사세 치킨가라아게
# 클러스터 내 항목 수: 15
# 클러스터 내 항목 (최대 10개):
# ['치킨가라아게', '맘스치킨 가라아게', '사세 치킨 가라아게', '사세 가라아게', '사세 치킨가라아게 x 3', '사세 치킨가라야게', '사세 치킨가라아게', '가라아게', '뉴골든치킨 가라아게', '사세 치킨 가라아게 체험딜']
#
# 클러스터 25:
# 대표 항목: 네이쳐리빙 모던 스윙 3단 빨래바구니
# 클러스터 내 항목 수: 9
# 클러스터 내 항목 (최대 10개):
# ['네이쳐리빙 모던 스윙 3단 빨래바구니', '스윙 2단 빨래바구니', '네이쳐리빙 모던 스윙 3단 빨래 바구니', '모던 스윙 3단 빨래바구니', '네이쳐리빙 모던 3단 빨래바구니', '네이쳐리빙 모던 트롤리 스윙 3단 빨래바구니', '네이쳐리빙 모던 3단 스윙 빨래바구니', '네이쳐리빙 모던 스윙 3단빨래바구니', '모던 트롤리 스윙 3단 빨래바구니']
#
# 클러스터 26:
# 대표 항목: 100 전라도 포기김치
# 클러스터 내 항목 수: 82
# 클러스터 내 항목 (최대 10개):
# ['전라도식 열무김치', '100 전라도식 열무김치', '전라도 겉절이', '종가 전라도 포기김치', '전라도 얼갈이 겉절이', '전라도 총각김치 재료', '전라도 열무김치', '전라도식 얼갈이김치', '전라도 총각김치', '100 당일제조 전라도 포기김치']
#
# 클러스터 27:
# 대표 항목: 오디세이 g5 s32cg510 게이밍 모니터
# 클러스터 내 항목 수: 185
# 클러스터 내 항목 (최대 10개):
# ['오디세이g5 게이밍모니터', '십일절 2024 오디세이 g5 s27cg550 게이밍 모니터', '전자 오디세이 g4 s27bg400 게이밍 모니터', '오디세이 게이밍모니터 특가행사안내', 'g5 s32cg550 qhd', '오디세이 g4 s25bg400 62cm 게이밍 모니터', '전자 오디세이 s32dg500 게이밍모니터', '전자 오디세이 g5 s32dg500 81cm 게이밍모니터', 'g5 c54t qhd 모니터', '가격호러쇼 전자 오디세이 g5 게이밍모니터 특가 행사']
#
# 클러스터 167:
# 대표 항목: 춘천 닭갈비
# 클러스터 내 항목 수: 45
# 클러스터 내 항목 (최대 10개):
# ['춘천골목닭갈비', '홍익닭갈비', '참닭 춘천식 닭갈비', '통닭다리 순살 춘천닭갈비', '명물 춘천 닭갈비', '참닭 춘천형 닭갈비', '춘천 닭갈비', '춘천닭갈비', '우리집 춘천 왕 닭갈비', '춘천 국물 닭갈비']
#
# 클러스터 28:
# 대표 항목: 햇 호두 14태
# 클러스터 내 항목 수: 7
# 클러스터 내 항목 (최대 10개):
# ['산 호두 14태', '햇 호두 14태 + 산', '호두 14태', '햇 호두 14태', '우고래빗 산 햇 호두 14태', '산 햇 호두 14태', '호두 14태 + 산']
#
# 클러스터 29:
# 대표 항목: cj햇반 백미밥
# 클러스터 내 항목 수: 32
# 클러스터 내 항목 (최대 10개):
# ['cj햇반 백미', '햇반 백미', '햇반 +잡곡밥', 'cj 햇반 현미밥', '햇반 백미밥', '햇반 백미밥 흑미밥', 'cj제일제당 햇반', '햇반 +흑미밥', '햇반 x+흑미잡곡', '햇반 x+흑미잡곡밥']
#
# 클러스터 3167:
# 대표 항목: 천연펄프 무표백 그루 키친타올
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['천연펄프 그루 무표백 키친타올', '천연펄프 무표백 그루 키친타올', '삼정펄프 무표백 그루 키친타올']
#
# 클러스터 1326:
# 대표 항목: 삼익가구 어썸 통세라믹 용 원목 식탁세트
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['어썸 통세라믹 용 원목 식탁세트', '삼익가구 어썸 통세라믹 용 원목 식탁세트', '삼익가구 어썸 통세라믹 원목 식탁 테이블']
#
# 클러스터 490:
# 대표 항목: 칼슘 마그네슘 아연 비타민d
# 클러스터 내 항목 수: 33
# 클러스터 내 항목 (최대 10개):
# ['칼슘 앤 마그네슘 비타민d 아연 베이직', '닥터포이 칼슘 마그네슘 아연 비타민d 외', '슈퍼파워 칼슘+마그네슘+아연+비타민d', '칼슘 마그네슘 비타민d 옵티msm', '칼슘 마그네슘 아연 비타민d', '칼슘+마그네슘+아연+비타민d', '안심 칼슘 마그네슘 비타민d', '캐나다 인테로 칼슘 마그네슘 아연 비타민d', '옵티msm 칼슘 마그네슘 비타민d', '인테로 칼슘 마그네슘 아연 비타민d']
#
# 클러스터 30:
# 대표 항목: 퍼실 딥클린 플러스 라벤더
# 클러스터 내 항목 수: 11
# 클러스터 내 항목 (최대 10개):
# ['헨켈 퍼실 딥클린 플러스 라벤더 + 카페', '헨켈 퍼실 딥클린 플러스 라벤더 +퍼실', '퍼실 딥클린 플러스 라벤더+증정품', '퍼실 딥클린 플러스 라벤더', '퍼실 딥클린플러스 라벤더 +버넬', '퍼실 딥클린 라벤더', '헨켈 퍼실 딥클린 플러스 라벤더', '퍼실 딥클린 플러스 라벤더 x+ 증정', '퍼실 딥클린 라벤더 +추가', '헨켈 퍼실 딥클린 라벤더']
#
# 클러스터 501:
# 대표 항목: 피죤 습기제로 제습제
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['피죤 습기제로 제습제 24p', '피죤 습기제로 제습제', '피죤 습기제로 대용량 제습제']
#
# 클러스터 2305:
# 대표 항목: 포카칩 오리지날어니언
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['포카칩 햇감자 오리지날어니언', '포카칩 오리지널 + 어니언', '포카칩 오리지날어니언']
#
# 클러스터 31:
# 대표 항목: 페브리즈 섬유탈취제 +다우니세제 증정
# 클러스터 내 항목 수: 13
# 클러스터 내 항목 (최대 10개):
# ['페브리즈 섬유탈취제 용기형 다우니실내건조 향 + 세제 증정', '페브리즈 섬유탈취제 용기형 다우니실내건조향 + 다우니세제', '페브리즈 섬유 탈취제 다우니 실내건조향', '페브리즈 섬유탈취제 다우니실내건조 향', '페브리즈 공기탈취제 에어 +다우니세제 증정', '페브리즈 섬유탈취제 +다우니 유연제 +보틀슬리브', '페브리즈 섬유탈취제 + 다우니', '페브리즈 섬유탈취제 +다우니세제 증정', '페브리즈 섬유탈취제 + 다우니 + 보틀슬리브', '페브리즈 공기탈취제 +다우니세탁세제 증정']
#
# 클러스터 32:
# 대표 항목: 보꼬네 모짜렐라 치즈
# 클러스터 내 항목 수: 11
# 클러스터 내 항목 (최대 10개):
# ['보꼬네 모짜렐라 치즈', '보꼬네 모짜렐라치즈', '보꼬네 모짜렐라 치즈 x 페이', '모짜렐라 슈 치즈', '보꼬네 모짜렐라 피자치즈', '모짜렐라 피자치즈', '보꼬네 모짜렐라트리플치즈', '제니코 모짜렐라 슈 치즈', '보꼬네 모짜렐라', '제니코 모짜렐라 치즈']
#
# 클러스터 41:
# 대표 항목: 100 착즙 땡모반 생수박 주스
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['땡모반 수박 주스', '착즙 생수박 주스', '착즙 땡모반 생수박 주스', '100 착즙 생수박 주스', '100 착즙 땡모반 수박 주스', '100 착즙 땡모반 생수박 주스']
#
# 클러스터 33:
# 대표 항목: 해태 오예스 미니
# 클러스터 내 항목 수: 5
# 클러스터 내 항목 (최대 10개):
# ['해태 오예스 미니', '해태제과 오예스 미니', '해태 오예스', '해태제과 오예스', '오예스 미니']
#
# 클러스터 34:
# 대표 항목: 진선미 포기김치
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['진선미 포기김치', '진미령의 포기김치', '진선미 맛김치']
#
# 클러스터 1920:
# 대표 항목: 송주불냉면 반반세트
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['송주불냉면 냉면세트', '송주불냉면 반반 10분 세트', '송주불냉면 반반세트']
#
# 클러스터 35:
# 대표 항목: 육식토끼 닭가슴살 소세지
# 클러스터 내 항목 수: 35
# 클러스터 내 항목 (최대 10개):
# ['육식토끼 소스닭가슴살 +소세지', '육식토끼 소스닭가슴살', '육식토끼 소스닭 3종 혼합', '육식토끼 닭가슴살 소세지', '육식토끼 소스 닭가슴살', '육식토끼 소세지소스닭', '육식토끼 닭가슴살 6종', '육식토끼 소스닭한입닭가슴살큐브', '육식토끼 소스닭닭가슴살소세지', '육식토끼 닭가슴살 소세지 훈제후랑크 등']
#
# 클러스터 1973:
# 대표 항목: 특등급 담양쌀
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['특등급 추청쌀', '특등급 담양쌀', '특등급 쌀', '특등급 담양 담양쌀']
#
# 클러스터 36:
# 대표 항목: toocki cc 초고속 충전기 케이블
# 클러스터 내 항목 수: 244
# 클러스터 내 항목 (최대 10개):
# ['toocki 충전기 + 케이블 2포트 kr', 'toocki gan 3포트 접지형 충전기', 'c타입 메탈케이블', 'toocki gan pps 3포트 접지형 디스플레이 초고속 멀티충전기 + 케이블', 'toocki c to c pd bps 초고속 충전 케이블', 'toocki 투키 pps pd30 c타입 3포트 충전기', 'toocki 7a 고속충전케이블', 'toocki gan pps 3포트 접지형 디스플레이 초고속 멀티충전기', 'toocki gan pps 3포트 접지형 디스플레이 c타입 초고속 멀티 충전기', 'toocki gan 고속충전기']
#
# 클러스터 2393:
# 대표 항목: 강남면옥 사골만둣국
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['강남면옥 사골만두칼국수', '강남면옥 사골만둣국 갈비탕', '강남면옥 사골만둣국']
#
# 클러스터 37:
# 대표 항목: 원할머니 명품 육개장
# 클러스터 내 항목 수: 11
# 클러스터 내 항목 (최대 10개):
# ['원할머니 육개장', '원할머니 육개장+얼큰순대국', '원할머니 명품 육개장', '원할머니 명품육개장', '원할머니 명품 육개장 x 최종', '원할머니 명품 육개장 최종할인가', '원할머니 육개장+순대국', '끌올 원할머니 명품 육개장+얼큰 순대국', '원할머니 육개장 페이', '원할머니 명품육개장 페이']
#
# 클러스터 38:
# 대표 항목: kf94 새부리형 마스크
# 클러스터 내 항목 수: 121
# 클러스터 내 항목 (최대 10개):
# ['와이드핏 kf94새부리형마스크', '유앤미 kf94 새부리형 마스크', '새부리형 kf94 대형 마스크', 'kf94 새부리형 마스크', '꿈에그린 라이트핏 kf94 새부리형', 'kf94 새부리형 마스크 소형 kf80 대형', '새부리형 대형 kf94마스크', '닥터로드 kf94 새부리형 마스크', '새부리형 kf94마스크', '윤선생 kf94 마스크']
#
# 클러스터 40:
# 대표 항목: 축박람회 코리아빌드 입장권 사전등록시
# 클러스터 내 항목 수: 5
# 클러스터 내 항목 (최대 10개):
# ['건축박람회 코리아빌드 입장권 사전등록시', '축박람회 코리아빌드 입장권 사전등록시', '축박람회 코리아빌드 입장권', '건축박람회입장권 사전등록', '축박람회 입장권 사전등록시']
#
# 클러스터 42:
# 대표 항목: 홍대쭈꾸미 약간매운맛
# 클러스터 내 항목 수: 10
# 클러스터 내 항목 (최대 10개):
# ['홍대쭈꾸미 약간매운맛', '홍대쭈꾸미 약간 매운맛', '홍대주꾸미 약간매운맛 매운맛', '홍대쭈꾸미 약간매운맛 +매운맛', '홍대쭈꾸미 약간매운맛매운맛', '홍대쭈꾸미 매운맛 약간매운맛', '홍대주꾸미 약간매운맛', '홍대쭈꾸미 약간매운맛 +치즈', '홍대 주꾸미 x 매운맛약간매운맛', '홍대쭈꾸미 매운맛약간매운맛']
#
# 클러스터 43:
# 대표 항목: 베지밀 뼈에좋은 칼슘 두유 검은콩
# 클러스터 내 항목 수: 5
# 클러스터 내 항목 (최대 10개):
# ['뼈에좋은 칼슘두유검은콩', '베지밀 뼈에좋은 칼슘 두유 검은콩', '베지밀 뼈에좋은 검은콩', '뼈에좋은두유 검은콩', '베지밀 뼈에좋은 칼슘두유 검은콩깨쌀']
#
# 클러스터 44:
# 대표 항목: 새청무쌀 상등급단일품종
# 클러스터 내 항목 수: 21
# 클러스터 내 항목 (최대 10개):
# ['새청무 특등급', '장흥 정남진 새청무쌀 상등급', '장흥 정남진 새청무 쌀', '단일품종 상등급 쌀 2종류', '새청무쌀 상등급', '장흥 정남진 새청무 쌀 외', '새청무 상등급', '새청무쌀 단일품종 상등급', '새청무 쌀 상등급단일품종', '쌀 단일품종 상등급 2종']
#
# 클러스터 635:
# 대표 항목: 노스페이스 베이직 반팔 티셔츠
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['노스페이스 코튼 베이직 반팔 티셔츠', '노스페이스 베이직 반팔 티셔츠', '노스페이스 눕시 ex 반팔 티셔츠 4컬러', '노스페이스 눕시 반팔 티셔츠']
#
# 클러스터 45:
# 대표 항목: 풀무원 아삭 포기김치
# 클러스터 내 항목 수: 9
# 클러스터 내 항목 (최대 10개):
# ['풀무원 아삭 포기김치', '풀무원 사계절 아삭 포기김치', '풀무원 생산직송 톡톡 포기김치', '풀무원 김치', '풀무원 사계절 아삭 포기김치 스클', '풀무원 포기김치', '사계절 아삭 포기김치', '풀무원 아삭 포기김치 외', '풀무원 톡톡 포기김치']
#
# 클러스터 2302:
# 대표 항목: toocki 데스크탑 고속 충전 usb c 타입 충전기 gan 5in 1
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['toocki 데스크탑 고속 충전 gan 5in 1', 'toocki 데스크탑 고속 충전 usb c 타입 충전기', 'toocki 데스크탑 고속 충전 usb c 타입 충전기 gan 5in 1']
#
# 클러스터 1894:
# 대표 항목: 오레오 초코크림
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['오레오 씬즈 초코크림', '오레오 쿠키 크림', '오레오 크림', '오레오 초코크림']
#
# 클러스터 46:
# 대표 항목: 차량용 핸드폰거치대
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['차량용 핸드폰거치대', '차량용 수동 핸드폰거치대', '디지티 차량용 핸드폰 거치대']
#
# 클러스터 47:
# 대표 항목: 컬쳐랜드권 7
# 클러스터 내 항목 수: 10
# 클러스터 내 항목 (최대 10개):
# ['컬쳐랜드권', '컬쳐랜드권 8', '컬쳐랜드권 신용', '컬쳐랜드권 78 신용카드', '컬쳐랜드권 신용카드', '컬쳐랜드', '컬쳐랜드권 7', '컬쳐랜드 7', '컬쳐랜드권 할인', '컬쳐랜드 당']
#
# 클러스터 48:
# 대표 항목: 코코도르 디퓨저 리필액 + diy 공병 + 스틱20p
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['코코도르 대용량 디퓨저 리필액 xdiy 공병스틱20p', '코코도르 디퓨저 리필액 + diy 공병 + 스틱20p', '코도르 디퓨저 리필액 + diy 공병 + 스틱20p', '코코도르 디퓨저 리필액 +diy 공병+스틱20p']
#
# 클러스터 49:
# 대표 항목: 크라제 함박스테이크
# 클러스터 내 항목 수: 8
# 클러스터 내 항목 (최대 10개):
# ['크라제 함박스테이크', '종료 크라제 함박스테이크', '크라제버거 비프스테이크', '크라제 비프스테이크', '크라제 함박스테이크 + 증정', '크라제 비프 소고기 스테이크', '크라제 함박스테이크 매 한정수량', '재업 크라제 함박스테이크']
#
# 클러스터 50:
# 대표 항목: 펩시콜라 제로 라임
# 클러스터 내 항목 수: 253
# 클러스터 내 항목 (최대 10개):
# ['펩시제로 제로카페인', '코카콜라 제로 can', '펩시제로슈거 라임향 제로카페인', '펩시 제로 라임향', '펩시제로라임 제로카페인', '펩시 제로 슈거 콜라 라임향', '펩시제로 대용량 라임향', '코카콜라', '펩시콜라 제로슈거 라임향', '펩시제로 라임향']
#
# 클러스터 51:
# 대표 항목: 스틸시리즈 arctis nova ireless 헤드셋
# 클러스터 내 항목 수: 42
# 클러스터 내 항목 (최대 10개):
# ['스틸시리즈 arctis 7p+ wireless 61471 헤드셋', '스틸시리즈 arctis nova5 외 다수', '스틸시리즈 arctis nova pro 무선 네플가', '스틸시리즈arctis novaprox 무선헤드셋', '스틸시리즈 arctis ireless', '스틸시리즈 arctis nova 5x 헤드셋 xbo', '스틸시리즈 arctis nova pro x 무선 외', '스틸시리즈 arctis nova 5 헤드셋', '스틸시리즈 arctis nova 5 헤드셋 예판 할인', '스틸시리즈 arctis nova pro wireless x 배터리교환type']
#
# 클러스터 52:
# 대표 항목: ps5 스텔라 블레이드
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['ps5 스텔라 블레이드', 'ps5 스텔라 블레이드 초회판', '스텔라블레이드 초회판', 'ps5 신작 스텔라 블레이드', 'ps5 스텔라 블레이드 사전예약', '스텔라 블레이드']
#
# 클러스터 53:
# 대표 항목: 맥심 모카골드 커피믹스 400t
# 클러스터 내 항목 수: 70
# 클러스터 내 항목 (최대 10개):
# ['동서 맥심 커피믹스 400t', '동서 커피믹스 400t', '맥심 모카골드 마일드 커피믹스 400t', '맥심 모카골드 400t', '맥심 슈프림골드 170t', '맥심 모카골드 커피믹스 400t', '맥심 모카골드 커피믹스 210t', '맥심 모카골드 커피믹스', '맥심 골드 커피믹스 400t', '맥심 모카골드골드 마일드 커피믹스']
#
# 클러스터 54:
# 대표 항목: 나랑드 사이다 제로
# 클러스터 내 항목 수: 105
# 클러스터 내 항목 (최대 10개):
# ['나랑드사이다 제로 can', '해태htb 갈배 사이다 제로', '갈배 사이다 제로', '나랑드사이다 제로 pet 오리지널', '나랑드사이다 파인애플', '나랑드사이다 x 24pet', '나랑드사이다', '갈배사이다 제로 뚱캔', '천연사이다 제로 12pet', '갈배사이다 제로']
#
# 클러스터 55:
# 대표 항목: lg 올 뉴 스타일러 오브제컬렉션 scmr82h 5벌+바지1벌 틴트미러
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['lg 스타일러 오브제컬렉션 scmr52 5벌+바지 1벌', 'lg 스타일러 오브제컬렉션 scmr52 5벌+바지 1벌 틴트미러', 'lg 올 뉴 스타일러 오브제컬렉션 scmr82h 5벌+바지1벌', 'lg 올 뉴 스타일러 오브제컬렉션 scmr82h 5벌+바지1벌 틴트미러']
#
# 클러스터 56:
# 대표 항목: 신일 캠핑 선풍기
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['신일 캠핑용 선풍기', '신일 선풍기', '신일 캠핑 선풍기', '일월 선풍기', '신일 캠핑용 무선 선풍기', '신일 5엽 선풍기']
#
# 클러스터 762:
# 대표 항목: 쿡솜씨 매콤오징어볶음 밀키트
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['쿡솜씨 매콤제육볶음오징어볶음 밀키트', '쿡솜씨 매콤오징어볶음 밀키트', '쿡솜씨 매콤오징어볶음 외']
#
# 클러스터 57:
# 대표 항목: 헤지스 피즈 2pack 반팔 티셔츠
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['헤지스 피즈 2pack 반팔', '헤지스 피즈 2pack 반팔 티셔츠', '헤지스 피즈 2pack 반팔티셔츠', '헤지스 피즈 코튼 반팔 티셔츠']
#
# 클러스터 58:
# 대표 항목: 매일두유 고단백
# 클러스터 내 항목 수: 20
# 클러스터 내 항목 (최대 10개):
# ['매일두유 고단백 검은콩', '매일유업 고단백', '매일 두유 999', '매일유업 매일두유 999', '매일두유 고단백', '매일두유 고단백 두유', '매일우유 고단백 두유', '매일 고단백두유', '매일유업 메디웰 고단백', '매일두유 999']
#
# 클러스터 774:
# 대표 항목: 앤드지 사이드밴딩 스판 슬랙스
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['앤드지 24ss 사이드밴딩 스판 슬랙스', '앤드지 사이드밴딩 스판 슬랙스', '앤드지 사이드밴딩 슬림핏 슬랙스']
#
# 클러스터 59:
# 대표 항목: 아이폰 맥세이프 케이스
# 클러스터 내 항목 수: 19
# 클러스터 내 항목 (최대 10개):
# ['아이폰 맥세이프 케이스', '갤럭시아이폰 맥세이프 크리스탈 케이스', '갤럭시아이폰 맥세이프케이스', '애플 정품 아이폰15 맥세이프 케이스', '갤럭시아이폰 카메라보호 맥세이프 케이스', '아이폰15 프로 맥세이프 투명 케이스', '애플 정품 아이폰 맥세이프 투명 케이스', '아이폰 맥세이프 투명젤리케이스', '애플 정품 아이폰15 맥세이프 투명 케이스', '아이폰15 맥세이프 투명케이스 정품']
#
# 클러스터 60:
# 대표 항목: 캐리어 제습기 cdhc200axlwwyh
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['캐리어 1등급 제습기 cdhc200axlwlyh', '캐리어 제습기 cdhc200axlwwyh', '캐리어 제습기 cdhc200axmwayh']
#
# 클러스터 61:
# 대표 항목: 퍼실 하이진젤 듀얼세탁세제 용기+ 리필
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['퍼실 하이진젤 듀얼세탁세제', '퍼실 하이진젤 듀얼', '퍼실 하이진젤 듀얼 세탁세제 용기 + 리필', '퍼실 하이진젤 듀얼세탁세제 용기+ 리필']
#
# 클러스터 505:
# 대표 항목: 3단 자동우산
# 클러스터 내 항목 수: 18
# 클러스터 내 항목 (최대 10개):
# ['3단우산', '3단 자동우산 +1', 'uv차단 3단 자동 우산', '3단 우산', 'uv 차단 3단 자동우산', '자외선 차단 3단 자동우산', '3단 완전 자동우산', '3단 자동우산', '로엘홈 3단 자동 양우산', '3단접이식 자동 양우산']
#
# 클러스터 62:
# 대표 항목: 컬쳐랜드 문화상품권 5만원권
# 클러스터 내 항목 수: 118
# 클러스터 내 항목 (최대 10개):
# ['북앤라이프 도서문화상품권 선주문5만원권', '컬처랜드상품권 5만원', '온라인문화상품권 5만', '컬쳐랜드상품권 5만원', '컬쳐랜드 모바일문화상품권권', '컬쳐랜드 모바일문화상품권 1만원권', '컬쳐랜드 모바일문화상품권', '컬처랜드 상품권 5만원권', '컬쳐랜드 온라인문화상품권 5만원권', '컬쳐랜드 문화상품권']
#
# 클러스터 63:
# 대표 항목: 보성홍차 아이스티 제로 복숭아레몬
# 클러스터 내 항목 수: 10
# 클러스터 내 항목 (최대 10개):
# ['보성홍차 아이스티 제로 복숭아맛', '보성홍차 아이스티 제로', '보성홍차 아이스티제로', '보성홍차 아이스티 제로 복숭아레몬애플샤인머스캣 + 투명이온', '동원 보성홍차 아이스티 제로 애플 샤인머스캣 복숭아 레몬', '보성홍차 아이스티 제로 복숭아레몬', '보성홍차 아이스티 제로 복숭아레몬애플샤인머스켓', '동원 보성홍차 아이스티 제로 레몬', '동원 보성홍차 아이스티 제로 0kcal 복숭아', '동원 보성홍차 아이스티 제로 복숭아레몬']
#
# 클러스터 64:
# 대표 항목: 사조 전자레인지 팝콘
# 클러스터 내 항목 수: 8
# 클러스터 내 항목 (최대 10개):
# ['사조 전자레인지 팝콘', '사조 전자레인지 팝콘 4종', '사조 전자레인지 팝콘 10퐁', '사조 전자레인지 팝콘 x 4종', '사조 전자레인지 팝콘 x 2종', '사조 전자레인지 팝콘 x 2종 매', '전자레인지 팝콘', '사조 전자렌지 팝콘']
#
# 클러스터 65:
# 대표 항목: 잭링크스 비프 져키 오리지널 육포
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['잭링크스 비프 져키 오리지널 육포', '잭링크스 비프 져키 오리지널', '쿠팡잭링크스 비프 스틱 오리지널 육포', '잭링크스 비프 스틱 오리지널 육포']
#
# 클러스터 66:
# 대표 항목: 최종가 asus rog flow zz301zelc 초경량 게이밍 터치 노트북 i9 rtx 3050ti 초고화질 태블릿pc
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['최종가 asus rog flow zz301zelc 초경량 게이밍 터치 노트북 i9 rtx 3050ti 태블릿pc', '최종가 asus rog flow zz301zelc 초경량 게이밍 터치 노트북 i9 rtx 3050ti 초고화질 태블릿pc', '네이버 최종가 asus rog flow zz301zelc 초경량 게이밍 노트북 i912900h rtx 3050ti 초고화질 태블릿pc']
#
# 클러스터 67:
# 대표 항목: 더단백 드링크
# 클러스터 내 항목 수: 21
# 클러스터 내 항목 (최대 10개):
# ['더단백 드링크음료 외', '더단백 드링크 6종', '빙그레 더단백 드링크 커피 18p', '더단백 프로틴 드링크', '빙그레 더단백 프로틴 드링크', '빙그레 더단백 드링크', '빙그레 더단백 드링크 x 페이', '더단백 드링크 커피 18p', '더단백 드링크음료', '더 단백 프로틴 드링크']
#
# 클러스터 68:
# 대표 항목: 파스텔 장우산
# 클러스터 내 항목 수: 10
# 클러스터 내 항목 (최대 10개):
# ['파스텔 장우산', '+1 파스텔 장우산', '파스텔톤 장우산', '16살대 고급 파스텔 장우산', '16살대 파스텔 장우산', '파스텔 장우산 16살', '16살대 고급 피스텔 장우산', '파스텔 장우산 16살대', '파스텔 장우산 +1', '파스텔 장우산이네요']
#
# 클러스터 69:
# 대표 항목: 큐라이프 니트릴장갑
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['큐라이프 니트릴장갑 블루', '큐라이프 니트릴장갑', '큐라이프 니트릴장갑 당 제한', '큐라이프 니트릴 장갑']
#
# 클러스터 2622:
# 대표 항목: 도트 아이스박스
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['도트 미니 아이스박스', '올리빙 도트 아이스박스', '도트 아이스박스']
#
# 클러스터 70:
# 대표 항목: 매직캔 호환 리필봉투 280
# 클러스터 내 항목 수: 26
# 클러스터 내 항목 (최대 10개):
# ['매직캔 정품 리필봉투 250', '매직캔 정품 리필봉투 280 카드사', '매직캔 호환 리필봉투 280', '매직캔 호환 리필봉투', '정품 매직캔 리필봉투 250', '매직캔 히포크롬 리필봉투 250리필', '매직캔 리필봉투 250', '매직캔 정품 리필봉투 280', '매직캔 리필봉투 280', '매직캔 반값 호환 리필봉투 280']
#
# 클러스터 71:
# 대표 항목: 나이키 스우시 쿠션 양말
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['나이키 스우시 양말', '나이키 스우시 쿠션 양말', '나이키 스우시 에브리데이 쿠션 양말', '나이키 스우시 양말 중목']
#
# 클러스터 72:
# 대표 항목: 갈매기살
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['갈매기살', '갈매기살50', '통갈매기살']
#
# 클러스터 841:
# 대표 항목: 형 틴도우 bldc 진공 무선 스틱 청소기 강력한 흡입력 hepa13 필터 pb101
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['2024 틴도우 bldc 진공 무선 진공청소기 강력한 흡입력 hepa13 필터', '형 틴도우 bldc 진공 무선 스틱 청소기 강력한 흡입력 hepa13 필터 pb101', '형 틴도우 bldc 물걸레 진공 무선 스틱 청소기 강력한 흡입력 hepa13 필터 pb101']
#
# 클러스터 73:
# 대표 항목: 가마로 닭강정 매콤한맛달콤한맛
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['가마로강정 닭강정 매콤한맛달콤한맛', '가마로닭강정 매콤한맛달콤한맛', '가마로 닭강정 매콤한맛달콤한맛']
#
# 클러스터 188:
# 대표 항목: 제주 비가림 하우스감귤
# 클러스터 내 항목 수: 8
# 클러스터 내 항목 (최대 10개):
# ['깨비농원 제주 하우스감귤', '제주 하우스감귤', '깨비농원 제주 정품 하우스 감귤', '제주 비가림 하우스감귤', '비가림 하우스감귤 2s', '비가림 하우스 감귤 중대과', '제주 정품 하우스 감귤', '비가림 하우스 감귤']
#
# 클러스터 74:
# 대표 항목: 클로버나인 갤럭시 아이폰 케이스 등
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['클로버나인 갤럭시 아이폰 케이스 등', '클로버나인 갤럭시 아이폰케이스 등', '클로버나인 갤럭시 아이폰 케이스']
#
# 클러스터 81:
# 대표 항목: 드라이시트 건조기용 피죤 보타닉
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['드라이시트 건조기용피죤 시그니처 보타닉', '드라이시트 건조기용 피죤 보타닉', '드라이시트 건조기용 피죤']
#
# 클러스터 75:
# 대표 항목: 제스프리 골드키위 대과
# 클러스터 내 항목 수: 36
# 클러스터 내 항목 (최대 10개):
# ['제스프리 썬 골드키위', '제스프리 골드키위', '제스프리 썬골드 키위 점보사이즈', '제스프리 골드키위 점보', '제스프리 골드키위 특대과', '제스프리 점보 골드키위', '제스프리 썬 골드키위 특대과', '제스프리 썬골드키위', '제스프리 골드키위 왕점보', '티프레쉬 제스프리 뉴질랜드 썬골드키위']
#
# 클러스터 76:
# 대표 항목: lg 스타일러 오브제컬렉션 5벌 scnr42
# 클러스터 내 항목 수: 7
# 클러스터 내 항목 (최대 10개):
# ['lg 스타일러 오브제컬렉션 5벌 샌드베이지 scbr42', 'lg 스타일러 오브제컬렉션 5벌 scbr42 샌드 베이지', 'lg 스타일러 오브제컬렉션 5벌 그라운드그린 scnr42', 'lg 스타일러 오브제컬렉션 5벌 scnr42', 'lg 스타일러 오브제컬렉션 5벌 scnr42 그라운드 그린 카드', 'lg 스타일러 오브제컬렉션 scbr42 5벌 샌드 베이지', 'lg 스타일러 오브제컬렉션 5벌 샌드베이지 scbr42 신모델']
#
# 클러스터 77:
# 대표 항목: 제주 삼다수 그린
# 클러스터 내 항목 수: 64
# 클러스터 내 항목 (최대 10개):
# ['삼다수 무유라벨 랜덤', '삼다수 그린 24펫', '삼다수 그린', '제주 삼다수 그린', '제주 삼다수', '삼다수 12펫', '제주 삼다수 그린 무유라벨', '제주삼다수 12pet 유', '광동 삼다수 그린', '삼다수 라벨랜덤']
#
# 클러스터 1293:
# 대표 항목: 뉴발란스 라이프스타일 운동화 스니커즈_bb550vtab
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['뉴발란스 라이프스타일 스니커즈_ctf', '뉴발란스 라이프스타일 운동화 스니커즈_bb550pb1', '뉴발란스 라이프스타일 운동화 스니커즈_bb550vtab', '뉴발란스 라이프스타일 운동화 스니커즈']
#
# 클러스터 78:
# 대표 항목: 1등급 한돈 뒷다리 대패
# 클러스터 내 항목 수: 7
# 클러스터 내 항목 (최대 10개):
# ['돈팡 1등급 한돈 뒷다리 대패', '한돈 뒷다리 대패', '한돈 만능 뒷다리 대패', '1등급 한돈 뒷다리 대패', '한돈 만능 뒷다리 대패 60', '돈팡 한돈 뒷다리 대패 + 외 한돈', '돈팡 1등급 한돈 뒷다리 대패 + 외 한돈']
#
# 클러스터 79:
# 대표 항목: cj 햇반
# 클러스터 내 항목 수: 7
# 클러스터 내 항목 (최대 10개):
# ['cj 햇반', 'cj햇반', 'cj햇반 1', 'cj햇반 210', 'cj 솥반', 'cj 햇반 210', 'cj백미햇반']
#
# 클러스터 80:
# 대표 항목: 썬키스트 제로
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['썬키스트 제로', '썬키스트 제로캔', '썬키스트제로']
#
# 클러스터 82:
# 대표 항목: 메가커피 아이스아메리카노
# 클러스터 내 항목 수: 41
# 클러스터 내 항목 (최대 10개):
# ['메가커피 아이스아메리카노', '메가커피 아이스 아메리카노', '메가커피 메가리카노 외 20', '메가커피 메가리카노 외', '메가커피아메리카노', '메가커피 아메리카노', '컴포즈커피 아이스 아메리카노 포장전용', '컴포즈커피 아메리카노', '컴포즈 아이스 아메리카노', '컴포즈 아메리카노 클럽전용']
#
# 클러스터 83:
# 대표 항목: 성주 꿀참외 랜덤과
# 클러스터 내 항목 수: 72
# 클러스터 내 항목 (최대 10개):
# ['성주 꿀참외 혼합과', '고당도 햇 성주 꿀참외 중과', '성주 꿀참외 랜덤과', '성주 고당도 꿀참외', '성주고당도 꿀참외', '고당도 꿀참외', '성주 참외', '성주 참외 혼합과', '성주 참외 랜덤과', '성주 꿀참외']
#
# 클러스터 84:
# 대표 항목: 연세 고칼슘 두유 호두아몬드+검은콩
# 클러스터 내 항목 수: 7
# 클러스터 내 항목 (최대 10개):
# ['고칼슘두유 호두와아몬드', '고칼슘 두유 호두아몬드', '연세 고칼슘두유 호두아몬드', '연세우유 고칼슘 두유 호두 아몬두 + 검은콩', '연세우유 고칼슘 두유 호두아몬두 + 검은콩', '연세 고칼슘 두유 호두아몬드+검은콩', '연세유업 고칼슘두유 호두아몬드 +검은콩']
#
# 클러스터 347:
# 대표 항목: 필터포유 pm03 차량용 블루헤파 에어컨필터
# 클러스터 내 항목 수: 17
# 클러스터 내 항목 (최대 10개):
# ['pm03 극초미세먼지 차량용 에어컨필터', '필터포유 pm03 차량용 블루헤파 에어컨필터', '헤파 pm03 차량용 에어컨필터', '필터포유 pm03 차량용 블루헤파 에어컨필터 +1', '대한 pm03 차량용 에어컨필터', '한일 pmb차량용 활성탄 에어컨필터', '한일 pmb차량용활성탄 자동차에어컨필터', '필터포유 차량용 활성탄 에어컨필터 +1', '필터포유차량용 블루헤파 에어컨필터 +1', 'pm03 차량용 블루헤파 에어컨필터 +1']
#
# 클러스터 85:
# 대표 항목: 아이폰 갤럭시 폰케이스 케이블
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['아이폰 갤럭시 폰케이스 케이블', '아이폰 갤럭시 폰케이스필름 케이블', '아이폰 케이스 케이블']
#
# 클러스터 86:
# 대표 항목: 비스포크 4도어 rf90dg90124e 냉장고 매트 크리미 베이지
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['비스포크 4도어 rf90dg90124e 냉장고 매트 크리미 베이지', '비스포크 4도어 rf90dg90124e 매트 크리미 베이지 냉장고', '전자 비스포크 4도어 rf90dg91114e 매트 크리미 베이지']
#
# 클러스터 87:
# 대표 항목: 닥터페퍼제로
# 클러스터 내 항목 수: 5
# 클러스터 내 항목 (최대 10개):
# ['닥터페퍼 제로', '닥터페퍼제로', '닥터페퍼 제로 뚱캔', '닥터페퍼', '닥터페퍼제로 2']
#
# 클러스터 88:
# 대표 항목: 갤럭시북4 프로 nt960xgqa51a
# 클러스터 내 항목 수: 85
# 클러스터 내 항목 (최대 10개):
# ['갤럭시북4 nt750xgra51a', '갤럭시북4 nt750xgra5', '전자 갤럭시북4 프로 nt960xgkk71a 윈도우11 울트라7', '전자 갤럭시북4 프로 nt960xgkk71a 윈도우11포함', '갤럭시북2 nt550xeza58a', '갤럭시북4 프로 nt960xgqa51a+실버만ssd추가', '갤럭시북4 프로 nt940xgqa51a', '전자 갤럭시북 프로 nt950xdya51a', '전자 갤럭시북2 프로360 nt950qewa51a', '갤럭시북 프로 360 nt950qdbk71a']
#
# 클러스터 89:
# 대표 항목: 고등어밥상 오렌지라벨
# 클러스터 내 항목 수: 5
# 클러스터 내 항목 (최대 10개):
# ['고등어밥상 오렌지라벨', '고등어밥상 오렌지라벨 고등어', '고등어밥상 오렌지라벨 순살고등어', '고등어밥상 오랜지라벨', '고등어밥상 오렌지라벨 16키로']
#
# 클러스터 368:
# 대표 항목: 크리오 덴티메이트 초극세모 칫솔
# 클러스터 내 항목 수: 30
# 클러스터 내 항목 (최대 10개):
# ['칫솔 덴티메이트 시즌2 초극세모', '크리오 덴티메이트 시즌2 초극세모 칫솔', '덴티메이트 시즌2 초극세모 칫솔', '크리오 덴티메이트 오리지널 초극세모 칫솔', '크리오 덴티메이트 멀티케어 초극세모 올인원 칫솔', '덴티메이트 토탈케어 치약', '크리오 형 덴티메이트 멀티케어 플러스 초극세모 칫솔', '크리오 덴티메이트 브레스케어 초극세모 칫솔', '크리오 덴티메이트 오리지널 초극세모', '크리오 덴티메이트 초극세모']
#
# 클러스터 2439:
# 대표 항목: 전자 오디세이 oled g9 s49cg934
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['전자오디세이oeldg9 s49cg934', '게이밍 오디세이 oled g9 s49cg934', '전자 오디세이 oled g9 s49cg934']
#
# 클러스터 1291:
# 대표 항목: 메가커피 50
# 클러스터 내 항목 수: 5
# 클러스터 내 항목 (최대 10개):
# ['메가커피 메뉴', '메가커피 20', '메가커피 520', '메가커피 메뉴 50', '메가커피 50']
#
# 클러스터 90:
# 대표 항목: 맥주효모 비오틴 셀렌
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['맥주효모 비오틴 셀렌', '프리미엄 맥주효모 비오틴 셀렌', '맥주 효모 비오틴']
#
# 클러스터 91:
# 대표 항목: 제주 미니 밤호박
# 클러스터 내 항목 수: 22
# 클러스터 내 항목 (최대 10개):
# ['제주 보우짱 미니 밤호박', '제주 보우짱 미니밤호박', '제주 미니 밤호박 못난이', '제주 미니밤호박 로얄과', '제주 미니 밤호박 보우짱 특품', '제주 미니 밤호박', '제주 밤호박 특품 카드', '제주 미니 밤호박 로얄과', '미니 밤호박 보우짱', '미니 밤호박']
#
# 클러스터 1947:
# 대표 항목: 비앙떼 제로 허니자몽티
# 클러스터 내 항목 수: 8
# 클러스터 내 항목 (최대 10개):
# ['비앙떼 제로 허니유자맛', '비앙떼 제로 허니자몽티', '비앙떼 허니자몽티', '비앙떼 허니자몽 티', '제로 허니자몽티', '제로 허니자몽 티', '광동 비앙떼허니자몽티', '광동비앙떼허니자몽티']
#
# 클러스터 92:
# 대표 항목: 리엔 흑모비책골드 염색약 흑갈색
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['리엔 흑모비책골드 염색약 자연갈색', '리엔 흑모비책골드 염색약 흑갈색', '리엔 흑모비책 염색약 흑갈색', '리엔 흑모비책 골드 염색약 흑갈색']
#
# 클러스터 93:
# 대표 항목: 동원 라이트스탠다드 참치
# 클러스터 내 항목 수: 19
# 클러스터 내 항목 (최대 10개):
# ['동원참치 스탠다드', '동원 라이트스탠다드참치', '동원참치 라이트스탠다드', '동원 라이트스탠다드 참치', '동원 라이트 스탠다드 참치 원터치', '라이트 스탠다드 참치 원터치', '동원 라이트 스탠다드 참치', '라이트스탠다드 참치', '동원참치 라이트고추참치콘', '동원 라이트스탠다드 참치 고추참치']
#
# 클러스터 94:
# 대표 항목: 푸마 바디웨어 코튼 런닝 3종 세트
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['푸마 코튼 런닝 3종세트', '푸마 바디웨어 코튼 런닝 3종 세트', '푸마 베이직 코튼 런닝 3종세트', '푸마 바디웨어 코튼 민소매 5종 세트']
#
# 클러스터 95:
# 대표 항목: 미니멜츠 구슬아이스크림 4종
# 클러스터 내 항목 수: 12
# 클러스터 내 항목 (최대 10개):
# ['미니멜츠 구슬아이스크림', '미니멜츠 구슬아이스크림 4종', '미니멜츠 구슬 아이스크림 4종', '미니벨츠 구슬아이스크림', '미니멜츠 구슬아이스크림 혼합', '미니멜츠 구슬 아이스크림', '미니멜츠 구슬아이스크림 3종', '미니멜츠 구슬아이스크림 4가지 맛할인', '미니멜츠 구슬 아이스크림 4종 스삼롯농', '미니멜츠 구슬아이스크림 4가지 맛']
#
# 클러스터 96:
# 대표 항목: hem7142t2 오므론 자동전자혈압계 혈압측정기
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['오므론 hem7142t2 자동전자혈압계 혈압측정기', 'hem7142t2 오므론 자동전자혈압측정계', '오므론 hem7121 자동전자혈압계 혈압측정기 14회 메모리', 'hem7142t2 오므론 자동전자혈압계', 'hem7142t2 오므론 자동전자혈압계 혈압측정기', '오므론 hem7142t2 자동전자혈압계']
#
# 클러스터 782:
# 대표 항목: 한성 크래미 몬스터크랩
# 클러스터 내 항목 수: 5
# 클러스터 내 항목 (최대 10개):
# ['크래미 몬스터크랩', '한성 몬스터크랩', '한성 크래미 몬스터크랩', '한성 크래미 몬스터크랩 x 쿠폰', '한성 크래미 몬스터크랩 x 당꼴']
#
# 클러스터 97:
# 대표 항목: 장순필 가마솥 육개장
# 클러스터 내 항목 수: 18
# 클러스터 내 항목 (최대 10개):
# ['장순필 가마솥 해장국', '장순필 가마솥 순대탕', '장순필 가마솥 추어탕', '장순필 가마솥 특 육개장 + 칼국수면', '장순필 가마솥 특 육개장', '장순필 가마솥 해장탕', '장순필 가마솥 육개장', '장순필 가마솥 특육개탕', '가마솥 해장국 해장탕', '장순필 가마솥 육개장 특 페이']
#
# 클러스터 486:
# 대표 항목: 직화 무뼈 닭발
# 클러스터 내 항목 수: 12
# 클러스터 내 항목 (최대 10개):
# ['매운 무뼈닭발', '무뼈 직화 불닭발', '직화 무뼈 닭발', '불맛 직화 불닭발', '뼈없는 직화 불닭발', '무뼈닭발', '직화 불닭발', '화통한 직화 무뼈 닭발', '직화무뼈닭발', '무뼈 불닭발']
#
# 클러스터 98:
# 대표 항목: 2080 클래식치약 x+치약
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['2080 클래식치약 x', '2080 클래식 치약', '2080클래식치약 +치약 증정', '2080클래식 치약 + 미니치약', '2080클래식 치약', '2080 클래식치약 x+치약']
#
# 클러스터 99:
# 대표 항목: 맥반석 구운계란 대란
# 클러스터 내 항목 수: 30
# 클러스터 내 항목 (최대 10개):
# ['구운계란 중란', '구운란 대란', '구운계란 대란', '맥반석 구운란 대란', '촉촉 구운란 대란 중란', '구운계란 초란 2판', '프리미엄 맥반석 구운란 대란 쿠폰적용', '프리미엄 맥반석 구운란 대란', '맥반석 구운계란 중란', '맥반석구운란']
#
# 클러스터 170:
# 대표 항목: 일화 부르르 제로콜라 체리
# 클러스터 내 항목 수: 32
# 클러스터 내 항목 (최대 10개):
# ['부르르 제로 레몬', '일화 부르르 제로콜라 체리', '부르르 제로콜라', '일화 부르르 제로사이다', '부르르 제로사이다', '부르르 제로콜라 체리', '일화 부르르 제로 사이다', '부르르 제로 사이다', '일화 부르르제로', '일화 부르르 제로콜라 맥콜 천연사이다 탑씨']
#
# 클러스터 100:
# 대표 항목: 오뚜기 뿌셔뿌셔 불고기맛
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['오뚜기 뿌셔뿌셔 불고기맛', '뿌셔뿌셔 불고기맛', '오뚜기 미니뿌셔 불고기맛', '뿌셔뿌셔 근본 불고기맛']
#
# 클러스터 101:
# 대표 항목: 팔도 비락식혜 제로
# 클러스터 내 항목 수: 26
# 클러스터 내 항목 (최대 10개):
# ['팔도 비락식혜제로', '비락식혜 제로', '팔도 비락 식혜 제로', '팔도 비락식혜', '비락식혜24 제로', '비락 식혜 제로 페이', '비락 식혜 제로', '비락식혜제로 8펫', '팔도 비락식혜 제로', '팔도 비락 식혜 제로 캔']
#
# 클러스터 102:
# 대표 항목: 지누스 그린티 플러스 하이브리드 스프링 매트리스 25cm 슈퍼싱글
# 클러스터 내 항목 수: 11
# 클러스터 내 항목 (최대 10개):
# ['지누스 그린티 플러스 하이브리드 스프링 매트리스 25cm 슈퍼싱글', '지누스 그린티 플러스 하이브리드 매트리스 20cm ss', '지누스 그린티 플러스 하이브리드 스프링 매트리스 20cm', '지누스 얼티마 에어 하이브리드 스프링 매트리스 25cm ss', '지누스 얼티마럭스s 하이브리드 매트리스 25cm 슈싱', '지누스 얼티마 에어 하이브리드 스프링 매트리스 25cm', '지누스 얼티마 에어 하이브리드 스프링 매트리스 25cm 슈퍼싱글', '지누스 얼티마 럭스s 하이브리드 매트리스 25cm 슈퍼싱글', '지누스 하이브리드 스프링 매트리스 25cm', '지누스 그린티 플러스 하이브리드 스프링 매트리스 20cm ss']
#
# 클러스터 103:
# 대표 항목: 로하스웰 관절편한 msm 1500
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['로하스웰 관절편한 msm 1500', '로하스웰 msm 1500', '로하스웰 관절편한 msm1500']
#
# 클러스터 104:
# 대표 항목: 기능성 티셔츠
# 클러스터 내 항목 수: 5
# 클러스터 내 항목 (최대 10개):
# ['기능성 냉감 티셔츠', 'k2 기능성 티셔츠', 'k2 기능성 티셔츠 페이', '기능성 집업 티셔츠', '기능성 티셔츠']
#
# 클러스터 375:
# 대표 항목: 맥도날드 2만원권 10
# 클러스터 내 항목 수: 27
# 클러스터 내 항목 (최대 10개):
# ['맥도날드권', '맥도날드 2만원권 10', '맥도날드 2만원권', '맥도날드 2만원권 선착순 10', '맥도날드금액권', '맥도날드 5만원 금액원', '맥도날드 1만원권 2만원권 10', '맥도날드 1만원권', '맥도날드 선착순 2만원권', '맥도날드 금액권 2만']
#
# 클러스터 162:
# 대표 항목: 이뮨 올인원 종합 멀티비타민 + 증정
# 클러스터 내 항목 수: 13
# 클러스터 내 항목 (최대 10개):
# ['이뮨 올인원 액상 멀티비타민 + 밀크씨슬', '이뮨 올인원 멀티비타민 +증정', '이뮨 올인원 종합 멀티비타민', '이뮨 올인원 종합 멀티 액상 비타민 20 +홍삼 10포', '이뮨 올인원 멀티비타민 + 밀크씨슬 증정', '이뮨 올인원 종합멀티비타민', '이뮨 올인원 멀티비타민', '이뮨 올인원 종합 멀티비타민 + 증정', '이뮨 올인원 종합 멀티비타민 미네랄20', '이뮨 올인원 종합 멀티비타민+오메가3 증정']
#
# 클러스터 105:
# 대표 항목: 사조대림 안심 삼계탕
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['대림 안심 삼계탕', '사조대림 안심삼계탕', '사조대림 안심 삼계탕']
#
# 클러스터 106:
# 대표 항목: jmw 에어뮤즈 bldc 써큘레이터
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['jmw 에어뮤즈 bldc 써큘레이터', 'jmw 에어뮤즈 bldc 써큘레이터 대형미니', 'jmw 에어뮤즈 써큘레이터']
#
# 클러스터 107:
# 대표 항목: 쿠쿠 용 트윈프레셔 밥솥 crpfhtas0610fw
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['쿠쿠 용 트윈프레셔 밥솥 crpfhtas0610fw', '쿠쿠 트윈프레셔 용 밥솥 crpst0610fw', '쿠쿠 올스텐 트윈프레셔 용 밥솥 crpkhtas1010fwm', '쿠쿠 트윈프레셔 밥솥 crpfhtas0610fw', '쿠쿠 용 밥솥 crpkhtas1010fwm', '쿠쿠 용 올스텐 트윈프레셔 밥솥 crpfhtas0610fw']
#
# 클러스터 108:
# 대표 항목: 눈건강 루테인 지아잔틴 30캡슐
# 클러스터 내 항목 수: 18
# 클러스터 내 항목 (최대 10개):
# ['인테로 루테인 지아잔틴 30캡슐', '루테인지아잔틴', '한미양행 루테인 지아잔틴 30캡슐', '인테로 루테인 지아잔틴 60캡슐', 'jw중외제약 눈건강 루테인 지아잔틴 30캡슐', '미생활건강 눈건강 루테인 지아잔틴', '한미생활건강 눈건강 루테인지아잔틴', '눈건강 루테인 지아잔틴', '눈건강 루테인 지아잔틴 30캡슐', '루테인지아잔틴 +1']
#
# 클러스터 776:
# 대표 항목: 이디야 스페셜 골드블렌드 커피믹스 120t
# 클러스터 내 항목 수: 5
# 클러스터 내 항목 (최대 10개):
# ['이디야 스페셜 골드블렌드모카블렌드 커피믹스 240t', '이디야 스페셜 골드블렌드 커피믹스 280t + 20t 증정', '이디야 스페셜 골드블렌드 커피믹스 120t', '이디야 스페셜 골드블렌드 리치크레마 커피믹스 280t', '일머리용 이디야 스페셜 골드블렌드 커피믹스 200t + 20t']
#
# 클러스터 109:
# 대표 항목: 스마트 모니터 m7 s43bm701
# 클러스터 내 항목 수: 69
# 클러스터 내 항목 (최대 10개):
# ['강세일 2024 스마트 모니터 m7 s43dm701', '7월 브랜드 위크 스마트 모니터 m7 s43bm701', '브랜드 위크 스마트 모니터 m7 s43bm700', '브랜드 위크 2024 스마트 모니터 m7 s43dm701', '스마트모니터 m5 s27cm501', '갓생쇼핑 2024 스마트 모니터 m7 s43dm701', '브랜드 위크 스마트 모니터 m7 s43dm701', '2024 스마트 모니터 m7 s43dm701 라이브', '6월 온세일 스마트 모니터 m7 s43bm702', '브랜드 판타지 스마트 모니터 m7 s43bm702']
#
# 클러스터 1222:
# 대표 항목: toocki 커널형 무선 블루투스 53 이어폰
# 클러스터 내 항목 수: 36
# 클러스터 내 항목 (최대 10개):
# ['toocki 커널형 디지털 tws 무선 블루투스 53 이어폰 j58', 'toocki tws 블루투스 53 무선 이어폰', 'toocki tws 블루투스 이어폰', 'toocki 블루투스 이어폰', 'toocki 무선 블루투스 53 헤드셋', 'toocki 커널형 무선 블루투스 53 이어폰', 'toocki 투키 무선 블루투스 53 헤드셋', 'toocki 귀걸이형 블루투스 이어폰', 'toocki 투키 디스플레이 블루투스 53 오픈형 무선 이어폰', 'toocki 커널형 무선 블루투스 이어폰']
#
# 클러스터 110:
# 대표 항목: 할인 시소닉 focus gold gmodular 외 다수
# 클러스터 내 항목 수: 7
# 클러스터 내 항목 (최대 10개):
# ['시소닉 focus gold gmodular 파워서플라이 외 다수', '시소닉 focus gold gmodular', '시소닉 gold gmodular 파워서플라이 외 다수', '할인 시소닉 focus gold gmodular외 다수 520', '할인 시소닉 focus gold gmodular 외 다수', '시소닉 시소닉 focus gold gmodular 외 다수', '시소닉 할인 시소닉 focus gold gmodular 외 다수']
#
# 클러스터 576:
# 대표 항목: 불스원샷 플래티넘
# 클러스터 내 항목 수: 11
# 클러스터 내 항목 (최대 10개):
# ['불스원샷 플래티넘 4in1', '불스원샷 플래티넘', '불스원샷 플래티넘 경유', '불스원샷 플래티넘 휘발유', '불스원샷 플래티넘 스클', '불스원샷 플래티넘 경유용', '불스원 플래티넘', '불스원샷 플래티넘휘발유', '불스원샷 플래티넘 택1', '불스원샷 플래티넘 2ea']
#
# 클러스터 1806:
# 대표 항목: 투뿔 한우 국거리
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['투쁠한우 국거리', '투플러스 한우 국거리', '투뿔 한우 국거리']
#
# 클러스터 111:
# 대표 항목: 해태 홈런볼 소금우유
# 클러스터 내 항목 수: 15
# 클러스터 내 항목 (최대 10개):
# ['해태 홈런볼초코', '해태제과 홈런볼 초코', '해태 홈런볼', '홈런볼 초코', '해태 홈런볼 소금우유', '해태 제과 홈런볼 초코', '홈런볼 오리지날소금우유', '해태제과 홈런볼 초코소금우유', '홈런볼 소금우유', '홈런볼 소금 우유']
#
# 클러스터 112:
# 대표 항목: qcy ailybuds pro ht10
# 클러스터 내 항목 수: 7
# 클러스터 내 항목 (최대 10개):
# ['qcy ailybuds pro ht10 블투이어폰', 'qcy ailybuds pro ht10', 'qcy ailybuds pro+ plus ht10 블루투스 이어폰', 'qcy ailybuds pro+plus ht10', 'qcy ailybuds pro + ht10', 'qcy ailybuds pro plus ht10', 'qcy ailybuds pro ht10 블루투스이어폰 외 gt2 등']
#
# 클러스터 113:
# 대표 항목: 레인ok 빗물을 튕겨주는 발수 와이퍼
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['레인ok 빗물을 튕겨주는 발수 와이퍼', '레인ok 빗물을 튕겨주는 와이퍼', '레인 ok 빗물 발수 와이퍼', '레인ok 빗물을 튕겨주는 발수와이퍼']
#
# 클러스터 1383:
# 대표 항목: 탁상용 무선 선풍기
# 클러스터 내 항목 수: 8
# 클러스터 내 항목 (최대 10개):
# ['탁상용 선풍기', '탁상용 무선 미니선풍기', '탁상용 미니 무선 선풍기', '탁상용 무소음 무선 선풍기', '탁상용 무선 저소음 선풍기', '탁상용 무선 선풍기', '샤오미 f6 탁상용 무선 선풍기', '샤오미 탁상용 무선 선풍기']
#
# 클러스터 1651:
# 대표 항목: 팔도 미니왕뚜껑
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['팔도 킹뚜껑', '팔도 왕뚜껑', '팔도도시락 왕뚜껑', '팔도 미니 곰탕 왕뚜껑', '팔도 미니왕뚜껑 80', '팔도 미니왕뚜껑']
#
# 클러스터 114:
# 대표 항목: 육개장 사발면 +김치사발면+짜파게티범벅
# 클러스터 내 항목 수: 7
# 클러스터 내 항목 (최대 10개):
# ['육개장 사발면 +김치+짜파게팀범벅', '육개장 사발면 +김치사발면+짜파게티범벅', '농심 육개장 사발면 +김치사발면+짜파게티범벅', '육개장 +김치사발면 +짜파게티범벅', '육개장+김치사발면+짜파게티범벅', '육개장 +김치사발면+짜파게티범벅', '육개장사발면+ 김치사발면+짜파게티범벅']
#
# 클러스터 115:
# 대표 항목: 한돈 듀록 양념 칼집구이 + 한돈 듀록 고추장불고기
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['록식당 한돈 듀록 양념 칼집구이+한돈 듀록 고추장불고기', '한돈 양념 칼집구이+한돈 고추장불고기', '한돈 듀록 양념 칼집구이 + 한돈 듀록 고추장불고기']
#
# 클러스터 267:
# 대표 항목: 클리어 샴푸
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['클리어샴푸', '클리어 샴푸', '클리어 맨 샴푸', '클리어 맨 샴푸 페이']
#
# 클러스터 116:
# 대표 항목: gigabyte 지포스 rtx 4060 ti windforce oc d6 피씨디렉트
# 클러스터 내 항목 수: 17
# 클러스터 내 항목 (최대 10개):
# ['gigabyte rtx 4070 super gaming oc d6x 피씨디렉트', 'gigabyte rtx 3060 ti gaming oc v2 d6', 'gigabyte 지포스 rtx 3080 ti gaming oc d6x 피씨디렉트', '끌올gigabyte 지포스 rtx 3080 ti gaming oc d6x 피씨디렉트', 'gigabyte 지포스 rtx 2060 super windforce oc d6', 'gigabyte 지포스 rtx 4070 super gaming oc d6x 피씨디렉트', 'gigabyte 지포스 rtx 4070 super gaming oc d6x 피씨디렉트 최종혜택가', 'gigabyte 지포스 rtx indforce oc d6 피씨디렉트 최종혜택가', 'gigabyte 지포스 rtx indforce oc d6 최종가 외 다수', '기가바이트 지포스 rtx 4070 super windforce oc d6']
#
# 클러스터 117:
# 대표 항목: 오뚜기 오쉐프 렌지에 돌려먹는 순살 고등어구이
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['오쉐프 렌지에 돌려먹는 순살 고등어구이', '렌지에 돌려먹는 고등어구이', '오뚜기 오쉐프 렌지에 돌려먹는 순살 고등어구이', '오뚜기 렌지에 돌려먹는 순살 고등어구이', '오뚜기 오쉐프 렌지에 돌려먹는 순살 생선구이 2종', '오뚜기 t 오뚜기 오쉐프 렌지에 돌려먹는 순살 고등어구이']
#
# 클러스터 118:
# 대표 항목: 다향 훈제오리
# 클러스터 내 항목 수: 13
# 클러스터 내 항목 (최대 10개):
# ['정다운 훈제오리', '다향 훈제오리', '정다운 허브훈제오리', '다향오리훈제', '다향오리 훈제', '허브마늘 훈제오리', '정다운 허브훈제오리 페이', '다향오리', '정다운 허브훈제오리+마늘훈제오리', '훈제오리']
#
# 클러스터 2662:
# 대표 항목: 산과들에 순수가온 100낱봉
# 클러스터 내 항목 수: 5
# 클러스터 내 항목 (최대 10개):
# ['순수가온 100낱봉', '산과들에 순수가온 100낱봉', '산과들에 순수가온 선물세트', '산과들에 순수가온 100선물세트', '산과들에 순수가온 60낱봉']
#
# 클러스터 119:
# 대표 항목: 앙블랑 물티슈 고평량 네이비
# 클러스터 내 항목 수: 16
# 클러스터 내 항목 (최대 10개):
# ['앙블랑 물티슈 80고평량 네이비', '앙블랑 물티슈 80고평량 네이비 본품', '앙블랑 물티슈 82고평량 네이비', '앙블랑 물티슈 82고평량', '앙블랑 물티슈 80평량 네이비', '앙블랑 물티슈 네이비 캡형', '앙블랑 물티슈 고평량 네이비', '앙블랑 아기물티슈 네오 캡형', '앙블랑 물티슈 고평량 네이비 캡형', '앙블랑 물티슈 초고평량 세이프 네이비 캡형']
#
# 클러스터 120:
# 대표 항목: 도브 비누 +증정
# 클러스터 내 항목 수: 5
# 클러스터 내 항목 (최대 10개):
# ['도브 비누 +증정', '도브 대용량 비누 +증정', '도브 대용량 비누', '도브 비누 + 증정', '도브 비누 바 + 증정']
#
# 클러스터 121:
# 대표 항목: 해의락 대천도시락김
# 클러스터 내 항목 수: 5
# 클러스터 내 항목 (최대 10개):
# ['해의락 대천 도시락김', '해의락 대천김', '해의락 대천김 x2', '해의락 대천도시락김', '해의락 도시락김']
#
# 클러스터 122:
# 대표 항목: 알티지 오메가3
# 클러스터 내 항목 수: 32
# 클러스터 내 항목 (최대 10개):
# ['알티지 오메가3', '알티지오메가3', '알티지 오메가3 식물성캡슐', '루체 초임계 알티지오메가3', '초임계 식물성 알티지 오메가', '초임계 식물성 알티지 오메가3 3달치', '디씨엔 알티지 오메가3', 'rtg 알티지 오메가3 비타민d', 'cmg제약 초임계 알티지 오메가3', '초임계 알티지 오메가3']
#
# 클러스터 123:
# 대표 항목: sapphire 라데온 rx 7900 xtx nitro+ vaporx oc d6
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['sapphire 라데온 rx 7900 xtx nitro+ vaporx oc d6 외 다수', 'sapphire 라데온 rx 7900 xtx nitro+ vaporx oc d6', '페이sapphire 라데온 rx 7900 xtx nitro+ vapor', 'sapphire 라데온 rx 7800 xt nitro+ oc d6']
#
# 클러스터 124:
# 대표 항목: 스케쳐스 맥스 쿠셔닝 포미
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['스케쳐스 맥스 쿠셔닝 포미', '스케쳐스 맥스 쿠셔닝 델타', '스케쳐스 맥스 쿠셔닝 엘리트']
#
# 클러스터 206:
# 대표 항목: 셀렉스 프로핏 웨이프로틴 드링크
# 클러스터 내 항목 수: 21
# 클러스터 내 항목 (최대 10개):
# ['셀렉스 프로핏 wpi 프로틴 드링크 복숭아초콜릿아메리카노', '셀렉스 프로핏 단백질 음료', '셀렉스 웨이프로틴 드링크 초코맛', '셀렉스 프로핏 단백질 드링크', '셀렉스 프로핏 단백질드링크', '셀럭스 프로핏 단백질 음료', '셀렉스 프로핏 웨이프로틴 드링크', '셀렉스 웨이프로틴 드링크', '셀렉스 프로핏 웨이프로틴', '셀렉스 프로핏 웨이프로틴 드링크 음료']
#
# 클러스터 125:
# 대표 항목: 건국 멸균 우유
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['건국유업 멸균우유', '건국 멸균우유', '건국 멸균 우유', '건국우유 멸균우유', '건국 멸균우유 건국우유 할인대전', '건국 멸균우유 건국우유']
#
# 클러스터 126:
# 대표 항목: sk하이닉스 platinum p41 nvme ssd
# 클러스터 내 항목 수: 18
# 클러스터 내 항목 (최대 10개):
# ['sk하이닉스 platinum p41 nvme ssd', 'sk하이닉스 platinum p41 nvme m2 ssd', 'sk하이닉스 platinum p41', 'sk하이닉스 platinum p2 ssd', 'sk하이닉스 platinum p41 ssd', 'sk하이닉스 platinum p41 pcie40 nvme m2 2280 ssd shpp41m2', 'sk하이닉스 platinum p2 nvme 한정수량', 'sk하이닉스 platinum p41 pcie40 nvme m2 2280 ssd', 'sk하이닉스 platinum p2 nvme', 'sk하이닉스 platinum p41 해외구매']
#
# 클러스터 127:
# 대표 항목: 위닉스 뽀송 인버터 제습기
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['위닉스뽀송 인버터 제습기', '위닉스 제습기', '위닉스 뽀송 인버터 제습기', '위닉스 인버터 제습기', '위닉스 뽀송 제습기', '위닉스 원데이 뽀송 제습기']
#
# 클러스터 128:
# 대표 항목: 한끼통살 닭가슴살 10종
# 클러스터 내 항목 수: 8
# 클러스터 내 항목 (최대 10개):
# ['한끼통살 닭가슴살', '한끼통살 닭가슴살 10종', '한끼통살 제로 닭가슴살', '한끼통살 소스 닭가슴살 17종 신규쿠폰', '한끼통살 신상 닭가슴살', '한끼통살 통 닭가슴살 3종', '한끼통살 닭가슴살 14종 택1', '한끼통살 소스 닭가슴살 10종 혼합']
#
# 클러스터 129:
# 대표 항목: d2 tkd cycle7 베어본 수제 윤활 스위치 패키지 특가 사전 안내
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['d2 tkd cycle7 베어본 수제 윤활 스위치 패키지 특가 사전 안내', 'd3 tkd cycle7 베어본 수제 윤활 스위치 패키지 특가 사전 안내', 'tkd cycle7 베어본 수제 윤활 스위치 패키지 특가 사전 안내']
#
# 클러스터 130:
# 대표 항목: tcl 4k uhd qled tv
# 클러스터 내 항목 수: 8
# 클러스터 내 항목 (최대 10개):
# ['tcl 4k uhd qled tv', '에이펙스 4k uhd led tv', '시티브 4k uhd led tv', '벡셀 4k uhd led tv', '필립스 4k uhd led tv', '델리파스 4k uhd qled tv', 'tcl 4k uhd qled tv 50c645', '75c755 tcl 4k uhd led tv']
#
# 클러스터 131:
# 대표 항목: 펩시제로 + 칠성사이다 제로
# 클러스터 내 항목 수: 18
# 클러스터 내 항목 (최대 10개):
# ['펩시제로 +사이다제로', '펩시 제로슈거 라임 + 칠성사이다 제로', '펩시제로 + 사이다제로', '맥콜제로 +천연사이다 제로', '펩시제로 칠성사이다 제로', '펩시 제로 코크제로 사이다제로', '펩시 제로 칠성 사이다', '펩시 제로 + 사이다 제로', '펩시콜라제로 +칠성사이다 제로', '펩시제로 + 칠성사이다 제로']
#
# 클러스터 132:
# 대표 항목: 필립스 샤티넬 어드밴스 모근제거기 bre71010
# 클러스터 내 항목 수: 8
# 클러스터 내 항목 (최대 10개):
# ['필립스 샤티넬 어드밴스 모근제거기', '필립스 샤티넬 어드밴스 바디 제모기 bre70000', '필립스샤티넬 어드밴스 모근제거기', '필립스 샤티넬 어드밴스드 전기제모기', '필립스 샤티넬 어드밴스 모근제거기 bre71010 카드', '필립스 샤티넬 어드밴스 모근제거기 bre7 + 알로에젤', '필립스 샤티넬 어드밴스 모근제거기 bre71010 322 예약배송', '필립스 샤티넬 어드밴스 모근제거기 bre71010']
#
# 클러스터 133:
# 대표 항목: 올반 얇은피 인생 왕교자
# 클러스터 내 항목 수: 7
# 클러스터 내 항목 (최대 10개):
# ['올반 얇은피 인생왕교자', '올반 얇은피 인생 왕교자', '올반 얇은피 인생 왕교자만두', '올반 인생 왕교자', '올반 짬뽕군만두얇은피 인생왕교자', '올반 얇은피인생왕교자 짬뽕명란', '올반 얇은피인생왕교자']
#
# 클러스터 134:
# 대표 항목: 더미식 백미밥 페이
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['더미식 백미밥', '더미식 백미밥 페이백', '더미식 백미밥 페이', '더미식 현미밥']
#
# 클러스터 135:
# 대표 항목: 비스포크 냉장고 rf85c90d1ap
# 클러스터 내 항목 수: 34
# 클러스터 내 항목 (최대 10개):
# ['전자 비스포크 4도어 rf85db90b1ap', '전자 비스포크 4도어 냉장고 rf85db90b1ap', '비스포크 냉장고 rf85db90b1ap 1등급 4도어 색상선택', '전자 비스포크 4도어 냉장고 rf85db91f1ap', '비스포크 냉장고 rf85c90d1ap 1등급 4도어', '전자 비스포크 냉장고 rf85a9103ap', '비스포크 냉장고 5도어 코타 rf85a92k1ap', '비스포크 냉장고 rf85a9103ap 대', '비스포크 냉장고 rf85a92k1ap', '비스포크 냉장고 rf85c9141ap 1등급 푸드쇼케이스']
#
# 클러스터 136:
# 대표 항목: 코오롱 오토드 프로케어 노즐살균 비데 a2000 ipx5 무필터 건조
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['코오롱 오토드 프로케어 노즐 살균 비데', '단독판매 코오롱 오토드 프로케어 노즐살균 리모컨 방수비데 a2000 ipx5 무필터 건조', '코오롱 오토드 프로케어 노즐살균 비데', '코오롱 오토드 프로케어 노즐살균 비데 a2000', '코오롱 오토드 울트라케어 살균 방수비데 a3000 ipx5 무필터 건조', '코오롱 오토드 프로케어 노즐살균 비데 a2000 ipx5 무필터 건조']
#
# 클러스터 137:
# 대표 항목: 활전복
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['활전복', '전복', '활 전복']
#
# 클러스터 313:
# 대표 항목: 라인바싸 탄산수
# 클러스터 내 항목 수: 20
# 클러스터 내 항목 (최대 10개):
# ['동아오츠카 라인바싸 탄산수 플레인 pet', '라인바싸 탄산수', '라인바싸 탄산수 플레인 pet', '라인바싸 40펫', '라인바싸 탄산수 음료', '라인바싸 미네랄 탄산수', '라인바싸 탄산수 플레인', '라인바싸 탄산수 페트', '라인바싸 탄산수 3종', '라인바싸 탄산수 x 민트라임']
#
# 클러스터 138:
# 대표 항목: 동원 통그릴 비엔나
# 클러스터 내 항목 수: 17
# 클러스터 내 항목 (최대 10개):
# ['동원 통그릴 비엔나 결제시', '동원 통그릴 비엔나', '동원 통그릴 비엔나 페이 최종혜택가', '동원 통그릴 비엔나 동원 딤섬만두', '동원 통그릴비엔나 2', '동원 통그릴 비엔나 딤섬만두', '통그릴 비엔나', '동원 통그릴 비엔나 소시지', '동원 통그릴비엔나 소시지', '동원 통그릴 비엔나 최종혜택가']
#
# 클러스터 139:
# 대표 항목: 팔도 왕뚜껑 컵라면
# 클러스터 내 항목 수: 14
# 클러스터 내 항목 (최대 10개):
# ['팔도 도시락 왕뚜껑 컵라면', '팔도도시락 컵라면', '팔도 도시락 컵라면', '킹뚜껑 컵라면', '팔도 왕뚜껑 +비빔면', '팔도 왕뚜껑 도시락 컵라면', '팔도 왕뚜껑 컵라면', '팔도 도시락 왕뚜껑 비빔면', '팔도 도시락 왕뚜껑 비빔면컵라면 소컵', '쎈딜 팔도 왕뚜껑 도시락 컵라면']
#
# 클러스터 695:
# 대표 항목: 리퍼제품 titan gx air 타공마우스
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['titan gx air 타공마우스', '리퍼제품 titan gx air 타공마우스', '리퍼제품 titan g air 타공 무선마우스', '리퍼제품 titan g air se 타공 무선마우스']
#
# 클러스터 140:
# 대표 항목: 웨스턴 디지털 wd blue 하드디스크 hdd wd80eaaz
# 클러스터 내 항목 수: 13
# 클러스터 내 항목 (최대 10개):
# ['웨스턴디지털 wd blue 하드디스크 hdd wd80eaaz', '웨스턴 디지털 wd blue 하드디스크 hdd wd80eaaz', '웨스턴 디지털 wd blue 하드디스크', '웨스턴디지털wd blue하드 hddwd80eaaz', '웨스턴 디지털 블루 하드디스크', '웨스턴 디지털 블루 하드디스크 hdd', '웨스턴 디지털 wd blue 하드디스크 hdd', 'wd blue 하드 디스크', 'wd blue 하드디스크 hdd', '웨스턴 디지털 윈드블루 하드디스크 hdd wd80eaaz']
#
# 클러스터 141:
# 대표 항목: 크리넥스 뽑아쓰는 키친타올
# 클러스터 내 항목 수: 27
# 클러스터 내 항목 (최대 10개):
# ['크리넥스 안심 클래식 키친타올', '크리넥스 안심 키친타올 에코패키지', '크리넥스 안심 키친타월', '크리넥스 클래식 키친타올', '크리넥스 뽑아쓰는키친타올', '크리넥스 뽑아쓰는 키친타올', '크리넥스 안심 키친타올', '뽑아쓰는 3겹 치킨타올', '한예지 뽑아쓰는 키친타올150', '크리넥스 도톰한 뽑아쓰는키친타올']
#
# 클러스터 142:
# 대표 항목: 종근당 락토핏 생유산균 골드 50포
# 클러스터 내 항목 수: 61
# 클러스터 내 항목 (최대 10개):
# ['종근당 락토핏 코어맥스 60포', '종근당건강 락토핏 골드 생유산균 x 50포', '락토핏 골드 50포+ 골드 60포 총 360포', '락토핏 코어맥스 60포', '락토핏 골드 50포 + 증정', '락토핏 골드 300포 + 증정', '종근당건강 생유산균 락토핏 코어맥스 60포', '락토핏 생유산균 로얄 60포', '락토핏 생유산균 골드 50포', '랏토핏 생유산균 로얄 60포']
#
# 클러스터 2584:
# 대표 항목: 1stplayer t7p 케이스 외 다수
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['1stplayer t7p 미들타워 외 다수', '1stplayer t7p 케이스 외 다수 510까지', '1stplayer t7p 케이스 외 다수']
#
# 클러스터 143:
# 대표 항목: sk하이닉스 p41 ssd
# 클러스터 내 항목 수: 20
# 클러스터 내 항목 (최대 10개):
# ['sk하이닉스 p41 ssd', 'sk 하이닉스 골드 p31 nvme ssd', 'sk 하이닉스 p31 nvme', 'sk하이닉스 gold p2 nvme ssd', 'sk하이닉스 p31', 'sk하이닉스 gold p31 nvme ssd', 'sk하이닉스 gold p31 m2 nvme tlc', 'sk하이닉스 p41', 'sk하이닉스 플래티넘 p41 ssd', 'sk 하이닉스 pc711']
#
# 클러스터 144:
# 대표 항목: 초록매실 제로
# 클러스터 내 항목 수: 10
# 클러스터 내 항목 (최대 10개):
# ['초록매실 제로', '초록매실제로', '초록매실제로 24펫', '초록 매실 제로', '초록매실 제로 24', '초록매실제로 x4', '초록매실제로x4', '초록매실 제로 x 24', '웅진 초록매실 제로', '초록매실']
#
# 클러스터 542:
# 대표 항목: 올반 영양삼계탕
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['올반 삼계탕 정', '올반 영양 삼계탕', '올반 영양삼계탕', '올반 삼계탕']
#
# 클러스터 145:
# 대표 항목: 아이스웨일 탄산수 플레인
# 클러스터 내 항목 수: 13
# 클러스터 내 항목 (최대 10개):
# ['아이스웨일 탄산수', '아이스웨일 플레인', '아이스웨일 탄산수 플레인맛', '아이스웨일 플레인 탄산수 40pet', '아이스웨일 플레인 탄산수 x 20pet', '광동 아이스웨일 탄산수 플레인', '아이스웨일 플레인 탄산수', '아이스웨일 플레인or자몽', '아이스웨일 탄산수 플레인 x 40p', '아이스웨일 탄산수 플레인']
#
# 클러스터 146:
# 대표 항목: 캘리포니아비치경주월드 이용권
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['캘리포니아비치경주월드 이용권 특가', '캘리포니아비치경주월드 종일이용권', '캘리포니아비치경주월드 이용권']
#
# 클러스터 1132:
# 대표 항목: 안심밥상 한돈 제주흑돼지 돼지세트
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['제주흑돼지 돼지세트', '안심밥상 한돈 제주흑돼지 돼지세트', '안심밥상 제주흑돼지세트', '한돈 제주흑돼지 돼지세트']
#
# 클러스터 147:
# 대표 항목: 닌텐도 스위치 oled
# 클러스터 내 항목 수: 12
# 클러스터 내 항목 (최대 10개):
# ['닌텐도 스위치 oled', '닌텐도스위치 oled', '닌텐도 스위치 oled + 마리오카트8 게임팩', '닌텐도 스위치 oled + 마리오 카트 8', '닌텐도 oled', '스위치 oled 네온', '닌텐도 스위치 oled 네온블루네온', '닌텐도 스위치 oled모델', '닌텐도 스위치 oled white', '위메프닌텐도 스위치 oled']
#
# 클러스터 148:
# 대표 항목: 갸스비 셋앤킵 스프레이
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['갸스비 셋앤킵 헤어스프레이', '갸스비 셋앤킵 스프레이', '갸스비 헤어 스프레이', '갸스비 센앤킵 스프레이']
#
# 클러스터 2171:
# 대표 항목: 매직쉐프 스타일리쉬 음식물처리기 mfwv
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['매직쉐프 스타일리쉬 음식물처리기', '매직쉐프 음식물처리기 mfwv', '매직쉐프 스타일리쉬 음식물처리기 mfwv']
#
# 클러스터 149:
# 대표 항목: 사이판 pic 골드카드 패밀리팩 3박5일
# 클러스터 내 항목 수: 19
# 클러스터 내 항목 (최대 10개):
# ['괌 pic 골드패스 자유여행', '괌 pic 골드패스 3박 5일 자유여행', '사이판 pic 골드카드 패밀리팩 3박5일', '사이판 월드리조트 골드카드 올인클루시브 3박5일', '사이판 pic 골드패스 자유여행', '사이판 pic 골드카드 3박5일', '사이판 월드리조트 골드카드 패밀리팩', '사이판 pic 골드카드 자유여행 3박 5일', '괌 pic 골드패스 패밀리팩 3박4일 자유여행', '괌 pic 골드패스 패밀리팩 3박4일']
#
# 클러스터 150:
# 대표 항목: 질레트 프로글라이드 파워 면도기 핸들1 + 면도날
# 클러스터 내 항목 수: 23
# 클러스터 내 항목 (최대 10개):
# ['질레트 프로글라이드 파워면도기 핸들1+면도날 +미니젤 증정', '질레트 프로글라이드 파워면도기 핸들1+면도날', '질레트 스킨텍 파워 면도기 + 면도날 + 미니젤', '질레트 스킨텍 파워면도기 + 면도날', '질레트 프로글라이드 파워 면도기 핸들1 + 면도날', '질레트 프로글라이드 파워 면도기 1up', '질레트 프로쉴드 파워 면도기 핸들1 + 면도날', '질레트 프로쉴드 파워 면도기 핸들+면도날', '질레트 프로쉴드 파워면도기 핸들 1+면도날+미니젤', '질레트 프로쉴드 파워 면도기 핸들1 + 면도날 + 미니젤 증정']
#
# 클러스터 151:
# 대표 항목: 프리미엄 류신 단백질 슈퍼맥스
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['프리미엄 류신 단백질 슈퍼맥스 고함량', '프리미엄 류신 단백질 슈퍼맥스', '고함량 프리미엄 류신 단백질 슈퍼맥스', '프리미엄 류신 단백질']
#
# 클러스터 152:
# 대표 항목: 닥터콜린 보호대
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['닥터콜린 손목보호대', '닥터콜린 보호대', '닥터콜린 무릎보호대', '닥터콜린 허리보호대']
#
# 클러스터 153:
# 대표 항목: 캐나다산 삼겹살목살
# 클러스터 내 항목 수: 12
# 클러스터 내 항목 (최대 10개):
# ['캐나다 삼겹살 목심', '보리먹은 캐나다산 삼겹살목살', '캐나다 삼겹살', '캐나다산 돼지 삼겹살목살', '캐나다산 돼지목심삼겹살', '보리먹인돼지 캐나다산 삼겹살목살', '품절 보리먹인돼지 캐나다산 삼겹살 목살', '캐나다산 삼겹살목심', '캐나다산 돼지 목심', '보리먹은돼지 캐나다산 삼겹살 목살 4만']
#
# 클러스터 154:
# 대표 항목: 팬물산 900 프로 철제 수납선반 5단
# 클러스터 내 항목 수: 10
# 클러스터 내 항목 (최대 10개):
# ['팬물산 900 프로 철제 수납선반 5단', '팬물산 900 프로 철제 수납 선반 5단', '철제 수납선반 5단 2종', '900 프로 철제 5단 수납선반', '팬물산 900 프로 철재 수납선반 5단 2종', '팬물산 철제 수납선반 5단 2종', '900프로 철제 수납선반 5단', '900 프로 철제 수납선반 5단', '900 프로 5단 철제 수납선반', '팬물산 900 프로 철제 수납선반 5단 2종']
#
# 클러스터 155:
# 대표 항목: 아이리버 이어폰
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['아이리버 이어폰', '아이팟 이어폰', '아이리버 무선 이어폰']
#
# 클러스터 2083:
# 대표 항목: 노블샌드제로 x 벤토나이트 고양이 모래
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['공구샌드 벤토나이트 고양이모래', '노블샌드제로 x 벤토나이트 고양이 응고형 모래', '노블샌드제로 벤토나이트 고양이 모래', '노블샌드제로 x 벤토나이트 고양이 모래']
#
# 클러스터 156:
# 대표 항목: 베이스어스 탁상 다용도 스탠드형 선풍기
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['베이스어스 탁상 다용도 스탠드형 선풍기', '베이스어스 스탠드형 선풍기', '베이스어스 탁상용 다용도 스탠드형 선풍기']
#
# 클러스터 462:
# 대표 항목: 클린앤소프트 천연펄프3겹
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['퓨어앤소프트 천연펄프3겹', '클린앤소프트 천연펄프3겹', '클린소프트 천연펄프']
#
# 클러스터 296:
# 대표 항목: 탑텐 코튼 베이직 반팔티
# 클러스터 내 항목 수: 10
# 클러스터 내 항목 (최대 10개):
# ['탑텐 코튼 베이직 반팔 티 3pack', '탑텐 코튼 베이직 반팔티', '탑텐 usa코튼 그래픽 반팔티', '탑텐 브이넥크루넥 반팔티', '탑텐 usa코튼 반팔티', '탑텐 usa코튼 그래픽 반팔 티', '탑텐 브이넥 반팔티', '탑텐 코튼 반팔티', '탑텐 베이직 반팔티', '탑텐 코튼 베이직 반팔티 3pc']
#
# 클러스터 157:
# 대표 항목: 소스 닭가슴살 3종
# 클러스터 내 항목 수: 62
# 클러스터 내 항목 (최대 10개):
# ['하림 냉장 수비드 닭가슴살 4종', '치큐 스팀 닭가슴살', '햇살닭 소스닭가슴살', '하림 냉장 수비드 닭가슴살 페퍼', '하림 냉장 수비드닭가슴살 페퍼', '냉장 닭가슴살', '치큐 스팀 닭가슴살 오리지널', '스팀 소스 닭가슴살', '스팀닭가슴살', '소스 닭가슴살 3종']
#
# 클러스터 158:
# 대표 항목: 농심 짜파게티
# 클러스터 내 항목 수: 26
# 클러스터 내 항목 (최대 10개):
# ['짜파게티', '농심 신라면+짜파게티', '농심 짜파게티 더', '농심 올리브 짜파게티', '사천 짜파게티', '농심 신라면 짜파게티안성탕면', '짜파게티 더', '농심 올리브짜파게티', '짜파게티 더 4p', '농심 신라면 x 짜파게티 더']
#
# 클러스터 159:
# 대표 항목: 티젠 콤부차 10스틱
# 클러스터 내 항목 수: 15
# 클러스터 내 항목 (최대 10개):
# ['티젠 콤부차 10스틱', '티젠 콤부차 30스틱입', '티젠 콤부차 혼합 220스틱', '티젠 콤부차 30스틱', '티젠 콤부차 20스틱', '티젠 콤부차 20스틱 외', '티젠 콤부차 20스틱+체험팩증정 외', '티젠 콤부차 10스틱 + 진저레몬10스틱', '티젠 콤부차 10스틱 +진저레몬10스틱', '티젠 콤부차 20스틱+10스틱']
#
# 클러스터 160:
# 대표 항목: 해피콜 플렉스팬 ih 와이드 22cm
# 클러스터 내 항목 수: 7
# 클러스터 내 항목 (최대 10개):
# ['해피콜 플렉스팬 ih 와이드 22cm', '해피콜 플렉스팬 11에디션 ih 인덕션 와이드 22cm', '해피콜 플렉스팬 11에디션 ih인덕션겸용 와이드 22cm', '해피콜 플렉스팬 인덕션와이드 22cm', '해피콜 플렉스팬 블랑 ih 와이드 22cm 2종 택 1', '해피콜 플렉스팬 22cm', '해피콜 플렉스팬 ih 20cm']
#
# 클러스터 161:
# 대표 항목: 정관장 홍삼지본 30포
# 클러스터 내 항목 수: 18
# 클러스터 내 항목 (최대 10개):
# ['정관장 홍삼지본', '정관장 홍삼원 x 30포', '정관장 홍삼진고 스틱 20포', '정관장 홍삼정', '정관장 홍삼원 20포', '정관장 홍삼본원스틱 30포', '정관장 근 홍삼본원스틱 30포', '정관장 홍삼진고', '정관장 홍삼지본 30포', '정관장 홍삼지본 30포 선물세트']
#
# 클러스터 2516:
# 대표 항목: 4대 편의점 금액권
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['클럽전용 4대 편의점 금액권', '4대 편의점 금액권', '4대 편의점 2천원 금액권']
#
# 클러스터 2185:
# 대표 항목: 먼지없는 베이직 항균 고정 밴딩 누빔 침대패드 sss 3colors
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['먼지없는 베이직 항균 고정 밴딩 누빔 침대패드', '먼지없는 베이직 항균 고정 밴딩 누빔 침대패드 sss q 3colors', '먼지없는 베이직 항균 고정 밴딩 누빔 침대패드 sss 3colors']
#
# 클러스터 163:
# 대표 항목: 구글 기프트코드 1만원권
# 클러스터 내 항목 수: 55
# 클러스터 내 항목 (최대 10개):
# ['구글 기프트코드권', '구글기프트코드', '20시 구글플레이 기프트코드 10', '구글기프트 10만원권', '구글 기프트 코드 십만원', '구글 기프트코드 10', '구글 기프트카드', '구글 기프트코드 1만원권', '구글 기프트카드 10만원권', '구글 플레이 기프트코드 10만권']
#
# 클러스터 164:
# 대표 항목: 한돈 냉장 삼겹살
# 클러스터 내 항목 수: 219
# 클러스터 내 항목 (최대 10개):
# ['옛날 대패삼겹살', '한돈 삼겹+목살', '삼겹살', '냉동 삼겹살', '냉동삼겹살', '대패 삼겹살', '보먹돼 삼겹목살', '보리먹고 자란 돼지 삼겹살목심당', '1등급 한돈 냉동 오겹살', '한돈 고추장 삼겹살 + 목살']
#
# 클러스터 165:
# 대표 항목: 금요일은 편의점 가는날
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['금토일은 편의점 가는날', '금요일은 편의점 가는 날', '금요일은 편의점 가는날']
#
# 클러스터 166:
# 대표 항목: 서울약사신협 프리미엄 홍삼정 천명 스틱 골드 30포
# 클러스터 내 항목 수: 12
# 클러스터 내 항목 (최대 10개):
# ['서울약사신협 홍삼정 천명스틱 골드 30포', '서울약사신협 홍삼정 천명 스틱골드 30포', '서울약사신협 홍삼정 천명 플러스 스틱 30포 +사은품', '서울약사신협 프리미엄홍삼정천명플러스30포', '서울약사신협 본사직영 프리미엄 홍삼정 천명 플러스 30포', '서울약사신협 프리미엄 홍삼정 천명 플러스 30포', '서울약사신협 프리미엄 홍삼정 천명 골드 30포', '서울약사신협 홍삼정 천명 스틱 골드 30포', '서울약사신협 프리미엄 홍삼정 천명스틱 골드 홍삼 스틱 30포', '홍삼정 천명스틱 골드 30포']
#
# 클러스터 168:
# 대표 항목: 애슐리 볶음밥 9종
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['애슐리 볶음밥 9종', '애슐리 볶음밥 맛 9종', '애슐리 볶음밥', '애슐리 볶음밥 7종']
#
# 클러스터 169:
# 대표 항목: 다인힐 브랜드 금액권
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['다인힐 브랜드 통함금액권', '다인힐 브랜드 금액권 특가', '다인힐 브랜드 통합 금액권', '다인힐 브랜드 금액권']
#
# 클러스터 171:
# 대표 항목: 하림 치킨너겟 페이
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['하림 치킨너겟', '하림 치킨너겟2', '하림 치킨너겟 페이', '하림 치킨너겟 1킬로 페이']
#
# 클러스터 172:
# 대표 항목: 아트뮤 pd31 pps gan 접지 멀티 초고속 충전기 gn210
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['아트뮤 usb pd pps gan 접지 멀티 초고속 충전기 gs610', '아트뮤 usb pd pps gan 접지 멀티 충전기', 'usb pd pps gan 접지 멀티 충전기', '아트뮤 pd31 pps gan 접지 멀티 초고속 충전기 gn410 출시특가', '아트뮤 pd31 pps gan 접지 멀티 초고속 충전기 gn210', 'pd31 pps gan 접지 멀티 초고속 충전기 gn210']
#
# 클러스터 3026:
# 대표 항목: 야크 라운드넥 경량 덕다운자켓
# 클러스터 내 항목 수: 8
# 클러스터 내 항목 (최대 10개):
# ['야크 라운드넥 경량패딩', '야크 라운드넥 경량패딩 m에코업패딩자켓', '야크 라운드넥 경량 패딩 자켓', '야크 덕다운자켓', '야크 경량다운자켓', '야크 경량 덕다운자켓', '야크 경량 다운 자켓', '야크 라운드넥 경량 덕다운자켓']
#
# 클러스터 1423:
# 대표 항목: bravotec guardian v2 타이탄 글래스 등
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['bravotec guardian 케이스', 'bravotec guardian v2 타이탄 글래스', 'bravotec guardian v2 타이탄 글래스 등', 'bravotec guardian v2 타이탄 글래스 a등급']
#
# 클러스터 793:
# 대표 항목: 자외선차단 쿨마스크
# 클러스터 내 항목 수: 12
# 클러스터 내 항목 (최대 10개):
# ['자외선 차단 쿨 스포츠 마스크 + 쿨토시', '라이더비 귀걸이형 자외선 차단 쿨 스포츠 마스크', '귀걸이형 자외선 차단 쿨 스포츠 마스크', '자외선차단 냉감마스크', '자외선 차단 스포츠 마스크', '자외선차단 쿨마스크', '자외선차단 쿨냉감마스크', '자외선차단 쿨냉감 마스크', '자외선 차단 쿨 스포츠 골프마스크', '자외선차단 골프마스크']
#
# 클러스터 173:
# 대표 항목: 갤럭시아이폰 투명 젤리케이스
# 클러스터 내 항목 수: 42
# 클러스터 내 항목 (최대 10개):
# ['투명 젤리 핸드폰 케이스', '갤럭시 아이폰 슬림 클리어 젤리 케이스', '갤럭시 아이폰 시리즈 슬림 클리어 젤리 케이스', '아이폰갤럭시 에어범퍼 젤리 케이스', '+1 아이폰갤럭시 범퍼 젤리 투명케이스', '방탄 젤리 핸드폰 케이스', '투명 핸드폰케이스', '갤럭시 아이폰 투명 케이스', '갤럭시아이폰 실리콘케이스', '갤럭시 아이폰 에어범퍼 젤리 케이스']
#
# 클러스터 174:
# 대표 항목: 안심한우 1등급 등심
# 클러스터 내 항목 수: 92
# 클러스터 내 항목 (최대 10개):
# ['암소 한우 사태 1등급', '암소 한우 1등급 채끝', '안심한우 1등급 채끝 구이용', '암소 한우 1등급', '안심한우 1등급 등심채끝', '안심한우 1등급 등심 구이용', '안심한우 1등급 구이용', '한우 암소 1등급 등심', '한우 암소 1등급 등심 채끝', '암소 한우 1등급 등심']
#
# 클러스터 175:
# 대표 항목: 풀무원 올바른 핫도그 +볶음밥
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['풀무원 올바른 핫도그 개별', '풀무원 올바른 핫도그 +볶음밥', '풀무원 올바른 핫도그 +치즈볼']
#
# 클러스터 176:
# 대표 항목: 친환경 생분해 강아지 배변봉투 + 디스펜서
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['친환경 생분해 강아지 배변봉투 + 디스펜서 증정', '친환경 생분해 강아지 배변봉투', '친환경 생분해 강아지 배변봉투 + 디스펜서', '생분해 강아지 배변봉투 +디스펜서']
#
# 클러스터 303:
# 대표 항목: 오뚜기 컵밥
# 클러스터 내 항목 수: 30
# 클러스터 내 항목 (최대 10개):
# ...
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['프링글스 맛 교차 선택', '프링글스 맛 교차 선택가능', '프링글스 맛 교차선택']
#
# 클러스터 3376:
# 대표 항목: 필립스 소닉케어 무선 파워플로서 강세정기
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['필립스 소닉케어 무선 파워플로서 강세정기', '필립스 소니케어 무선 파워플로서 강세정기', '필립스 소닉케어 무선 파워플로서 구강세정기']
#
# 클러스터 3378:
# 대표 항목: inutes till dawn
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['inutes till dawn', '배포 inutes till dawn', '게임 inutes till dawn']
#
# 클러스터 3570:
# 대표 항목: ps5 갓 오브 워 라그나로크 컬렉터즈 에디션
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['갓 오브 워 라그나로크 컬렉터즈', 'ps5 갓 오브 워 라그나로크 컬렉터스 에디션 할인', 'ps5 갓 오브 워 라그나로크 컬렉터즈 에디션']
#
# 클러스터 3577:
# 대표 항목: 클릭적립스토어 알림적립
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['클릭적립 보오글스토어 알림적립', '클릭적립스토어 알림', '클릭적립스토어 알림적립']
#
# 클러스터 3386:
# 대표 항목: 아스텔앤컨 acro be100
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['아스텔앤컨 acro be100 스피커', '아스텔앤컨 acro be100', '아스텔엔컨 스피커 acro be100']
#
# 클러스터 3390:
# 대표 항목: 사이버펑크 2077 얼티밋에디션
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['사이버펑크 2077 얼티밋에디션', '사이버펑크2077 얼티밋에디션', '사이버 펑크 2077 얼티밋 에디션 래플', '사이버 펑크 2077 얼티밋 에디션']
#
# 클러스터 3417:
# 대표 항목: 수퍼누트라 쿠바산 원료 폴리코사놀
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['수퍼누트라 쿠바산 폴리코사놀', '수퍼누트라 쿠바산 원료 폴리코사놀 90캡슐', '수퍼누트라 쿠바산 원료 폴리코사놀', '미국빠른 수퍼누트라 쿠바산 원료 폴리코사놀 90베지캡슐']
#
# 클러스터 3391:
# 대표 항목: 쿨러마스터 hyper 620s argb 투타워 공랭
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['쿨러마스터 hyper 620s argb', '쿨러마스터 hyper 620s argb 투타워 공랭쿨러', '쿨러마스터 hyper 620s argb 투타워 공랭']
#
# 클러스터 3480:
# 대표 항목: 닌텐도 스플래툰3 다운로드번호 동봉
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['스플래툰3 다운로드번호동봉상품', '닌텐도 스플래툰3 다운로드번호 동봉', '닌텐도 스플래툰3 다운로드번호동봉 + 특전 키링']
#
# 클러스터 3399:
# 대표 항목: 리아 한우불고기버거세트
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['한우불고기세트', '리아 한우불고기버거세트', '한우불고기버거세트', '리아 한우불고기버거 세트']
#
# 클러스터 3432:
# 대표 항목: 갤럭시탭 a8 smxifi 그레이
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['갤럭시탭a8 smxifi 그레이', '갤럭시탭 a8 smxifi 그레이', '갤럭시탭 a8 smxifi 롯카 등']
#
# 클러스터 3402:
# 대표 항목: 제로스킨 케이스 시그니처5
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['제로스킨 케이스 시그니처5', '제로스킨 핸드폰케이스 시그니처', '제로스킨 케이스 시그니처56']
#
# 클러스터 3404:
# 대표 항목: 불 에너지 드링크 오리지널
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['불 에너지드링크 오리지널슈가프리', '불 에너지드링크 오리지널', '불 에너지 드링크 슈가프리', '불 에너지 드링크 오리지널']
#
# 클러스터 3410:
# 대표 항목: 클릭적립 카드
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['클릭적립 마이카', '클릭적립 카드', '클릭적립 nh카드']
#
# 클러스터 3405:
# 대표 항목: 메타 퀘스트3 사전예약
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['메타퀘스트프로 사전예약', '메타 퀘스트3 사전예약', '메타 퀘스트3 vr 사전예약 외', '메타 퀘스트3 사전 예약']
#
# 클러스터 3408:
# 대표 항목: 홈플래닛 피트 인이어 이어폰
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['홈플래닛 피트 인이어 이어폰', '홈플래닛 피트 인이어이어폰', '홈플래닛 피트 인이어 이어폰 와우할인가']
#
# 클러스터 3409:
# 대표 항목: hmkwatch analog 140 하루
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['hmkwatch analog144 등 4종', 'hmkwatch analog144 연휴', 'hmkwatch analog 168 2종', 'hmkwatch analog 168 하루', 'hmkwatch analog 140', 'hmkwatch analog 140 하루']
#
# 클러스터 3411:
# 대표 항목: 월드콘구구콘
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['월드콘구구콘', '설레임월드콘구구콘', '월드콘 +구구콘']
#
# 클러스터 3524:
# 대표 항목: french phrase book learn 앱
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['russian phrase book learn 앱', 'french phrase book learn 앱', 'english phrase book learn 앱']
#
# 클러스터 3414:
# 대표 항목: 기분좋은선택 프리미엄 미용티슈
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['기분좋은선택 프리미엄 미용티슈', '기분좋은선택 미용티슈', '기분좋은선택 프리미엄 미용티슈 x6']
#
# 클러스터 3509:
# 대표 항목: 스노우라인 프라임디럭스텐트
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['스노우라인 프라임디럭스플러스 텐트', '스노우라인 프라임디럭스텐트', '스노우라인 프라임 디럭스']
#
# 클러스터 3512:
# 대표 항목: 말표 마력 에베레스트 에너지드링크
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['마력 에베레스트 에너지드링크', '말표 마력 에베레스트 에너지드링크', '말표 마력 다크홀스 에너지드링크']
#
# 클러스터 3418:
# 대표 항목: 메가커피 할메가커피
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['메가커피 할메가커피', '메가커피 할메가커피 외 2종', '메가커피 왕할메가커피']
#
# 클러스터 3419:
# 대표 항목: 이번주 만원 이하 할인 한국어 지원 타이틀
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['이번주 만원 이하 할인 한국어 지원 타이틀', '이번주 만천원 이하 한국어 지원 할인 타이틀', '이번주 만원 이하 한국어 지원 할인 타이틀', '이번주 만원 이하 할인 한국어 타이틀']
#
# 클러스터 3440:
# 대표 항목: lg 모니터 노트북 빅프로모션 안내 드립니다
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['모니터 노트북 빅프로모션 재안내 드립니다 27일', 'lg 모니터 노트북 빅프로모션 안내 드립니다', '모니터 노트북 빅 프로모션 예고 드립니다']
#
# 클러스터 3420:
# 대표 항목: octaring icon pack
# 클러스터 내 항목 수: 7
# 클러스터 내 항목 (최대 10개):
# ['octa dark icon pack', 'octaring icon pack', 'octane icon pack', 'six icon pack', 'klepon dark icon pack', 'klepon wheel dark icon pack', 'orgi icon pack']
#
# 클러스터 3560:
# 대표 항목: linios red icon pack
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['ichigo red icon pack', 'linios red icon pack', 'linios blue icon pack', 'linios pink icon pack']
#
# 클러스터 3421:
# 대표 항목: ps5 이스x 노딕스 아돌 크리스틴 에디션109500
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['원스토어 ps5 이스x 노르딕 아돌 크리스틴 에디션', 'ps5 이스x 노딕스 아돌 크리스틴 에디션 예약판 109500', 'ps5 이스x 노딕스 아돌 크리스틴 에디션109500', 'ns 이스x 노딕스 아돌크리스틴 에디션1095002500', 'ps5 이스x 노딕스 아돌 크리스틴 에디션 109500', 'ps5ps5 이스x 노딕스 아돌 크리스틴 에디션']
#
# 클러스터 3527:
# 대표 항목: 제주누보 논알콜 맥주
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['제주누보 논알콜', '제주누보 논알콜 맥주 할인', '제주누보 논알콜 맥주']
#
# 클러스터 3470:
# 대표 항목: 매일 상하유기농치즈 주스 요미요미 베스트
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['매일 상하목장 유기농주스 요미요미 베스트', '매일 상하유기농치즈 주스 요미요미', '매일 상하유기농치즈 주스 요미요미 베스트']
#
# 클러스터 3422:
# 대표 항목: 메가박스 포대팝콘
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['메가박스 포대팝콘', '메가박스 팝콘l', '메가박스 포대팝콘권 외']
#
# 클러스터 3423:
# 대표 항목: 9월 가을 경복궁 야간관람
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['10월 가을 경복궁 야간관람', '가을 경복궁 야간관람', '9월 가을 경복궁 야간관람']
#
# 클러스터 3452:
# 대표 항목: 버거킹 트러플 머쉬룸 와퍼 세트
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['버거킹 트러플머쉬룸와퍼 외', '버거킹 트러플 머쉬룸 와퍼 세트 주니어세트', '버거킹 트러플 머쉬룸 와퍼 세트']
#
# 클러스터 3460:
# 대표 항목: 야크 아이유 다운 u마카롱듀오플리스다운후디자켓
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['아이유 다운 u마카롱듀오플리스다운후디자켓 남여공용', '야크 아이유 다운 u마카롱듀오플리스다운후디자켓', '야크 u마카롱듀오플리스 다운후디자켓']
#
# 클러스터 3424:
# 대표 항목: 상주곶감 반건시 선물세트
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['상주곶감 반건시 선물세트', '상주곶감 선물세트', '상주 반건시 실속 선물세트']
#
# 클러스터 3579:
# 대표 항목: 반디 프리미엄 베이직 캔버스 방수 앞치마
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['프리미엄 캔버스 방수 앞치마', '프리미엄 베이직 캔버스 방수 앞치마 a802', '반디 프리미엄 베이직 캔버스 방수 앞치마']
#
# 클러스터 3427:
# 대표 항목: 주말특가 2종류
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['주말특가 2종류', '주말특가 3종류', '주말특가 4종류']
#
# 클러스터 3479:
# 대표 항목: 샘표 고등어
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['샘표 고등어통조림', '샘표 고등어캔', '샘표 고등어']
#
# 클러스터 3431:
# 대표 항목: 빅스 잠자리 마우스 정발
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['진행중 빅스 잠자리 마우스 정발', '빅스 잠자리 마우스 정발', '잠자리 마우스 정발']
#
# 클러스터 3481:
# 대표 항목: sk매직 보더리스 light 인덕션 ihram3b4
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['보더리스 light 인덕션 전기레인지 ihram3b4', 'sk매직 보더리스 light 인덕션 전기레인지', 'sk매직 보더리스 light 인덕션 신상', 'sk매직 보더리스 light 인덕션 ihram3b4', 'sk매직 보더리스 light 인덕션 ihram3b4 빌트인 신상', 'sk매직 보더리스 light 인덕션 ihram3b4 빌트인']
#
# 클러스터 3429:
# 대표 항목: 포터블 외장ssd t7 shield
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['전자 공식인증 포터블 외장ssd t7 shield 쉴드', '외장ssd t7 shiled', '온 공식인증 포터블 외장 ssd t7 shield', '외장 ssd t7 shield', '포터블 외장ssd t7 shield', '공식인증 포터블 외장 ssd t7 shield 실드']
#
# 클러스터 3430:
# 대표 항목: 유닉스 고출력 헤어드라이어 una1470n
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['유닉스 3단 풍속 조절 고출력 헤어 드라이어 una1470n', '유닉스 고출력 헤어드라이어 una1470n', '유닉스 음이온 고출력 헤어 드라이어 una1470n']
#
# 클러스터 3434:
# 대표 항목: futorum h1 디지털 시계 페이스
# 클러스터 내 항목 수: 6
# 클러스터 내 항목 (최대 10개):
# ['futorum h10 워치 페이스 3종', 'futorum h11 디지털 워치 페이스 3종', 'futorum h13 워치 페이스', 'futorum h13 디지털 시계 페이스', 'futorum h1 디지털 시계 페이스', 'futorum h10 디지털 시계 페이스']
#
# 클러스터 3586:
# 대표 항목: 삼립 잼있는 미니딸기쿠키
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['삼립 잼있는 딸기잼 쿠키', '삼립 잼있는 미니사과쿠키', '삼립 잼있는 미니딸기쿠키']
#
# 클러스터 3435:
# 대표 항목: 아웃 오브 라인 더 포레스트 콰르텟
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['아웃 오브 라인 더 포레스트 콰르텟', '아웃 오브 라인 더 포레스트 콰르텟 배포 시작', '게임 아웃 오브 라인 더 포레스트 콰르텟']
#
# 클러스터 3522:
# 대표 항목: 탑건 매버릭
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['4k 탑건 매버릭', '탑건매버릭', '탑건 매버릭']
#
# 클러스터 3439:
# 대표 항목: 플라이디지 베이더3 프로 무선 pc 게임패드 컨트롤러
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['플라이디지 베이더3 프로 무선 컨트롤러', '플라이디지 베이더3 프로 무선 pc 게임패드 컨트롤러 vader3 pro', '플라이디지 베이더3 프로 무선 pc 게임패드 컨트롤러']
#
# 클러스터 3441:
# 대표 항목: ssd 870 evo sata3 tlc mz77e4t0bw
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['ssd 870 evo sata3 tlc mz77e4t0bw', '전자 ssd 870 evo sata3 tlc mz77e4t0bw', 'ssd 870 evo mz77e4t0bw', 'ssd 870 evo mz77e2t0bw']
#
# 클러스터 3442:
# 대표 항목: ssd 870 evo
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['ssd 870 evo 카드혜택', 'ssd 870 evo', '전자 ssd 870 evo']
#
# 클러스터 3485:
# 대표 항목: 해남 햇 꿀고구마 베니하루카 특상
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['해남 햇 꿀고구마 특상 베니하루카', '햇고구마 베니하루카 특상', '해남 햇 꿀고구마 베니하루카 특상']
#
# 클러스터 3472:
# 대표 항목: 시나노 골드 사과
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['시나노골드 사과 실속', '시나노 골드사과', '시나노 골드 사과']
#
# 클러스터 3443:
# 대표 항목: 마블어벤져스 완전판
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['마블 어벤져스 완전판', '마블어벤져스 완전판', '마블어벤저스 완전판']
#
# 클러스터 3573:
# 대표 항목: 리엔케이 고농축 탄력케어 4종세트 + 세럼증정
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['고농축 탄력케어 4종세트 + 세럼증정', '리엔케이 고농축 탄력케어 4종세트 + 세럼증정 +샘플파우치', '리엔케이 고농축 탄력케어 4종세트 + 세럼증정']
#
# 클러스터 3447:
# 대표 항목: 2080진지발리스 오리지널 치약
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['2080진지발리스 시리즈 치약', '2080진지발리스 오리지널 치약', '2080 오리지널 치약']
#
# 클러스터 3449:
# 대표 항목: 샤인머스켓 2수
# 클러스터 내 항목 수: 7
# 클러스터 내 항목 (최대 10개):
# ['자인 샤인머스켓 23수', '샤인머스켓 23수', '샤인머스캣 23수', '샤인머스켓 특품 2수', '샤인머스켓 2수', '샤인머스켓 특품', '샤인머스캣 1수']
#
# 클러스터 3451:
# 대표 항목: 컬러풀 rtx 4060 ti 울트라 duo 외 6종
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['컬러풀 rtx 4060 ti 울트라 duo 외 6종', '컬러풀 rtx 4060 ti 울트라 duo 외 6종 컬러풀x하이마트 기획전', '컬러풀 rtx 4070 ti 울트라 oc']
#
# 클러스터 3453:
# 대표 항목: 찬우물 열무김치 총각김치 포기김치
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['찬우물 열무김치파김치총각김치포기김치', '찬우물 열무김치총각김치포기김치 부터', '찬우물 열무김치 총각김치 포기김치']
#
# 클러스터 3500:
# 대표 항목: 삼양 할라피뇨치즈 불닭볶음면 큰컵
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['삼양 할라피뇨 치즈 불닭 볶음면 큰컵 와우 할인가', '삼양 할라피뇨치즈 불닭볶음면 큰컵', '삼양 할라피뇨 불닭볶음면 컵']
#
# 클러스터 3457:
# 대표 항목: 농심 튀김우동 큰사발면
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['농심 튀김우동 큰사발면', '튀김우동 큰사발면', '튀김우동 큰사발', '농심 튀김우동큰사발']
#
# 클러스터 3463:
# 대표 항목: 발키리 a360 argb 예판
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['발키리 a360 argb 특가예판진행', '발키리 a360 argb 수냉쿨러', '발키리 a360 argb 예판']
#
# 클러스터 3462:
# 대표 항목: 스트라다 단열 스테인레스 스틸 쉐이커 보틀
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['스트라다 단열 스테인레스 스틸 쉐이커 보틀', '스트라다 단열 스테일레스 스틸 쉐이커 보틀', '스트라다 단열 스테인레스 스틸 쉐이커 보틀 보냉 텀블러']
#
# 클러스터 3464:
# 대표 항목: 몽블랑 익스플로러 edp
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['몽블랑 익스플로러 향수 edp', '몽블랑 익스플로러 edp', '몽블랑 익스플로러 edt']
#
# 클러스터 3471:
# 대표 항목: 몬스터에너지 제로슈거
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['몬스터에너지 제로슈거', '몬스터 에너지 제로슈거', '몬스터에너지제로슈거']
#
# 클러스터 3476:
# 대표 항목: 홍로사과
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['홍로사과', '홍로 사과', '햇 홍로사과']
#
# 클러스터 3477:
# 대표 항목: gskill trident z5 neo rgb 시리즈 sdram ddr5 6000 cl32 135v
# 클러스터 내 항목 수: 5
# 클러스터 내 항목 (최대 10개):
# ['gskill trident z5 neo rgb 시리즈 sdram ddr5 6000 cl32 135v', 'gskill trident z5 neo rgb 시리즈 sdram ddr5 6000 cl32 135v 듀얼 채널 데스크탑 메모리 매트', 'gskill trident z5 neo 시리즈 sdram ddr5 6000', 'gskill trident z5 neo rgb ddr5 6000 cl36', 'gskill trident z5 neo rgb 시리즈 sdram ddr5 6000 cl36 135v 듀얼 체널 데스크탑 메모리 매트']
#
# 클러스터 3572:
# 대표 항목: 전자 990 pro pcie 40 nvme ssd mzv9p2t0bw
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['전자 990 pro nvme tlc ssd mzv9p2t0bw', '전자 990 pro pcie 40 nvme ssd mzv9p2t0bw', '990 pro pcie 40 nvme ssd mzv9p2t0bw']
#
# 클러스터 3486:
# 대표 항목: msi md241pw ips 모니터
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['msi md241pw 모니터 특가', 'msi md241pw ips 아이케어 무결점 모니터', 'msi md241pw ips 모니터', 'msi md241pw ips 아이케어 피벗 모니터']
#
# 클러스터 3484:
# 대표 항목: crucial p5 plus 4세대 nvme m2 ssd 내장 게이밍 ssd
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['crucial p5 plus 4세대 nvme m2 ssd 내장 게이밍 ssd 히트싱크 포함', 'crucial p5 plus 4세대 nvme m2 ssd 내장 게이밍 ssd', 'crucial p5 plus 4세대 nvme m2 ssd 방열판 포함']
#
# 클러스터 3483:
# 대표 항목: 원모어 소노플로우 se 노이즈 캔슬링 블루투스 헤드폰
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['원모어 소노플로우 se 노이즈 캔슬링 블루투스 헤드폰', '원모어 소노플로우se 노이즈 캔슬링 헤드폰', '원모어 소노플로우 ldac 고음질 노이즈캔슬링 블루투스 헤드폰']
#
# 클러스터 3487:
# 대표 항목: 네파 남여공용 ctr 롱 푸퍼 구스 다운 자켓 7hf2064
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['네파 남여공용 ctr 롱 푸퍼 구스 다운 자켓 7hf2064', '끌올 네파 남여공용 ctr 롱 푸퍼 구스 다운 자켓 7hf2064', '네파 남여공용 ctr 롱 푸퍼 구스 다운 자켓 7hf2064 74380원']
#
# 클러스터 3490:
# 대표 항목: 오가닉 그라운드 유기농 유아 스킨케어 5종세트
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['오가닉 그라운드 유기농 유아 스킨케어 5종세트', '오가닉그라운드 프리미엄 유아 스킨케어 5종 세트', '오가닉 그라운드 유기농 유아 스킨케어']
#
# 클러스터 3491:
# 대표 항목: 포스트 콘푸라이트13슈거라이트 시리얼
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['동서 포스트 콘푸라이트13슈거라이트 시리얼', '포스트 콘푸라이트13슈거라이트 시리얼', '콘푸라이트13슈거라이트 시리얼']
#
# 클러스터 3492:
# 대표 항목: ns 위쳐3 컴플리트 에디션 445002500
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['ns 위쳐3 컴플리트 에디션 445002500', '위쳐3 컴플리트 에디션 448002500', 'ns 위쳐3 컴플리트 에디션 450000']
#
# 클러스터 3493:
# 대표 항목: ps5 아머드 코어 6 루비콘의 화염 콜렉터즈 에디션
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['ps5 아머드 코어 vi 루비콘의 화염 컬렉터즈 에디션', 'ps5 아머드 코어 6 루비콘의 화염 콜렉터즈 에디션', 'ps45 아머드 코어6 루비콘의 화염 콜렉터즈', '아머드코어6 루비콘의 화염 콜렉터즈에디션']
#
# 클러스터 3494:
# 대표 항목: 비스포크 직수 냉온정수기 rwp54421bf
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['비스포크 직수형 냉온정수기 rwp54421bf 언더싱크', '비스포크 직수형 냉온정수기 rwp54421bf 빌트인 정수기', '비스포크 직수 냉온정수기 rwp54421bf']
#
# 클러스터 3496:
# 대표 항목: lck 우승 프로모션 재 안내 드립니다
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['lck 우승 프로모션 재안내 드립니다 910', 'lck 우승 프로모션 재 안내 드립니다', 'lck 젠지 우승 프로모션 안내 드립니다']
#
# 클러스터 3578:
# 대표 항목: 게임용 컴퓨터 라이젠5 7600 + rtx 4070 ti 구성
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['게임용 컴퓨터 라이젠5 7600 + rtx 4070 ti crr no371', '게임용 컴퓨터 라이젠5 7600 + rtx 4070 게임 2종 증정', '게임용 컴퓨터 라이젠5 7600 + rtx 4070 ti 구성']
#
# 클러스터 3563:
# 대표 항목: 방수 매트리스커버베개커버
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['기능성 방수 매트리스커버 베개커버', '방수매트리스커버 s + 베개커버', '방수 매트리스커버베개커버']
#
# 클러스터 3497:
# 대표 항목: 세그웨이 나인봇 전동킥보드 f20a
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['나인봇 전동킥보드 f20a', '세그웨이 나인봇 전동킥보드 f20a', '세그웨이나인봇 전동 킥보드 f20a']
#
# 클러스터 3502:
# 대표 항목: 페이포인트 받으세요
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['페이포인트 받으세요', '포인트 받으세요', '페이인트 받으세요']
#
# 클러스터 3504:
# 대표 항목: 우주패스 slim 연간
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['우주패스 slim 연간 구독', '우주패스 slim 연간 쿠폰', '우주패스 slim 연간']
#
# 클러스터 3511:
# 대표 항목: 제로스킨 시그니처5 휴대폰 케이스
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['제로스킨 시그니처5 휴대폰 케이스', '제로스킨 시그니처 6 휴대폰 케이스', '제로스킨 시그니처 폰케이스']
#
# 클러스터 3514:
# 대표 항목: 헤이오트x프렌즈 현미누룽지오트밀
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['헤이오트 프렌즈 현미누룽지오트밀', '헤이오트x프렌즈 현미누룽지오트밀', '헤이오트x프렌즈 누룽지 오트밀']
#
# 클러스터 3515:
# 대표 항목: lg 32un880 uhd 4k 모니터 특가 안내
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['lg 32un880 uhd 4k 모니터 특가 안내', 'lg 32un880 울트라hd 4k 모니터', 'lg 32un880 4k 모니터 11절 특가 사전안내']
#
# 클러스터 3519:
# 대표 항목: 캐치티니핑 티니핑 abc 영어놀이 사운드카드 + 하츄핑 키링
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['캐치티니핑 티니핑 abc 영어놀이세트 + 키링', '캐치티니핑 abc 영어놀이 사운드카드 + 하츄핑 키링 포함', '캐치티니핑 티니핑 abc 영어놀이 사운드카드 + 하츄핑 키링', '캐치티니핑 티니핑 abc 영어놀이 사운드카드 +하츄핑 키링']
#
# 클러스터 3518:
# 대표 항목: intex explorer 300 용 공기 주입식 보트 세트
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['intex explorer 300 용 공기 주입식 보트 세트 우주패스', 'intex explorer 300 용 공기 주입식 보트 세트', '끌올 intex explorer 300 용 공기 주입식 보트 세트']
#
# 클러스터 3520:
# 대표 항목: 테이프공 만들기 비비드 48cm +워터비즈볼 외
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['테이프공 만들기 펄 48cm + 워터비즈볼', 'kc인증 테이프공 만들기 비비드 48cm +워터비즈볼', '테이프공 만들기 비비드 48cm +워터비즈볼 외']
#
# 클러스터 3521:
# 대표 항목: 닌텐도 스위치 파이널 판타지 픽셀 리마스터
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['닌텐도 스위치 파이널 판타지 픽셀 리마스터 한글판', '닌텐도 스위치 파이널판타지 픽셀 리마스터 컬렉션', '닌텐도 스위치 파이널 판타지 픽셀 리마스터']
#
# 클러스터 3530:
# 대표 항목: 주연테크 qhd 모니터
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['주연테크 uhd 모니터', '주연테크 qhd 게이밍모니터', '주연테크 qhd 모니터']
#
# 클러스터 3574:
# 대표 항목: 갓성비 코튼브리즈 건조기시트 섬유유연제
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['갓성비 코튼브리즈 건조기시트', '갓성비 코튼브리즈 + 건조기시트 섬유유연제', '갓성비 코튼브리즈 건조기시트 섬유유연제']
#
# 클러스터 3535:
# 대표 항목: 큰컵 불닭볶음면 x 임박특가
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['큰컵 불닭볶음면 x 임박특가', '큰컵 불닭볶음면 임박특가', '큰컵 불닭볶음면 x 9월20일 임박특가']
#
# 클러스터 3565:
# 대표 항목: 샤오미 유선 선풍기
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['샤오미 bldc 유선 선풍기', '샤오미 유선 선풍기 2세대', '샤오미 유선 선풍기']
#
# 클러스터 3546:
# 대표 항목: black book 외
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['black book', 'black book 외 1종', 'black book 외']
#
# 클러스터 3549:
# 대표 항목: 홍천한우마을 일품떡갈비 외
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['홍천한우마을 일품떡갈비 외 11가지', '홍천한우마을 일품떡갈비 3팩 외', '홍천한우마을 일품떡갈비 외']
#
# 클러스터 3552:
# 대표 항목: 대한민국 명품특산물
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['대한민국 명품특산물 입장권', '대한민국 명품특산물 박람', '대한민국 명품특산물']
#
# 클러스터 3553:
# 대표 항목: 815콜라 제로
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['815콜라제로', '815콜라 제로 음료', '웅진식품 815콜라 제로 음료', '815콜라 제로']
#
# 클러스터 3557:
# 대표 항목: 닥터크린 피톤치트 물티슈 엠보싱 캡형 sm
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['닥터크린 피톤치트 물티슈 캡형 sm', '닥터크린 피톤치트 물티슈', '닥터크린 피톤치트 물티슈 엠보싱 캡형', '닥터크린 피톤치트 물티슈 엠보싱 캡형 sm']
#
# 클러스터 3568:
# 대표 항목: 킹덤 러쉬 벤전스
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['킹덤 러쉬 벤전스', '킹덤러쉬 벤전스', '킹덤 러쉬 벤전스 게임']
#
# 클러스터 3571:
# 대표 항목: 푸드 장조림 통조림
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['푸드 장조림 통조림', '푸드 장조림 통조림3', '장조림 통조림']
#
# 클러스터 3576:
# 대표 항목: 2차 기프티콘 100퍼 문자로 바로와요
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['기프티콘 문자로 바로와요', '2차 기프티콘 문자로 바로와요', '2차 기프티콘 100퍼 문자로 바로와요', '기프티콘 100퍼 문자로 바로와요']
#
# 클러스터 3589:
# 대표 항목: all 덴탈마스크 대형
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['all 위니 덴탈마스크 대형', 'all 일회용마스크 대형', 'all 덴탈마스크 대형']
#
# 클러스터 3587:
# 대표 항목: 갤럭시z 플립5 z폴드5 사전예약
# 클러스터 내 항목 수: 3
# 클러스터 내 항목 (최대 10개):
# ['갤럭시z 플립5 z폴드 사전예약', '갤럭시z 플립5 z폴드5 사전예약', '갤럭시z 플립5 z폴드 5 사전예약']
#
# 클러스터 3590:
# 대표 항목: 파이널 판타지 16 스탠다드
# 클러스터 내 항목 수: 4
# 클러스터 내 항목 (최대 10개):
# ['파이널 판타지 16 스탠다드 부산 중앙동', '파이널 판타지 16 스탠다드', '파이널판타지 16 스탠다드', '파이널판타지 16 스탠다드 에디션']

# %%
conda install rapidfuzz
# Out:
# Channels:
#  - conda-forge
#  - nvidia
#  - rapidsai
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.7.1
#     latest version: 24.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /root/miniconda3/envs/jupyter_env
#
#   added / updated specs:
#     - rapidfuzz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     rapidfuzz-3.10.0           |  py310hf71b8c6_0         2.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   rapidfuzz          conda-forge/linux-64::rapidfuzz-3.10.0-py310hf71b8c6_0
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
